# %% [markdown]
# ## Load dataset

# %%
import json
from datasets import load_dataset, Dataset
from transformers import AutoTokenizer
import matplotlib.pyplot as plt
import numpy as np

# %%
CACHE_DIR = "/huggingface/cache"


DATASET_NAME = "isek-ai/danbooru-tags-2023"

# %%
ds = load_dataset(DATASET_NAME, name="all", split="train", cache_dir=CACHE_DIR)
ds
# Out:
# Dataset({
#     features: ['id', 'copyright', 'character', 'artist', 'general', 'meta', 'rating', 'score', 'created_at'],
#     num_rows: 6574149
# })

# %% [markdown]
# ## Simple filtering

# %%
ds = ds.filter(lambda x: x["general"] is not None, batched=False)
ds
# Out:
# Dataset({
#     features: ['id', 'copyright', 'character', 'artist', 'general', 'meta', 'rating', 'score', 'created_at'],
#     num_rows: 6574005
# })

# %% [markdown]
# ## Create general tag lists by rating

# %%
general_general_tags = set()
general_sensitive_tags = set()
general_questionable_tags = set()
general_explicit_tags = set()

general_general_tag_counts = {}
general_sensitive_tag_counts = {}
general_questionable_tag_counts = {}
general_explicit_tag_counts = {}


def load_general_tags(examples):
    for i, general in enumerate(examples["general"]):
        rating = examples["rating"][i]
        for tag in general.split(", "):
            if rating == "g":
                general_general_tags.add(tag)
                if tag not in general_general_tag_counts:
                    general_general_tag_counts[tag] = 1
                else:
                    general_general_tag_counts[tag] += 1
            elif rating == "s":
                general_sensitive_tags.add(tag)
                if tag not in general_sensitive_tag_counts:
                    general_sensitive_tag_counts[tag] = 1
                else:
                    general_sensitive_tag_counts[tag] += 1
            elif rating == "q":
                general_questionable_tags.add(tag)
                if tag not in general_questionable_tag_counts:
                    general_questionable_tag_counts[tag] = 1
                else:
                    general_questionable_tag_counts[tag] += 1
            elif rating == "e":
                general_explicit_tags.add(tag)
                if tag not in general_explicit_tag_counts:
                    general_explicit_tag_counts[tag] = 1
                else:
                    general_explicit_tag_counts[tag] += 1


ds.map(load_general_tags, batched=True)
# Out:
# Map:   0%|          | 0/6574005 [00:00<?, ? examples/s]
# Dataset({
#     features: ['id', 'copyright', 'character', 'artist', 'general', 'meta', 'rating', 'score', 'created_at'],
#     num_rows: 6574005
# })

# %%
general_sensitive_tag_counts
# Out:
# {'1girl': 2740350,
#  ':d': 264919,
#  'artist name': 130379,
#  'barefoot': 164808,
#  'black hair': 629488,
#  'black skirt': 127145,
#  'brown eyes': 400564,
#  'butterfly sitting': 540,
#  'classroom': 6144,
#  'copyright notice': 3932,
#  'desk': 15274,
#  'feet': 76312,
#  'hairband': 220247,
#  'indoors': 113642,
#  'knees apart feet together': 735,
#  'long hair': 1996089,
#  'looking at viewer': 1502503,
#  'not for sale': 73,
#  'on desk': 2499,
#  'open mouth': 952020,
#  'pleated skirt': 237969,
#  'school desk': 6454,
#  'school uniform': 358545,
#  'serafuku': 151347,
#  'short sleeves': 267053,
#  'sitting': 452256,
#  'sitting on desk': 1705,
#  'skirt': 768453,
#  'smile': 1328998,
#  'solo': 2408602,
#  'window': 53248,
#  'black leotard': 37189,
#  'blue eyes': 802114,
#  'breasts': 1499060,
#  'bustier': 3250,
#  'cleavage': 628136,
#  'corset': 21700,
#  'demon girl': 33470,
#  'gothic': 2313,
#  'green hair': 180497,
#  'head wings': 27840,
#  'huge breasts': 51766,
#  'jewelry': 467775,
#  'lace': 18503,
#  'leotard': 113475,
#  'lingerie': 21044,
#  'necklace': 117862,
#  'underwear': 308847,
#  'wings': 208627,
#  '1boy': 358662,
#  'ahoge': 280685,
#  'ass': 183237,
#  'bandeau': 13589,
#  'bikini': 283656,
#  'blonde hair': 705098,
#  'blush': 1171660,
#  'caustics': 1515,
#  'couple': 29906,
#  'green eyes': 374661,
#  'hetero': 36895,
#  'nervous': 3829,
#  'official alternate costume': 130775,
#  'partially submerged': 15840,
#  'pool': 10819,
#  'pool ladder': 1912,
#  'poolside': 4955,
#  'ribbon': 524951,
#  'sweatdrop': 90142,
#  'swimming': 2638,
#  'swimsuit': 376788,
#  'teaching': 135,
#  'water': 113515,
#  'white bikini': 53539,
#  'blue hair': 372337,
#  'braid': 288402,
#  'hair over one eye': 99299,
#  'long sleeves': 603494,
#  'oekaki': 8021,
#  'pajamas': 11911,
#  'parted lips': 217065,
#  'sweat': 118109,
#  'you gonna get raped': 2380,
#  '6+girls': 42419,
#  'breast press': 14021,
#  'brown hair': 664286,
#  'child': 21656,
#  'crossover': 27473,
#  'dyed bangs': 1186,
#  'hair slicked back': 3988,
#  'half updo': 16768,
#  'large breasts': 682881,
#  'midriff': 197022,
#  'multicolored hair': 252007,
#  'multiple girls': 711861,
#  'name tag': 11103,
#  'navel': 469962,
#  'one-piece swimsuit': 83942,
#  'red hair': 223246,
#  'retro artstyle': 7825,
#  'school swimsuit': 40330,
#  'slingshot swimsuit': 1678,
#  'sunglasses': 43301,
#  'symmetrical docking': 3134,
#  'bat wings': 32782,
#  'bracelet': 97299,
#  'closed mouth': 440989,
#  'demon tail': 24456,
#  'demon wings': 17078,
#  'earrings': 235906,
#  'elbow gloves': 154819,
#  'gloves': 629441,
#  'half-closed eyes': 26255,
#  'miniskirt': 137956,
#  'pencil skirt': 20095,
#  'pointy ears': 154842,
#  'red background': 21078,
#  'red eyes': 606928,
#  'red theme': 4741,
#  'tail': 344109,
#  'twintails': 424156,
#  'flat chest': 51084,
#  'forehead': 19535,
#  'goggles': 29367,
#  'goggles on head': 16924,
#  'grin': 102424,
#  'hands': 11836,
#  'one eye closed': 197636,
#  'shouting': 3423,
#  'swim cap': 832,
#  'watermark': 39120,
#  '^_^': 43953,
#  'aqua hair': 51140,
#  'beret': 43475,
#  'black neckerchief': 5535,
#  'black socks': 31894,
#  'black thighhighs': 152066,
#  'blazer': 32954,
#  'blue-framed eyewear': 1901,
#  'blue jacket': 29848,
#  'blue pants': 9115,
#  'blue sky': 91955,
#  'blue socks': 2705,
#  'brown headwear': 9479,
#  'brown pantyhose': 19420,
#  'brown socks': 773,
#  'building': 22570,
#  'buttons': 47175,
#  'closed eyes': 261575,
#  'cloud': 141979,
#  'curly hair': 14350,
#  'day': 173250,
#  'double-breasted': 8840,
#  'drill hair': 41437,
#  'everyone': 7966,
#  'faceless': 8864,
#  'faceless male': 5348,
#  'facing viewer': 18614,
#  'feet out of frame': 58215,
#  'glasses': 159633,
#  'group picture': 1005,
#  'hair intakes': 43160,
#  'hair ribbon': 297881,
#  'hands on own hips': 15069,
#  'harem': 755,
#  'hat': 579285,
#  'hug': 56267,
#  'jacket': 358215,
#  'kneehighs': 59798,
#  'lineup': 1928,
#  'looking over eyewear': 1814,
#  'loose socks': 4372,
#  'neckerchief': 66210,
#  'necktie': 181428,
#  'orange hair': 97527,
#  'outdoors': 229928,
#  'over-rim eyewear': 1623,
#  'pants': 139793,
#  'pantyhose': 269369,
#  'parted hair': 1342,
#  'pink-framed eyewear': 1642,
#  'pink hair': 290219,
#  'ponytail': 287316,
#  'pregnant': 1356,
#  'purple eyes': 362318,
#  'purple hair': 278582,
#  'red sailor collar': 2432,
#  'sailor collar': 102032,
#  'school': 2131,
#  'semi-rimless eyewear': 20207,
#  'shirt': 655560,
#  'short hair': 986323,
#  'short twintails': 26502,
#  'sky': 202680,
#  'socks': 152648,
#  'teacher': 2210,
#  'thighhighs': 584048,
#  'twin drills': 21588,
#  'white socks': 33607,
#  'yellow jacket': 7343,
#  'yellow shirt': 11604,
#  'zettai ryouiki': 90751,
#  '2girls': 462455,
#  'front-tie top': 28659,
#  'hug from behind': 12305,
#  'lotion': 1131,
#  'pink eyes': 115176,
#  'side-tie bikini bottom': 56767,
#  'standing': 401770,
#  'sunscreen': 823,
#  'thigh gap': 38339,
#  'twin braids': 85190,
#  'very long hair': 464982,
#  'yuri': 76897,
#  'bandages': 43559,
#  'bare shoulders': 548519,
#  'choker': 193654,
#  'fingerless gloves': 125703,
#  'katana': 37141,
#  'sarashi': 15226,
#  'sword': 150176,
#  'torn clothes': 47315,
#  'weapon': 321117,
#  'bare legs': 77597,
#  'bra strap': 4262,
#  'cigarette': 13425,
#  'curtains': 26404,
#  'elf': 22415,
#  'orange sky': 1970,
#  'smoking': 9628,
#  't-shirt': 27231,
#  'alternate hairstyle': 54742,
#  'ball': 22486,
#  'bike shorts': 28350,
#  'cleats': 197,
#  'crop top': 108552,
#  'crown': 31459,
#  'eyelashes': 61321,
#  'flipped hair': 8328,
#  'full body': 338952,
#  'gem': 27664,
#  'hair tie': 10438,
#  'hair up': 6398,
#  'high ponytail': 33497,
#  'legs apart': 15449,
#  'light smile': 32752,
#  'lipstick': 26540,
#  'makeup': 50364,
#  'pink lips': 12105,
#  'pink socks': 980,
#  'playing sports': 355,
#  'shoes': 192524,
#  'sidelocks': 251717,
#  'simple background': 741986,
#  'sketch': 70266,
#  'sneakers': 27911,
#  'soccer': 939,
#  'soccer ball': 1792,
#  'soccer uniform': 3017,
#  'sphere earrings': 524,
#  'sportswear': 12703,
#  'telstar': 681,
#  'turtleneck': 48444,
#  'uniform': 88788,
#  'white background': 622143,
#  'white gloves': 134154,
#  'bare arms': 84645,
#  'china dress': 30102,
#  'chinese clothes': 48619,
#  'cleavage cutout': 53949,
#  'clothing cutout': 87228,
#  'cosplay': 69390,
#  'covered nipples': 29760,
#  'dress': 637551,
#  'facial mark': 40955,
#  'forehead mark': 10423,
#  'parody': 36157,
#  'pelvic curtain': 27463,
#  'ranpha franboise (cosplay)': 8,
#  'sleeveless': 210622,
#  'sleeveless dress': 72523,
#  'bow': 545919,
#  'bow panties': 13136,
#  'food': 195122,
#  'food on face': 8585,
#  'groin': 58634,
#  'hair bobbles': 26695,
#  'hair ornament': 651343,
#  'no pants': 23168,
#  'nose bubble': 1049,
#  'panties': 238363,
#  'sleeping': 30752,
#  'sleepy': 4161,
#  'yellow panties': 1886,
#  'arm support': 44445,
#  'hair twirling': 2334,
#  'male focus': 188337,
#  'no shoes': 42911,
#  'otoko no ko': 19664,
#  'yokozuwari': 11682,
#  '3girls': 115616,
#  ':o': 85355,
#  'albino': 3409,
#  'arms behind back': 30584,
#  'halterneck': 61582,
#  'photo background': 2044,
#  'pink bikini': 11660,
#  'purple bikini': 9618,
#  'small breasts': 192622,
#  'striped bikini': 16874,
#  'striped clothes': 36956,
#  'tankini': 1682,
#  'vertical-striped bikini': 886,
#  'vertical-striped clothes': 3965,
#  'water slide': 283,
#  'waterpark': 90,
#  'waves': 3269,
#  'white hair': 304250,
#  'bobby socks': 4658,
#  'book': 65341,
#  'bucket': 7079,
#  'ceiling': 1471,
#  'duster': 726,
#  'dutch angle': 54182,
#  'embarrassed': 36244,
#  'flower': 292187,
#  'frills': 227670,
#  'from below': 31489,
#  'maid': 70250,
#  'mary janes': 20909,
#  'multicolored clothes': 23776,
#  'multicolored panties': 164,
#  'picture frame': 3099,
#  'rag': 319,
#  'striped panties': 15581,
#  'vase': 3046,
#  'white panties': 68260,
#  'wind': 28254,
#  'wind lift': 9170,
#  'wrist cuffs': 84176,
#  'bottle': 33116,
#  'floral print': 40458,
#  'greyscale': 207777,
#  'lace-trimmed panties': 4839,
#  'lace trim': 22448,
#  'lowleg': 7584,
#  'monochrome': 266511,
#  'print thighhighs': 2778,
#  'vertical stripes': 20020,
#  'alternate costume': 201020,
#  'enmaided': 12642,
#  'frilled thighhighs': 3832,
#  'maid headdress': 65974,
#  'leaning forward': 57478,
#  'orange bikini': 4020,
#  '3:': 3853,
#  '3;': 105,
#  'age difference': 5388,
#  'fruit': 49063,
#  'height difference': 11526,
#  'kooribata': 181,
#  'watermelon': 5366,
#  'copyright name': 55156,
#  'elbow pads': 3526,
#  'incoming attack': 979,
#  'incoming punch': 272,
#  'low-tied long hair': 17167,
#  'medium breasts': 460193,
#  'punching': 3733,
#  'suspender skirt': 9657,
#  'suspenders': 32862,
#  'tank top': 37683,
#  'accidental exposure': 623,
#  'accidental pervert': 115,
#  'assisted exposure': 1140,
#  'black eyes': 81094,
#  'blouse': 24664,
#  'bra': 91428,
#  'clothes pull': 14660,
#  'hakama': 19870,
#  'hakama pants': 908,
#  'hakama short skirt': 6024,
#  'hakama skirt': 17652,
#  'japanese clothes': 177085,
#  'miko': 9843,
#  'open clothes': 172795,
#  'open shirt': 30862,
#  'pants pull': 1481,
#  'pantsing': 81,
#  "pulling another's clothes": 121,
#  'red hakama': 5899,
#  'tripping': 1232,
#  '^^^': 23045,
#  'blush stickers': 34220,
#  'cat': 33416,
#  'crossed arms': 38165,
#  'food in mouth': 8392,
#  'spoken blush': 2755,
#  'tears': 77866,
#  'hand on own chest': 28233,
#  'parasol': 7299,
#  'railing': 9696,
#  'solo focus': 48193,
#  'triangle mouth': 6069,
#  'umbrella': 47661,
#  'wading': 21080,
#  'anatomy': 94,
#  'bad anatomy': 4482,
#  'skeleton': 4173,
#  'x-ray': 585,
#  'black gloves': 182875,
#  'boots': 232072,
#  'pantyshot': 39686,
#  'skull earrings': 1303,
#  'strapless': 90739,
#  'tube top': 10551,
#  '5girls': 30326,
#  'basketball': 1656,
#  'basketball (object)': 1796,
#  'buruma': 16617,
#  'from behind': 83694,
#  'gym uniform': 16584,
#  'head out of frame': 5904,
#  'looking back': 113737,
#  'low twintails': 45785,
#  'running': 12791,
#  'bag': 100858,
#  'bench': 7286,
#  'cover': 26244,
#  'dvd cover': 614,
#  'eating': 36731,
#  'expressionless': 41818,
#  'in-universe location': 174,
#  'looking away': 37354,
#  'looking up': 26168,
#  'onomichi (city)': 7,
#  'plastic bag': 1563,
#  'popsicle': 14534,
#  'river': 2835,
#  'spring onion': 2106,
#  'unworn shoes': 5873,
#  'unworn socks': 836,
#  '1980s (style)': 2156,
#  'alien': 2052,
#  'armor': 102223,
#  'bleeding': 2365,
#  'blood': 59624,
#  'blood drip': 372,
#  'blood in hair': 861,
#  'blood on clothes': 9418,
#  'broken glass': 1686,
#  'bruise': 3518,
#  'cable': 6583,
#  'corpse': 1473,
#  'fake screenshot': 3409,
#  'gameplay mechanics': 5175,
#  'glass': 8173,
#  'gun': 74698,
#  'helmet': 29027,
#  'hose': 3249,
#  'injury': 12891,
#  'mecha': 10065,
#  'monster': 10572,
#  'pain': 767,
#  'power armor': 2108,
#  'realistic': 8455,
#  'robot': 17929,
#  'science fiction': 11650,
#  'tube': 990,
#  'unworn headwear': 16729,
#  'unworn helmet': 1793,
#  'varia suit': 355,
#  'victory': 63,
#  'animal': 40106,
#  'animal on hand': 413,
#  'bird': 44196,
#  'bird feeding': 11,
#  'bird on hand': 1223,
#  'feeding': 4348,
#  'kimono': 101185,
#  'obi': 40362,
#  'pale skin': 24698,
#  'sash': 66985,
#  'veranda': 1326,
#  '4boys': 9737,
#  'angel (evangelion)': 133,
#  'assault rifle': 9296,
#  'h&k g36': 190,
#  'multiple boys': 134958,
#  'real life insert': 2559,
#  'rifle': 23189,
#  'sun microsystems': 1,
#  'adjusting hair': 11276,
#  'animal print': 27642,
#  'aqua eyes': 78991,
#  'arm behind back': 17581,
#  'ass visible through thighs': 37051,
#  'asymmetrical hair': 14743,
#  'bow bra': 6720,
#  'breasts apart': 9110,
#  'camisole': 21782,
#  'cat print': 1378,
#  'clenched hand': 23374,
#  'clothes writing': 23381,
#  'contrapposto': 17900,
#  'cowboy shot': 264437,
#  'frilled bra': 4818,
#  'frilled panties': 4003,
#  'green bra': 1790,
#  'green panties': 2957,
#  'grey hair': 272987,
#  'grey panties': 1960,
#  'hair between eyes': 480756,
#  'hair bow': 258638,
#  'hand on own hip': 81113,
#  'head tilt': 71743,
#  'heterochromia': 49978,
#  'lace-trimmed bra': 6594,
#  'legs together': 13871,
#  'long pointy ears': 1311,
#  'lowleg panties': 2422,
#  'mature female': 7164,
#  'narrow waist': 4603,
#  'painting (object)': 2053,
#  'parted bangs': 70419,
#  'pink bra': 8402,
#  'pink panties': 14538,
#  'plant': 27094,
#  'potted plant': 7319,
#  'print panties': 2901,
#  'raised eyebrows': 9160,
#  'red bra': 4130,
#  'red panties': 5844,
#  'ribbon-trimmed bra': 299,
#  'ribbon-trimmed panties': 188,
#  'ribbon trim': 22928,
#  'rug': 1168,
#  'see-through': 68447,
#  'short hair with long locks': 19545,
#  'side-tie panties': 17252,
#  'tile floor': 4750,
#  'tiles': 6729,
#  'tress ribbon': 12379,
#  'underwear only': 26084,
#  'white bra': 14798,
#  'yellow bra': 1192,
#  '1990s (style)': 4617,
#  'arms up': 80440,
#  'dress shirt': 57536,
#  'eye contact': 17486,
#  'hairclip': 148249,
#  'hallway': 1541,
#  'leaning': 2463,
#  'looking at another': 82751,
#  'plaid': 67475,
#  'plaid skirt': 43997,
#  'school bag': 14915,
#  'sweater': 81826,
#  'sweater vest': 15845,
#  'vest': 84275,
#  'armpits': 115449,
#  'arms behind head': 21006,
#  'black pantyhose': 82159,
#  'locker': 2138,
#  'locker room': 1220,
#  'panties under pantyhose': 14032,
#  'undressing': 18732,
#  'animal ears': 514454,
#  'bloomers': 12680,
#  'rabbit ears': 115051,
#  'single shoe': 4875,
#  'striped thighhighs': 31492,
#  'bikini under clothes': 12376,
#  'grey eyes': 68516,
#  'wet': 59940,
#  'wet clothes': 21123,
#  'wet shirt': 8370,
#  'legs': 75999,
#  'lips': 67120,
#  'competition swimsuit': 19102,
#  'highleg': 58079,
#  'highleg swimsuit': 11513,
#  '2boys': 83970,
#  'bodysuit': 59689,
#  'curvy': 12151,
#  'fishnets': 30497,
#  'full moon': 21034,
#  'glowing': 44875,
#  'hand on own thigh': 5968,
#  'leather': 6268,
#  'mask': 51252,
#  'moon': 39046,
#  'ninja': 7706,
#  'shiny clothes': 13917,
#  'skin tight': 21241,
#  'white bodysuit': 5427,
#  'catfight': 159,
#  'ribbed sweater': 18981,
#  'sleeveless turtleneck': 6497,
#  'throwing': 1879,
#  ':p': 17272,
#  'happy': 31112,
#  'ice cream': 11659,
#  'innertube': 21514,
#  'swim ring': 6761,
#  'thick eyebrows': 34861,
#  'tongue': 108126,
#  'tongue out': 80383,
#  '1987': 20,
#  'basket': 8655,
#  'bicycle': 2979,
#  'bicycle basket': 473,
#  'black bow': 60282,
#  'blurry': 95873,
#  'brown footwear': 40589,
#  'dated': 78928,
#  'depth of field': 51875,
#  'mascara': 1934,
#  'pavement': 837,
#  'pushing bicycle': 9,
#  'road': 5343,
#  'satchel': 1513,
#  'shoulder bag': 11960,
#  'signature': 120475,
#  'street': 2702,
#  'vanishing point': 488,
#  'white skirt': 38803,
#  'wing collar': 30936,
#  'green-tinted eyewear': 505,
#  'green background': 14062,
#  'thigh boots': 48374,
#  'tinted eyewear': 7866,
#  'visor': 1983,
#  'white thighhighs': 97736,
#  'bell': 56137,
#  'cat ears': 125430,
#  'covering breasts': 3150,
#  'covering privates': 8959,
#  'fang': 148650,
#  'jingle bell': 20893,
#  'shiny skin': 40262,
#  'skindentation': 49689,
#  'topless': 3220,
#  'biker clothes': 1193,
#  'bikesuit': 827,
#  'black bodysuit': 10509,
#  'black bra': 30380,
#  'character name': 98517,
#  'cropped jacket': 22247,
#  'grey gloves': 4267,
#  'holding': 539523,
#  'holding helmet': 913,
#  'looking to the side': 67630,
#  'motor vehicle': 18846,
#  'motorcycle': 4471,
#  'motorcycle helmet': 752,
#  'open bodysuit': 452,
#  'open jacket': 93478,
#  'riding': 7143,
#  'speech bubble': 60671,
#  'straddling': 3168,
#  'unzipped': 7617,
#  'zipper': 18798,
#  'breastplate': 12705,
#  'bridal garter': 8926,
#  'finger in own mouth': 1081,
#  'floating hair': 60489,
#  'forehead protector': 3038,
#  'legwear garter': 1463,
#  'light': 6875,
#  'nail polish': 112242,
#  'purple nails': 10497,
#  'standing on one leg': 38558,
#  'foreshortening': 24866,
#  'outstretched arm': 31927,
#  'wavy hair': 42406,
#  'witch hat': 51491,
#  'collar': 75778,
#  'costume switch': 4162,
#  'deformed': 278,
#  'eureka (eureka seven) (cosplay)': 13,
#  'leg up': 35917,
#  'raglan sleeves': 6035,
#  'shorts': 220731,
#  'talho yuuki (cosplay)': 3,
#  'thigh strap': 71128,
#  'white footwear': 42236,
#  'blue theme': 12197,
#  'perspective': 3831,
#  'uwabaki': 3794,
#  'blood on face': 15806,
#  'blood on weapon': 3662,
#  'cloudy sky': 34259,
#  'nata (tool)': 826,
#  'ribbon-trimmed clothes': 1526,
#  'sunset': 13645,
#  'white dress': 120808,
#  'water bottle': 6220,
#  "hand on another's stomach": 643,
#  "hand on another's thigh": 866,
#  'lying': 139675,
#  'nightgown': 4242,
#  'pinky swear': 229,
#  'upside-down': 11478,
#  '4girls': 54082,
#  'bed': 31321,
#  'black panties': 54716,
#  'long legs': 12925,
#  'clothes lift': 50244,
#  'dress lift': 10152,
#  'checkered bra': 40,
#  'checkered clothes': 8359,
#  'checkered panties': 68,
#  'crotch seam': 6805,
#  'thighband pantyhose': 15906,
#  'angel': 9162,
#  'angel wings': 15082,
#  'feathered wings': 25292,
#  'halo': 79134,
#  'lifted by self': 21391,
#  'orange sailor collar': 1228,
#  'sailor dress': 14805,
#  'excalibur (fate/stay night)': 2509,
#  'genderswap': 21912,
#  'genderswap (ftm)': 3960,
#  'nature': 18973,
#  'pectorals': 33074,
#  'recursive genderswap': 202,
#  'topless male': 18122,
#  'tree': 70487,
#  'chopsticks': 10052,
#  'holding book': 16095,
#  'lion': 1200,
#  'stuffed animal': 33965,
#  'stuffed lion': 209,
#  'stuffed toy': 39349,
#  'huge bow': 781,
#  'pointing': 28298,
#  'strapless dress': 30893,
#  'yellow bow': 18296,
#  'aqua background': 3842,
#  'breast lift': 1387,
#  'lens flare': 20296,
#  'military': 59519,
#  'military uniform': 52589,
#  'pink skirt': 17417,
#  'siblings': 43308,
#  'sisters': 28609,
#  'upskirt': 14776,
#  'cape': 104490,
#  'halloween': 18108,
#  "jack-o'-lantern": 10074,
#  'kiseru': 2958,
#  'naked cape': 149,
#  'pumpkin': 6889,
#  'smoking pipe': 5144,
#  'witch': 8948,
#  "lillian girls' academy school uniform": 433,
#  'android': 9068,
#  'baton': 144,
#  'comic': 231961,
#  'magical girl': 39075,
#  'side braid': 21924,
#  'skull': 15234,
#  'cloak': 19406,
#  'garter straps': 48383,
#  'juliet sleeves': 29906,
#  'lace-trimmed legwear': 5608,
#  'large hat': 1327,
#  'puffy sleeves': 153530,
#  'riding crop': 1921,
#  'white shirt': 294776,
#  'bucket hat': 573,
#  'can': 11335,
#  'payphone': 140,
#  'phone': 38246,
#  'reading': 7533,
#  'badge': 4849,
#  'belt': 162445,
#  'button badge': 2217,
#  'cabbie hat': 8153,
#  'center opening': 12909,
#  'hat tip': 912,
#  'jumpsuit': 3242,
#  'no bra': 20624,
#  'purple panties': 4908,
#  'smiley face': 1577,
#  'anklet': 12225,
#  'belly chain': 1704,
#  'kneeling': 49594,
#  'navel piercing': 4450,
#  'piercing': 34856,
#  'shirt lift': 14955,
#  'toe ring': 583,
#  'green skirt': 26405,
#  'stunt': 10,
#  'arm up': 98684,
#  'beach': 51869,
#  'black bikini': 66150,
#  'blue one-piece swimsuit': 18677,
#  'covered navel': 75586,
#  'hat bow': 23779,
#  'holding water gun': 1382,
#  'lowleg bikini': 2667,
#  'ocean': 56346,
#  'rock': 10004,
#  'sports bikini': 1684,
#  'straw hat': 12877,
#  'sun hat': 18144,
#  'transparent': 5925,
#  'trigger discipline': 6355,
#  'water gun': 4802,
#  'blue shorts': 19836,
#  'casual': 28261,
#  'cat tail': 71499,
#  'cutoffs': 6435,
#  'denim': 35784,
#  'denim shorts': 19023,
#  'fake animal ears': 65853,
#  'micro shorts': 6825,
#  'short shorts': 86417,
#  'tail through clothes': 2334,
#  'folding fan': 11341,
#  'hand fan': 23294,
#  'holding fan': 7548,
#  'polearm': 32681,
#  'spear': 16623,
#  'twins': 11667,
#  'white hairband': 13005,
#  'blue bow': 46276,
#  'bowtie': 124258,
#  'hankaku space': 1,
#  "holding another's tail": 209,
#  'kemonomimi mode': 16551,
#  'red jacket': 21075,
#  'striped bow': 12861,
#  'striped bowtie': 3842,
#  'tail grab': 529,
#  'verone gakuin school uniform': 57,
#  'frown': 44577,
#  'handgun': 20421,
#  'holding gun': 28381,
#  'holding weapon': 117891,
#  'star (sky)': 23492,
#  'starry sky': 16279,
#  'jumping': 12421,
#  'red skirt': 51835,
#  'yellow neckerchief': 5608,
#  'hitodama': 8983,
#  'sheath': 28488,
#  'sheathed': 14423,
#  'triangular headpiece': 7131,
#  'girl sandwich': 3920,
#  'kiss': 20193,
#  'kissing cheek': 2536,
#  'sandwiched': 4666,
#  'yellow eyes': 306475,
#  'baby': 2437,
#  'wide sleeves': 119467,
#  "widow's peak": 267,
#  'aiming': 4217,
#  'aiming at viewer': 1999,
#  'blood splatter': 4254,
#  'cross': 34020,
#  'pile bunker': 132,
#  'seventh holy scripture': 57,
#  'tattoo': 52006,
#  'moe (phrase)': 87,
#  'towel': 21849,
#  'album cover': 2689,
#  'antennae': 9027,
#  'apron': 90727,
#  'brooch': 28239,
#  'clenched hands': 15123,
#  'collage': 1698,
#  'column lineup': 1386,
#  'dark-skinned female': 75999,
#  'dark skin': 101709,
#  'finger to mouth': 19126,
#  'fur-trimmed leotard': 423,
#  'fur-trimmed sleeves': 5585,
#  'fur trim': 72652,
#  'headband': 43343,
#  'impossible clothes': 14658,
#  'impossible shirt': 3155,
#  'orange thighhighs': 1109,
#  'pince-nez': 2560,
#  'pink thighhighs': 4430,
#  'robot ears': 2307,
#  'yellow thighhighs': 1240,
#  'orange headwear': 2401,
#  'scarf': 90720,
#  'sleeves past wrists': 72154,
#  'v arms': 14614,
#  'zoom layer': 10022,
#  'pink theme': 4555,
#  'reference sheet': 6774,
#  'black serafuku': 12198,
#  'blunt bangs': 113927,
#  'extra ears': 23648,
#  'hime cut': 9366,
#  'upper body': 274247,
#  'antenna hair': 31162,
#  'buckle': 20670,
#  'red shorts': 8188,
#  'lily (flower)': 4225,
#  'bowl': 12241,
#  'breast poke': 375,
#  'chest of drawers': 755,
#  'controller': 7136,
#  'cooking': 3617,
#  'holding bowl': 1884,
#  'holding chopsticks': 3121,
#  'holding spoon': 3661,
#  'kotatsu': 3283,
#  'nabe': 158,
#  'peaceful': 152,
#  'poking': 2245,
#  'remote control': 1679,
#  'spoon': 10377,
#  'steam': 12672,
#  'table': 33053,
#  'television': 4380,
#  'tissue box': 1395,
#  'blending': 328,
#  'white theme': 1787,
#  'bathroom': 2154,
#  'facing to the side': 692,
#  'night': 48264,
#  'peeking': 1229,
#  'tile wall': 1667,
#  'urinal': 70,
#  'what': 1186,
#  'cosplay photo': 611,
#  'guitar': 9269,
#  'instrument': 24902,
#  'photo (medium)': 3848,
#  'red footwear': 27235,
#  'red headwear': 19935,
#  'bespectacled': 13210,
#  'sleeves rolled up': 17937,
#  'mob cap': 34038,
#  'puddle': 1727,
#  'wet floor': 153,
#  'aura': 5982,
#  'dark aura': 868,
#  'gohei': 8898,
#  'ofuda': 12191,
#  'forest': 13805,
#  'landscape': 1374,
#  'scenery': 9319,
#  'surreal': 1709,
#  '\\m/': 4456,
#  'cuffs': 11840,
#  'nakahara komugi (cosplay)': 14,
#  'nurse': 7552,
#  'nurse cap': 10283,
#  'rabbit tail': 33408,
#  'tool kit': 39,
#  'analog clock': 616,
#  'bat (animal)': 7364,
#  'blue background': 43575,
#  'cake': 15766,
#  'cake slice': 2481,
#  'clock': 8903,
#  'clock tower': 901,
#  'comic sans': 131,
#  'english text': 75891,
#  'fork': 9973,
#  'happy halloween': 2369,
#  'night sky': 23064,
#  'strawberry shortcake': 1232,
#  'tower': 2537,
#  'white bloomers': 3386,
#  ':3': 45809,
#  'vampire': 6937,
#  'white shorts': 16787,
#  'nude': 16067,
#  ':q': 12870,
#  'border': 37790,
#  'fur-trimmed jacket': 9838,
#  'gradient': 2664,
#  'hair over shoulder': 21037,
#  'heart': 202246,
#  'heart necklace': 3005,
#  'high heel boots': 20194,
#  'high heels': 104601,
#  'hood': 118945,
#  'hood down': 32672,
#  'hoodie': 53266,
#  'jeans': 13470,
#  'knee boots': 36636,
#  'leather jacket': 3126,
#  'leg lift': 4701,
#  'open hoodie': 3726,
#  'orange eyes': 69404,
#  'pendant': 19604,
#  'shadow': 48073,
#  'spiked hair': 24242,
#  'beachball': 11189,
#  '3boys': 20530,
#  ...}

# %%
# remove too few tags (less than 100)
general_general_tag_counts = {
    k: v for k, v in general_general_tag_counts.items() if v >= 100
}
general_sensitive_tag_counts = {
    k: v for k, v in general_sensitive_tag_counts.items() if v >= 100
}
general_questionable_tag_counts = {
    k: v for k, v in general_questionable_tag_counts.items() if v >= 100
}
general_explicit_tag_counts = {
    k: v for k, v in general_explicit_tag_counts.items() if v >= 100
}

# %%
general_sensitive_tag_counts
# Out:
# {'1girl': 2740350,
#  ':d': 264919,
#  'artist name': 130379,
#  'barefoot': 164808,
#  'black hair': 629488,
#  'black skirt': 127145,
#  'brown eyes': 400564,
#  'butterfly sitting': 540,
#  'classroom': 6144,
#  'copyright notice': 3932,
#  'desk': 15274,
#  'feet': 76312,
#  'hairband': 220247,
#  'indoors': 113642,
#  'knees apart feet together': 735,
#  'long hair': 1996089,
#  'looking at viewer': 1502503,
#  'on desk': 2499,
#  'open mouth': 952020,
#  'pleated skirt': 237969,
#  'school desk': 6454,
#  'school uniform': 358545,
#  'serafuku': 151347,
#  'short sleeves': 267053,
#  'sitting': 452256,
#  'sitting on desk': 1705,
#  'skirt': 768453,
#  'smile': 1328998,
#  'solo': 2408602,
#  'window': 53248,
#  'black leotard': 37189,
#  'blue eyes': 802114,
#  'breasts': 1499060,
#  'bustier': 3250,
#  'cleavage': 628136,
#  'corset': 21700,
#  'demon girl': 33470,
#  'gothic': 2313,
#  'green hair': 180497,
#  'head wings': 27840,
#  'huge breasts': 51766,
#  'jewelry': 467775,
#  'lace': 18503,
#  'leotard': 113475,
#  'lingerie': 21044,
#  'necklace': 117862,
#  'underwear': 308847,
#  'wings': 208627,
#  '1boy': 358662,
#  'ahoge': 280685,
#  'ass': 183237,
#  'bandeau': 13589,
#  'bikini': 283656,
#  'blonde hair': 705098,
#  'blush': 1171660,
#  'caustics': 1515,
#  'couple': 29906,
#  'green eyes': 374661,
#  'hetero': 36895,
#  'nervous': 3829,
#  'official alternate costume': 130775,
#  'partially submerged': 15840,
#  'pool': 10819,
#  'pool ladder': 1912,
#  'poolside': 4955,
#  'ribbon': 524951,
#  'sweatdrop': 90142,
#  'swimming': 2638,
#  'swimsuit': 376788,
#  'teaching': 135,
#  'water': 113515,
#  'white bikini': 53539,
#  'blue hair': 372337,
#  'braid': 288402,
#  'hair over one eye': 99299,
#  'long sleeves': 603494,
#  'oekaki': 8021,
#  'pajamas': 11911,
#  'parted lips': 217065,
#  'sweat': 118109,
#  'you gonna get raped': 2380,
#  '6+girls': 42419,
#  'breast press': 14021,
#  'brown hair': 664286,
#  'child': 21656,
#  'crossover': 27473,
#  'dyed bangs': 1186,
#  'hair slicked back': 3988,
#  'half updo': 16768,
#  'large breasts': 682881,
#  'midriff': 197022,
#  'multicolored hair': 252007,
#  'multiple girls': 711861,
#  'name tag': 11103,
#  'navel': 469962,
#  'one-piece swimsuit': 83942,
#  'red hair': 223246,
#  'retro artstyle': 7825,
#  'school swimsuit': 40330,
#  'slingshot swimsuit': 1678,
#  'sunglasses': 43301,
#  'symmetrical docking': 3134,
#  'bat wings': 32782,
#  'bracelet': 97299,
#  'closed mouth': 440989,
#  'demon tail': 24456,
#  'demon wings': 17078,
#  'earrings': 235906,
#  'elbow gloves': 154819,
#  'gloves': 629441,
#  'half-closed eyes': 26255,
#  'miniskirt': 137956,
#  'pencil skirt': 20095,
#  'pointy ears': 154842,
#  'red background': 21078,
#  'red eyes': 606928,
#  'red theme': 4741,
#  'tail': 344109,
#  'twintails': 424156,
#  'flat chest': 51084,
#  'forehead': 19535,
#  'goggles': 29367,
#  'goggles on head': 16924,
#  'grin': 102424,
#  'hands': 11836,
#  'one eye closed': 197636,
#  'shouting': 3423,
#  'swim cap': 832,
#  'watermark': 39120,
#  '^_^': 43953,
#  'aqua hair': 51140,
#  'beret': 43475,
#  'black neckerchief': 5535,
#  'black socks': 31894,
#  'black thighhighs': 152066,
#  'blazer': 32954,
#  'blue-framed eyewear': 1901,
#  'blue jacket': 29848,
#  'blue pants': 9115,
#  'blue sky': 91955,
#  'blue socks': 2705,
#  'brown headwear': 9479,
#  'brown pantyhose': 19420,
#  'brown socks': 773,
#  'building': 22570,
#  'buttons': 47175,
#  'closed eyes': 261575,
#  'cloud': 141979,
#  'curly hair': 14350,
#  'day': 173250,
#  'double-breasted': 8840,
#  'drill hair': 41437,
#  'everyone': 7966,
#  'faceless': 8864,
#  'faceless male': 5348,
#  'facing viewer': 18614,
#  'feet out of frame': 58215,
#  'glasses': 159633,
#  'group picture': 1005,
#  'hair intakes': 43160,
#  'hair ribbon': 297881,
#  'hands on own hips': 15069,
#  'harem': 755,
#  'hat': 579285,
#  'hug': 56267,
#  'jacket': 358215,
#  'kneehighs': 59798,
#  'lineup': 1928,
#  'looking over eyewear': 1814,
#  'loose socks': 4372,
#  'neckerchief': 66210,
#  'necktie': 181428,
#  'orange hair': 97527,
#  'outdoors': 229928,
#  'over-rim eyewear': 1623,
#  'pants': 139793,
#  'pantyhose': 269369,
#  'parted hair': 1342,
#  'pink-framed eyewear': 1642,
#  'pink hair': 290219,
#  'ponytail': 287316,
#  'pregnant': 1356,
#  'purple eyes': 362318,
#  'purple hair': 278582,
#  'red sailor collar': 2432,
#  'sailor collar': 102032,
#  'school': 2131,
#  'semi-rimless eyewear': 20207,
#  'shirt': 655560,
#  'short hair': 986323,
#  'short twintails': 26502,
#  'sky': 202680,
#  'socks': 152648,
#  'teacher': 2210,
#  'thighhighs': 584048,
#  'twin drills': 21588,
#  'white socks': 33607,
#  'yellow jacket': 7343,
#  'yellow shirt': 11604,
#  'zettai ryouiki': 90751,
#  '2girls': 462455,
#  'front-tie top': 28659,
#  'hug from behind': 12305,
#  'lotion': 1131,
#  'pink eyes': 115176,
#  'side-tie bikini bottom': 56767,
#  'standing': 401770,
#  'sunscreen': 823,
#  'thigh gap': 38339,
#  'twin braids': 85190,
#  'very long hair': 464982,
#  'yuri': 76897,
#  'bandages': 43559,
#  'bare shoulders': 548519,
#  'choker': 193654,
#  'fingerless gloves': 125703,
#  'katana': 37141,
#  'sarashi': 15226,
#  'sword': 150176,
#  'torn clothes': 47315,
#  'weapon': 321117,
#  'bare legs': 77597,
#  'bra strap': 4262,
#  'cigarette': 13425,
#  'curtains': 26404,
#  'elf': 22415,
#  'orange sky': 1970,
#  'smoking': 9628,
#  't-shirt': 27231,
#  'alternate hairstyle': 54742,
#  'ball': 22486,
#  'bike shorts': 28350,
#  'cleats': 197,
#  'crop top': 108552,
#  'crown': 31459,
#  'eyelashes': 61321,
#  'flipped hair': 8328,
#  'full body': 338952,
#  'gem': 27664,
#  'hair tie': 10438,
#  'hair up': 6398,
#  'high ponytail': 33497,
#  'legs apart': 15449,
#  'light smile': 32752,
#  'lipstick': 26540,
#  'makeup': 50364,
#  'pink lips': 12105,
#  'pink socks': 980,
#  'playing sports': 355,
#  'shoes': 192524,
#  'sidelocks': 251717,
#  'simple background': 741986,
#  'sketch': 70266,
#  'sneakers': 27911,
#  'soccer': 939,
#  'soccer ball': 1792,
#  'soccer uniform': 3017,
#  'sphere earrings': 524,
#  'sportswear': 12703,
#  'telstar': 681,
#  'turtleneck': 48444,
#  'uniform': 88788,
#  'white background': 622143,
#  'white gloves': 134154,
#  'bare arms': 84645,
#  'china dress': 30102,
#  'chinese clothes': 48619,
#  'cleavage cutout': 53949,
#  'clothing cutout': 87228,
#  'cosplay': 69390,
#  'covered nipples': 29760,
#  'dress': 637551,
#  'facial mark': 40955,
#  'forehead mark': 10423,
#  'parody': 36157,
#  'pelvic curtain': 27463,
#  'sleeveless': 210622,
#  'sleeveless dress': 72523,
#  'bow': 545919,
#  'bow panties': 13136,
#  'food': 195122,
#  'food on face': 8585,
#  'groin': 58634,
#  'hair bobbles': 26695,
#  'hair ornament': 651343,
#  'no pants': 23168,
#  'nose bubble': 1049,
#  'panties': 238363,
#  'sleeping': 30752,
#  'sleepy': 4161,
#  'yellow panties': 1886,
#  'arm support': 44445,
#  'hair twirling': 2334,
#  'male focus': 188337,
#  'no shoes': 42911,
#  'otoko no ko': 19664,
#  'yokozuwari': 11682,
#  '3girls': 115616,
#  ':o': 85355,
#  'albino': 3409,
#  'arms behind back': 30584,
#  'halterneck': 61582,
#  'photo background': 2044,
#  'pink bikini': 11660,
#  'purple bikini': 9618,
#  'small breasts': 192622,
#  'striped bikini': 16874,
#  'striped clothes': 36956,
#  'tankini': 1682,
#  'vertical-striped bikini': 886,
#  'vertical-striped clothes': 3965,
#  'water slide': 283,
#  'waves': 3269,
#  'white hair': 304250,
#  'bobby socks': 4658,
#  'book': 65341,
#  'bucket': 7079,
#  'ceiling': 1471,
#  'duster': 726,
#  'dutch angle': 54182,
#  'embarrassed': 36244,
#  'flower': 292187,
#  'frills': 227670,
#  'from below': 31489,
#  'maid': 70250,
#  'mary janes': 20909,
#  'multicolored clothes': 23776,
#  'multicolored panties': 164,
#  'picture frame': 3099,
#  'rag': 319,
#  'striped panties': 15581,
#  'vase': 3046,
#  'white panties': 68260,
#  'wind': 28254,
#  'wind lift': 9170,
#  'wrist cuffs': 84176,
#  'bottle': 33116,
#  'floral print': 40458,
#  'greyscale': 207777,
#  'lace-trimmed panties': 4839,
#  'lace trim': 22448,
#  'lowleg': 7584,
#  'monochrome': 266511,
#  'print thighhighs': 2778,
#  'vertical stripes': 20020,
#  'alternate costume': 201020,
#  'enmaided': 12642,
#  'frilled thighhighs': 3832,
#  'maid headdress': 65974,
#  'leaning forward': 57478,
#  'orange bikini': 4020,
#  '3:': 3853,
#  '3;': 105,
#  'age difference': 5388,
#  'fruit': 49063,
#  'height difference': 11526,
#  'kooribata': 181,
#  'watermelon': 5366,
#  'copyright name': 55156,
#  'elbow pads': 3526,
#  'incoming attack': 979,
#  'incoming punch': 272,
#  'low-tied long hair': 17167,
#  'medium breasts': 460193,
#  'punching': 3733,
#  'suspender skirt': 9657,
#  'suspenders': 32862,
#  'tank top': 37683,
#  'accidental exposure': 623,
#  'accidental pervert': 115,
#  'assisted exposure': 1140,
#  'black eyes': 81094,
#  'blouse': 24664,
#  'bra': 91428,
#  'clothes pull': 14660,
#  'hakama': 19870,
#  'hakama pants': 908,
#  'hakama short skirt': 6024,
#  'hakama skirt': 17652,
#  'japanese clothes': 177085,
#  'miko': 9843,
#  'open clothes': 172795,
#  'open shirt': 30862,
#  'pants pull': 1481,
#  "pulling another's clothes": 121,
#  'red hakama': 5899,
#  'tripping': 1232,
#  '^^^': 23045,
#  'blush stickers': 34220,
#  'cat': 33416,
#  'crossed arms': 38165,
#  'food in mouth': 8392,
#  'spoken blush': 2755,
#  'tears': 77866,
#  'hand on own chest': 28233,
#  'parasol': 7299,
#  'railing': 9696,
#  'solo focus': 48193,
#  'triangle mouth': 6069,
#  'umbrella': 47661,
#  'wading': 21080,
#  'bad anatomy': 4482,
#  'skeleton': 4173,
#  'x-ray': 585,
#  'black gloves': 182875,
#  'boots': 232072,
#  'pantyshot': 39686,
#  'skull earrings': 1303,
#  'strapless': 90739,
#  'tube top': 10551,
#  '5girls': 30326,
#  'basketball': 1656,
#  'basketball (object)': 1796,
#  'buruma': 16617,
#  'from behind': 83694,
#  'gym uniform': 16584,
#  'head out of frame': 5904,
#  'looking back': 113737,
#  'low twintails': 45785,
#  'running': 12791,
#  'bag': 100858,
#  'bench': 7286,
#  'cover': 26244,
#  'dvd cover': 614,
#  'eating': 36731,
#  'expressionless': 41818,
#  'in-universe location': 174,
#  'looking away': 37354,
#  'looking up': 26168,
#  'plastic bag': 1563,
#  'popsicle': 14534,
#  'river': 2835,
#  'spring onion': 2106,
#  'unworn shoes': 5873,
#  'unworn socks': 836,
#  '1980s (style)': 2156,
#  'alien': 2052,
#  'armor': 102223,
#  'bleeding': 2365,
#  'blood': 59624,
#  'blood drip': 372,
#  'blood in hair': 861,
#  'blood on clothes': 9418,
#  'broken glass': 1686,
#  'bruise': 3518,
#  'cable': 6583,
#  'corpse': 1473,
#  'fake screenshot': 3409,
#  'gameplay mechanics': 5175,
#  'glass': 8173,
#  'gun': 74698,
#  'helmet': 29027,
#  'hose': 3249,
#  'injury': 12891,
#  'mecha': 10065,
#  'monster': 10572,
#  'pain': 767,
#  'power armor': 2108,
#  'realistic': 8455,
#  'robot': 17929,
#  'science fiction': 11650,
#  'tube': 990,
#  'unworn headwear': 16729,
#  'unworn helmet': 1793,
#  'varia suit': 355,
#  'animal': 40106,
#  'animal on hand': 413,
#  'bird': 44196,
#  'bird on hand': 1223,
#  'feeding': 4348,
#  'kimono': 101185,
#  'obi': 40362,
#  'pale skin': 24698,
#  'sash': 66985,
#  'veranda': 1326,
#  '4boys': 9737,
#  'angel (evangelion)': 133,
#  'assault rifle': 9296,
#  'h&k g36': 190,
#  'multiple boys': 134958,
#  'real life insert': 2559,
#  'rifle': 23189,
#  'adjusting hair': 11276,
#  'animal print': 27642,
#  'aqua eyes': 78991,
#  'arm behind back': 17581,
#  'ass visible through thighs': 37051,
#  'asymmetrical hair': 14743,
#  'bow bra': 6720,
#  'breasts apart': 9110,
#  'camisole': 21782,
#  'cat print': 1378,
#  'clenched hand': 23374,
#  'clothes writing': 23381,
#  'contrapposto': 17900,
#  'cowboy shot': 264437,
#  'frilled bra': 4818,
#  'frilled panties': 4003,
#  'green bra': 1790,
#  'green panties': 2957,
#  'grey hair': 272987,
#  'grey panties': 1960,
#  'hair between eyes': 480756,
#  'hair bow': 258638,
#  'hand on own hip': 81113,
#  'head tilt': 71743,
#  'heterochromia': 49978,
#  'lace-trimmed bra': 6594,
#  'legs together': 13871,
#  'long pointy ears': 1311,
#  'lowleg panties': 2422,
#  'mature female': 7164,
#  'narrow waist': 4603,
#  'painting (object)': 2053,
#  'parted bangs': 70419,
#  'pink bra': 8402,
#  'pink panties': 14538,
#  'plant': 27094,
#  'potted plant': 7319,
#  'print panties': 2901,
#  'raised eyebrows': 9160,
#  'red bra': 4130,
#  'red panties': 5844,
#  'ribbon-trimmed bra': 299,
#  'ribbon-trimmed panties': 188,
#  'ribbon trim': 22928,
#  'rug': 1168,
#  'see-through': 68447,
#  'short hair with long locks': 19545,
#  'side-tie panties': 17252,
#  'tile floor': 4750,
#  'tiles': 6729,
#  'tress ribbon': 12379,
#  'underwear only': 26084,
#  'white bra': 14798,
#  'yellow bra': 1192,
#  '1990s (style)': 4617,
#  'arms up': 80440,
#  'dress shirt': 57536,
#  'eye contact': 17486,
#  'hairclip': 148249,
#  'hallway': 1541,
#  'leaning': 2463,
#  'looking at another': 82751,
#  'plaid': 67475,
#  'plaid skirt': 43997,
#  'school bag': 14915,
#  'sweater': 81826,
#  'sweater vest': 15845,
#  'vest': 84275,
#  'armpits': 115449,
#  'arms behind head': 21006,
#  'black pantyhose': 82159,
#  'locker': 2138,
#  'locker room': 1220,
#  'panties under pantyhose': 14032,
#  'undressing': 18732,
#  'animal ears': 514454,
#  'bloomers': 12680,
#  'rabbit ears': 115051,
#  'single shoe': 4875,
#  'striped thighhighs': 31492,
#  'bikini under clothes': 12376,
#  'grey eyes': 68516,
#  'wet': 59940,
#  'wet clothes': 21123,
#  'wet shirt': 8370,
#  'legs': 75999,
#  'lips': 67120,
#  'competition swimsuit': 19102,
#  'highleg': 58079,
#  'highleg swimsuit': 11513,
#  '2boys': 83970,
#  'bodysuit': 59689,
#  'curvy': 12151,
#  'fishnets': 30497,
#  'full moon': 21034,
#  'glowing': 44875,
#  'hand on own thigh': 5968,
#  'leather': 6268,
#  'mask': 51252,
#  'moon': 39046,
#  'ninja': 7706,
#  'shiny clothes': 13917,
#  'skin tight': 21241,
#  'white bodysuit': 5427,
#  'catfight': 159,
#  'ribbed sweater': 18981,
#  'sleeveless turtleneck': 6497,
#  'throwing': 1879,
#  ':p': 17272,
#  'happy': 31112,
#  'ice cream': 11659,
#  'innertube': 21514,
#  'swim ring': 6761,
#  'thick eyebrows': 34861,
#  'tongue': 108126,
#  'tongue out': 80383,
#  'basket': 8655,
#  'bicycle': 2979,
#  'bicycle basket': 473,
#  'black bow': 60282,
#  'blurry': 95873,
#  'brown footwear': 40589,
#  'dated': 78928,
#  'depth of field': 51875,
#  'mascara': 1934,
#  'pavement': 837,
#  'road': 5343,
#  'satchel': 1513,
#  'shoulder bag': 11960,
#  'signature': 120475,
#  'street': 2702,
#  'vanishing point': 488,
#  'white skirt': 38803,
#  'wing collar': 30936,
#  'green-tinted eyewear': 505,
#  'green background': 14062,
#  'thigh boots': 48374,
#  'tinted eyewear': 7866,
#  'visor': 1983,
#  'white thighhighs': 97736,
#  'bell': 56137,
#  'cat ears': 125430,
#  'covering breasts': 3150,
#  'covering privates': 8959,
#  'fang': 148650,
#  'jingle bell': 20893,
#  'shiny skin': 40262,
#  'skindentation': 49689,
#  'topless': 3220,
#  'biker clothes': 1193,
#  'bikesuit': 827,
#  'black bodysuit': 10509,
#  'black bra': 30380,
#  'character name': 98517,
#  'cropped jacket': 22247,
#  'grey gloves': 4267,
#  'holding': 539523,
#  'holding helmet': 913,
#  'looking to the side': 67630,
#  'motor vehicle': 18846,
#  'motorcycle': 4471,
#  'motorcycle helmet': 752,
#  'open bodysuit': 452,
#  'open jacket': 93478,
#  'riding': 7143,
#  'speech bubble': 60671,
#  'straddling': 3168,
#  'unzipped': 7617,
#  'zipper': 18798,
#  'breastplate': 12705,
#  'bridal garter': 8926,
#  'finger in own mouth': 1081,
#  'floating hair': 60489,
#  'forehead protector': 3038,
#  'legwear garter': 1463,
#  'light': 6875,
#  'nail polish': 112242,
#  'purple nails': 10497,
#  'standing on one leg': 38558,
#  'foreshortening': 24866,
#  'outstretched arm': 31927,
#  'wavy hair': 42406,
#  'witch hat': 51491,
#  'collar': 75778,
#  'costume switch': 4162,
#  'deformed': 278,
#  'leg up': 35917,
#  'raglan sleeves': 6035,
#  'shorts': 220731,
#  'thigh strap': 71128,
#  'white footwear': 42236,
#  'blue theme': 12197,
#  'perspective': 3831,
#  'uwabaki': 3794,
#  'blood on face': 15806,
#  'blood on weapon': 3662,
#  'cloudy sky': 34259,
#  'nata (tool)': 826,
#  'ribbon-trimmed clothes': 1526,
#  'sunset': 13645,
#  'white dress': 120808,
#  'water bottle': 6220,
#  "hand on another's stomach": 643,
#  "hand on another's thigh": 866,
#  'lying': 139675,
#  'nightgown': 4242,
#  'pinky swear': 229,
#  'upside-down': 11478,
#  '4girls': 54082,
#  'bed': 31321,
#  'black panties': 54716,
#  'long legs': 12925,
#  'clothes lift': 50244,
#  'dress lift': 10152,
#  'checkered clothes': 8359,
#  'crotch seam': 6805,
#  'thighband pantyhose': 15906,
#  'angel': 9162,
#  'angel wings': 15082,
#  'feathered wings': 25292,
#  'halo': 79134,
#  'lifted by self': 21391,
#  'orange sailor collar': 1228,
#  'sailor dress': 14805,
#  'excalibur (fate/stay night)': 2509,
#  'genderswap': 21912,
#  'genderswap (ftm)': 3960,
#  'nature': 18973,
#  'pectorals': 33074,
#  'recursive genderswap': 202,
#  'topless male': 18122,
#  'tree': 70487,
#  'chopsticks': 10052,
#  'holding book': 16095,
#  'lion': 1200,
#  'stuffed animal': 33965,
#  'stuffed lion': 209,
#  'stuffed toy': 39349,
#  'huge bow': 781,
#  'pointing': 28298,
#  'strapless dress': 30893,
#  'yellow bow': 18296,
#  'aqua background': 3842,
#  'breast lift': 1387,
#  'lens flare': 20296,
#  'military': 59519,
#  'military uniform': 52589,
#  'pink skirt': 17417,
#  'siblings': 43308,
#  'sisters': 28609,
#  'upskirt': 14776,
#  'cape': 104490,
#  'halloween': 18108,
#  "jack-o'-lantern": 10074,
#  'kiseru': 2958,
#  'naked cape': 149,
#  'pumpkin': 6889,
#  'smoking pipe': 5144,
#  'witch': 8948,
#  "lillian girls' academy school uniform": 433,
#  'android': 9068,
#  'baton': 144,
#  'comic': 231961,
#  'magical girl': 39075,
#  'side braid': 21924,
#  'skull': 15234,
#  'cloak': 19406,
#  'garter straps': 48383,
#  'juliet sleeves': 29906,
#  'lace-trimmed legwear': 5608,
#  'large hat': 1327,
#  'puffy sleeves': 153530,
#  'riding crop': 1921,
#  'white shirt': 294776,
#  'bucket hat': 573,
#  'can': 11335,
#  'payphone': 140,
#  'phone': 38246,
#  'reading': 7533,
#  'badge': 4849,
#  'belt': 162445,
#  'button badge': 2217,
#  'cabbie hat': 8153,
#  'center opening': 12909,
#  'hat tip': 912,
#  'jumpsuit': 3242,
#  'no bra': 20624,
#  'purple panties': 4908,
#  'smiley face': 1577,
#  'anklet': 12225,
#  'belly chain': 1704,
#  'kneeling': 49594,
#  'navel piercing': 4450,
#  'piercing': 34856,
#  'shirt lift': 14955,
#  'toe ring': 583,
#  'green skirt': 26405,
#  'arm up': 98684,
#  'beach': 51869,
#  'black bikini': 66150,
#  'blue one-piece swimsuit': 18677,
#  'covered navel': 75586,
#  'hat bow': 23779,
#  'holding water gun': 1382,
#  'lowleg bikini': 2667,
#  'ocean': 56346,
#  'rock': 10004,
#  'sports bikini': 1684,
#  'straw hat': 12877,
#  'sun hat': 18144,
#  'transparent': 5925,
#  'trigger discipline': 6355,
#  'water gun': 4802,
#  'blue shorts': 19836,
#  'casual': 28261,
#  'cat tail': 71499,
#  'cutoffs': 6435,
#  'denim': 35784,
#  'denim shorts': 19023,
#  'fake animal ears': 65853,
#  'micro shorts': 6825,
#  'short shorts': 86417,
#  'tail through clothes': 2334,
#  'folding fan': 11341,
#  'hand fan': 23294,
#  'holding fan': 7548,
#  'polearm': 32681,
#  'spear': 16623,
#  'twins': 11667,
#  'white hairband': 13005,
#  'blue bow': 46276,
#  'bowtie': 124258,
#  "holding another's tail": 209,
#  'kemonomimi mode': 16551,
#  'red jacket': 21075,
#  'striped bow': 12861,
#  'striped bowtie': 3842,
#  'tail grab': 529,
#  'frown': 44577,
#  'handgun': 20421,
#  'holding gun': 28381,
#  'holding weapon': 117891,
#  'star (sky)': 23492,
#  'starry sky': 16279,
#  'jumping': 12421,
#  'red skirt': 51835,
#  'yellow neckerchief': 5608,
#  'hitodama': 8983,
#  'sheath': 28488,
#  'sheathed': 14423,
#  'triangular headpiece': 7131,
#  'girl sandwich': 3920,
#  'kiss': 20193,
#  'kissing cheek': 2536,
#  'sandwiched': 4666,
#  'yellow eyes': 306475,
#  'baby': 2437,
#  'wide sleeves': 119467,
#  "widow's peak": 267,
#  'aiming': 4217,
#  'aiming at viewer': 1999,
#  'blood splatter': 4254,
#  'cross': 34020,
#  'pile bunker': 132,
#  'tattoo': 52006,
#  'towel': 21849,
#  'album cover': 2689,
#  'antennae': 9027,
#  'apron': 90727,
#  'brooch': 28239,
#  'clenched hands': 15123,
#  'collage': 1698,
#  'column lineup': 1386,
#  'dark-skinned female': 75999,
#  'dark skin': 101709,
#  'finger to mouth': 19126,
#  'fur-trimmed leotard': 423,
#  'fur-trimmed sleeves': 5585,
#  'fur trim': 72652,
#  'headband': 43343,
#  'impossible clothes': 14658,
#  'impossible shirt': 3155,
#  'orange thighhighs': 1109,
#  'pince-nez': 2560,
#  'pink thighhighs': 4430,
#  'robot ears': 2307,
#  'yellow thighhighs': 1240,
#  'orange headwear': 2401,
#  'scarf': 90720,
#  'sleeves past wrists': 72154,
#  'v arms': 14614,
#  'zoom layer': 10022,
#  'pink theme': 4555,
#  'reference sheet': 6774,
#  'black serafuku': 12198,
#  'blunt bangs': 113927,
#  'extra ears': 23648,
#  'hime cut': 9366,
#  'upper body': 274247,
#  'antenna hair': 31162,
#  'buckle': 20670,
#  'red shorts': 8188,
#  'lily (flower)': 4225,
#  'bowl': 12241,
#  'breast poke': 375,
#  'chest of drawers': 755,
#  'controller': 7136,
#  'cooking': 3617,
#  'holding bowl': 1884,
#  'holding chopsticks': 3121,
#  'holding spoon': 3661,
#  'kotatsu': 3283,
#  'nabe': 158,
#  'peaceful': 152,
#  'poking': 2245,
#  'remote control': 1679,
#  'spoon': 10377,
#  'steam': 12672,
#  'table': 33053,
#  'television': 4380,
#  'tissue box': 1395,
#  'blending': 328,
#  'white theme': 1787,
#  'bathroom': 2154,
#  'facing to the side': 692,
#  'night': 48264,
#  'peeking': 1229,
#  'tile wall': 1667,
#  'what': 1186,
#  'cosplay photo': 611,
#  'guitar': 9269,
#  'instrument': 24902,
#  'photo (medium)': 3848,
#  'red footwear': 27235,
#  'red headwear': 19935,
#  'bespectacled': 13210,
#  'sleeves rolled up': 17937,
#  'mob cap': 34038,
#  'puddle': 1727,
#  'wet floor': 153,
#  'aura': 5982,
#  'dark aura': 868,
#  'gohei': 8898,
#  'ofuda': 12191,
#  'forest': 13805,
#  'landscape': 1374,
#  'scenery': 9319,
#  'surreal': 1709,
#  '\\m/': 4456,
#  'cuffs': 11840,
#  'nurse': 7552,
#  'nurse cap': 10283,
#  'rabbit tail': 33408,
#  'analog clock': 616,
#  'bat (animal)': 7364,
#  'blue background': 43575,
#  'cake': 15766,
#  'cake slice': 2481,
#  'clock': 8903,
#  'clock tower': 901,
#  'comic sans': 131,
#  'english text': 75891,
#  'fork': 9973,
#  'happy halloween': 2369,
#  'night sky': 23064,
#  'strawberry shortcake': 1232,
#  'tower': 2537,
#  'white bloomers': 3386,
#  ':3': 45809,
#  'vampire': 6937,
#  'white shorts': 16787,
#  'nude': 16067,
#  ':q': 12870,
#  'border': 37790,
#  'fur-trimmed jacket': 9838,
#  'gradient': 2664,
#  'hair over shoulder': 21037,
#  'heart': 202246,
#  'heart necklace': 3005,
#  'high heel boots': 20194,
#  'high heels': 104601,
#  'hood': 118945,
#  'hood down': 32672,
#  'hoodie': 53266,
#  'jeans': 13470,
#  'knee boots': 36636,
#  'leather jacket': 3126,
#  'leg lift': 4701,
#  'open hoodie': 3726,
#  'orange eyes': 69404,
#  'pendant': 19604,
#  'shadow': 48073,
#  'spiked hair': 24242,
#  'beachball': 11189,
#  '3boys': 20530,
#  'blizzard': 138,
#  'snow': 16834,
#  'snowing': 10260,
#  'winter': 3763,
#  'sunflower': 10329,
#  'yellow flower': 11243,
#  'arm strap': 8259,
#  'bust chart': 211,
#  'casual one-piece swimsuit': 9219,
#  'frilled bikini': 24684,
#  'from side': 82402,
#  'front-tie bikini top': 16098,
#  'pouch': 15723,
#  'print swimsuit': 511,
#  'profile': 49099,
#  'quad tails': 1623,
#  'sideboob': 61798,
#  'swept bangs': 50254,
#  'underboob': 46768,
#  'dog': 10754,
#  'ferret': 503,
#  'frog': 7414,
#  'puppet': 1804,
#  ...}

# %%
for s_tag in general_sensitive_tags.copy():
    if s_tag not in general_sensitive_tag_counts:
        general_sensitive_tags.remove(s_tag)
    elif s_tag in general_general_tags:
        general_sensitive_tags.remove(s_tag)

general_sensitive_tags
# Out:
# {'adhesive bra',
#  'adjusting bra',
#  'adjusting leotard',
#  'adjusting panties',
#  'adjusting swimsuit',
#  'alternate color school swimsuit',
#  'aqua bra',
#  'aqua panties',
#  'aqua sarong',
#  'arena (company)',
#  'areolae',
#  'armpit focus',
#  'artificial vagina',
#  'artoria pendragon (lancer alter) (royal icing) (fate) (cosplay)',
#  'ass grab',
#  'ass support',
#  'backboob',
#  'bdsm',
#  'bikini bottom pull',
#  'bikini bridge',
#  'bikini day',
#  'bikini in mouth',
#  'bikini pull',
#  'bikini tan',
#  'bikini top lift',
#  'bikini tug',
#  'bikini under shorts',
#  'black bikini bottom',
#  'black fundoshi',
#  'bondage',
#  'bow swimsuit',
#  'bra lift',
#  'bra pull',
#  'breast poke',
#  'bridal lingerie',
#  'bridgeless bra',
#  'bulge',
#  'bursting ass',
#  'buruma pull',
#  'bust cup',
#  'c-string',
#  'cameltoe',
#  'camisole lift',
#  'cammy white (cosplay)',
#  'camouflage bikini',
#  'card between breasts',
#  'cat ear panties',
#  'cinderella bust',
#  'cleavage reach',
#  'condom',
#  'condom in mouth',
#  'condom packet strip',
#  'condom wrapper',
#  'cross-laced bikini',
#  'cross-laced one-piece swimsuit',
#  'cunnilingus gesture',
#  'cutie panther',
#  'deva battle suit',
#  'downpants',
#  'embroidered bra',
#  'embroidered panties',
#  'eyepatch bikini',
#  'fat mons',
#  'fellatio gesture',
#  'florence nightingale (trick or treatment) (fate) (cosplay)',
#  'frilled bikini top',
#  'front-hook bra',
#  'fuck-me shirt',
#  'g-string',
#  'german flag bikini',
#  'gigantic breasts',
#  'gold leotard',
#  "grabbing another's breast",
#  'grabbing own ass',
#  'grey bikini',
#  'groping',
#  'gusset',
#  'handjob gesture',
#  'hands on ass',
#  'he wants to order (meme)',
#  'heart panties',
#  'high-waist sideboob',
#  'hitachi magic wand',
#  'holding condom',
#  'implied masturbation',
#  'impossible swimsuit',
#  'innerboob',
#  'jockstrap',
#  'kittysuit',
#  'lace panties',
#  'lace-trimmed bikini',
#  'lace-trimmed garter belt',
#  'latex leotard',
#  'leotard pull',
#  'loli',
#  'lowleg bikini',
#  'lowleg panties',
#  'maid leotard',
#  'male pubic hair',
#  'micro bra',
#  'micro panties',
#  'mismatched bikini',
#  'mizu happi',
#  'moe2021',
#  'mole on ass',
#  'muchourin',
#  'multi-strapped bikini',
#  'multi-strapped bikini bottom',
#  'multi-strapped bikini top',
#  'multi-strapped panties',
#  'multicolored bra',
#  'multicolored panties',
#  'naked kimono',
#  'naked tabard',
#  'navel focus',
#  'nearly naked apron',
#  'o-ring panties',
#  'o-ring swimsuit',
#  'object in swimsuit',
#  'off-shoulder one-piece swimsuit',
#  'open bikini',
#  'open bra',
#  'oral invitation',
#  'outseal',
#  'paizuri invitation',
#  'panties around one leg',
#  'panties over garter belt',
#  'panties over pantyhose',
#  'panties under bike shorts',
#  'panties under shorts',
#  'partially visible vulva',
#  'plaid panties',
#  'presenting',
#  'presenting removed panties',
#  'pubic hair',
#  'pubic hair peek',
#  'purple sports bra',
#  'racerback',
#  'rainbow bikini',
#  'removing bra',
#  'ribbed panties',
#  'ribbon between breasts',
#  'ribbon bra',
#  'ribbon panties',
#  'ribbon-trimmed bra',
#  'ribbon-trimmed swimsuit',
#  'ryona',
#  'sarong lift',
#  'satin bra',
#  'satin panties',
#  'school swimsuit flap',
#  'self exposure',
#  'sex toy',
#  'sexually suggestive',
#  'shiny swimsuit',
#  'shota',
#  'side-tie bottom',
#  'side-tie swimsuit',
#  'silver bikini',
#  'skirt around one leg',
#  'skirt caught on object',
#  'sling bikini top',
#  'speedo (company)',
#  'spread armpit',
#  'spread navel',
#  'strapless bottom',
#  'striped sports bra',
#  'stripper',
#  'suggestive fluid',
#  'swimsuit tug',
#  'swimwear (module)',
#  'taut swimsuit',
#  'torn bikini',
#  'torn bra',
#  'torn panties',
#  'torn swimsuit',
#  'translucent bunnysuit',
#  'trefoil',
#  'two-tone one-piece swimsuit',
#  'underboob',
#  'untied bikini',
#  'untied panties',
#  'unworn bikini bottom',
#  'unworn sarong',
#  'unworn swim cap',
#  'veiny breasts',
#  'vertical-striped bra',
#  'vertical-striped one-piece swimsuit',
#  'vertical-striped panties',
#  'vibrator',
#  'wakamezake',
#  'wedgie',
#  'wet panties',
#  'wet swimsuit',
#  'whale tail (clothing)',
#  'wiffle gag',
#  'yamakasa',
#  'yoko littner (cosplay)'}

# %%
for q_tag in general_questionable_tags.copy():
    if q_tag not in general_questionable_tag_counts:
        general_questionable_tags.remove(q_tag)
    elif q_tag in general_general_tags:
        general_questionable_tags.remove(q_tag)
    elif q_tag in general_sensitive_tags:
        general_questionable_tags.remove(q_tag)

general_questionable_tags
# Out:
# {'69',
#  'anal beads',
#  'anus peek',
#  'applying sunscreen',
#  'ass on glass',
#  'ass tattoo',
#  'backless panties',
#  'backwards virgin killer sweater',
#  'bandaid on pussy',
#  'between labia',
#  'bike shorts pull',
#  'bikini around one leg',
#  'bikini bottom aside',
#  'black pasties',
#  'black pubic hair',
#  'blonde pubic hair',
#  'bloomers pull',
#  'blue nipples',
#  'blue pubic hair',
#  'bound thighs',
#  'box tie',
#  'breast milk',
#  'breast slip',
#  'brown pubic hair',
#  'bulge lift',
#  'bulge press',
#  'bulge to ass',
#  'bulges touching',
#  'butt plug',
#  'censored nipples',
#  'chastity belt',
#  'cleave gag',
#  'cleft of venus',
#  'clitoris piercing',
#  'clitoris slip',
#  'clothed female nude female',
#  'clothed masturbation',
#  'clothed sex',
#  'colored nipples',
#  'colored pubic hair',
#  'condom in clothes',
#  'consensual tentacles',
#  'convenient head',
#  'covered anus',
#  'covered clitoris',
#  'covered penis',
#  'covered piercing',
#  "covering another's breasts",
#  'covering nipples',
#  'covering one breast',
#  'cross pasties',
#  'crotch rope',
#  'crotch rub',
#  'crotchless panties',
#  'cum',
#  'cunnilingus',
#  'cupless bikini',
#  'cupless bra',
#  'dark areolae',
#  'dark nipples',
#  'dildo',
#  'doggystyle',
#  'dress in mouth',
#  'dry humping',
#  'egg vibrator',
#  'erect clitoris',
#  'erection',
#  'erection under clothes',
#  'ero guro',
#  'excessive pubic hair',
#  'extended downblouse',
#  'face in ass',
#  'fellatio',
#  'female masturbation',
#  'female pubic hair',
#  'fff threesome',
#  'fingering',
#  'fingering through clothes',
#  'fingering through panties',
#  'flaccid',
#  'floating breasts',
#  'footjob',
#  'frogtie',
#  'frontal wedgie',
#  'frontless outfit',
#  'frottage',
#  'futa with female',
#  'futanari',
#  'gag harness',
#  'glands of montgomery',
#  "grabbing another's ass",
#  'grabbing own thigh',
#  'green pubic hair',
#  'grey pubic hair',
#  'guided breast grab',
#  'guro',
#  'hair over crotch',
#  'hand in panties',
#  'hand under swimsuit',
#  'handjob',
#  'happy sex',
#  'heart maebari',
#  'heart pasties',
#  'hogtie',
#  'holding sex toy',
#  'huge nipples',
#  'human dog',
#  "i've never seen a guy recreate this successfully tbh (meme)",
#  'imminent anal',
#  'imminent fellatio',
#  'implied anal',
#  'implied cunnilingus',
#  'implied fingering',
#  'implied handjob',
#  'implied paizuri',
#  'impossible towel',
#  'inverted nipples',
#  'just shoes',
#  'lactation through clothes',
#  'large areolae',
#  'large bulge',
#  'leotard aside',
#  'licking armpit',
#  'licking breast',
#  'licking foot',
#  'licking navel',
#  'licking neck',
#  'licking nipple',
#  'linked collar',
#  'lube',
#  'male lactation',
#  'male masturbation',
#  'male swimwear challenge',
#  'masturbation',
#  'masturbation through clothes',
#  'mismatched pubic hair',
#  'missionary',
#  'mole on crotch',
#  'mole on pussy',
#  'molestation',
#  'monoglove',
#  'naked belt',
#  'naked capelet',
#  'naked cardigan',
#  'naked chocolate',
#  'naked dogeza',
#  'naked necktie',
#  'naked paint',
#  'naked suspenders',
#  'nipple bar',
#  'nipple chain',
#  'nipple clamps',
#  'nipple cutout',
#  'nipple jewelry',
#  'nipple press',
#  'nipple pull',
#  'nipple rings',
#  'nipple rub',
#  'nipple stimulation',
#  'nipple tassels',
#  'nipple tweak',
#  'nipple-to-nipple',
#  'nude modeling',
#  'nudist',
#  'ofuda on nipples',
#  'ofuda on pussy',
#  'one breast out',
#  'open towel',
#  'oppai challenge',
#  'paizuri',
#  'pajamas pull',
#  'panties around ankles',
#  'panties aside',
#  'pants around one leg',
#  'pantsing',
#  'panty tug',
#  'pearl thong',
#  'pee stain',
#  'penis',
#  'penis in panties',
#  'penis peek',
#  'pink pubic hair',
#  'precum',
#  'predicament bondage',
#  'projectile lactation',
#  'public nudity',
#  'purple pubic hair',
#  'pussy',
#  'pussy cutout',
#  'pussy juice',
#  'pussy juice drip through clothes',
#  'pussy juice puddle',
#  'pussy juice stain',
#  'pussy juice trail',
#  'pussy peek',
#  'pussy piercing',
#  'rape',
#  'remote control vibrator',
#  'removing pasties',
#  'ring gag',
#  'see-through bra',
#  'see-through panties',
#  'self breast sucking',
#  'sex',
#  'sex from behind',
#  'shaped pubic hair',
#  'shelf bra',
#  'shibari under clothes',
#  'shorts around one leg',
#  'simulated fellatio',
#  'simulated footjob',
#  'simulated paizuri',
#  'skirt around ankles',
#  'small nipples',
#  'soap censor',
#  'sparse pubic hair',
#  'sports bra lift',
#  'spread ass',
#  'spread pussy',
#  'spread pussy under clothes',
#  'stained panties',
#  'star censor',
#  'stealth sex',
#  'strap-on',
#  'swimsuit aside',
#  'swimsuit lift',
#  'table humping',
#  'tape on nipples',
#  'tape on pussy',
#  'testicle peek',
#  'text censor',
#  'thigh straddling',
#  'through clothes',
#  'top pull',
#  'torso flash',
#  'tribadism',
#  'tweaking own nipple',
#  'undone bra',
#  'undone sarashi',
#  'used condom',
#  'vaginal',
#  'vibrator in thigh strap',
#  'vibrator in thighhighs',
#  'vibrator on nipple',
#  'vibrator under clothes',
#  'vibrator under panties',
#  'wet male underwear',
#  'wireless sex toy controller',
#  'zenra'}

# %%
for e_tag in general_explicit_tags.copy():
    if e_tag not in general_explicit_tag_counts:
        general_explicit_tags.remove(e_tag)
    elif e_tag in general_general_tags:
        general_explicit_tags.remove(e_tag)
    elif e_tag in general_sensitive_tags:
        general_explicit_tags.remove(e_tag)
    elif e_tag in general_questionable_tags:
        general_explicit_tags.remove(e_tag)

general_explicit_tags
# Out:
# {'after anal',
#  'after cunnilingus',
#  'after ejaculation',
#  'after fingering',
#  'after footjob',
#  'after handjob',
#  'after insertion',
#  'after masturbation',
#  'after paizuri',
#  'after rape',
#  'after vaginal',
#  'amazon position',
#  'anal ball wear',
#  'anal fingering',
#  'anal fisting',
#  'anal fluid',
#  'anal hair',
#  'anal hook',
#  'anilingus',
#  'animal penis',
#  'anus cutout',
#  'armbinder',
#  'armpit sex',
#  'ass freckles',
#  'ass hair',
#  'ass-to-ass penetration',
#  'assisted masturbation',
#  'autoarousal',
#  'autofacial',
#  'autofellatio',
#  'autopaizuri',
#  'bad vulva',
#  'ball bra',
#  'ball busting',
#  'bikini top aside',
#  'blue plate special (sex)',
#  'bootjob',
#  'bouncing ass',
#  'bouncing penis',
#  'breast pump',
#  'broken condom',
#  'bukkake',
#  'buruma around one leg',
#  'buruma aside',
#  'buttjob',
#  'buttjob over clothes',
#  'caressing testicles',
#  'catheter',
#  'cbt',
#  'censored with cum',
#  'cervical penetration',
#  'cervix',
#  'chastity cage',
#  'clitoral hood',
#  'clitoral stimulation',
#  'clitoral stimulation through clothing',
#  'clitoris ring',
#  'clitoris tweak',
#  'clothed male nude male',
#  'clothes gag',
#  'cock ring',
#  'colored condom',
#  'condom belt',
#  'condom left inside',
#  'condom on penis',
#  'cooperative fellatio',
#  'cooperative footjob',
#  'cooperative grinding',
#  'cooperative handjob',
#  'cooperative paizuri',
#  'covered penetration',
#  'crotchless leotard',
#  'crotchless swimsuit',
#  'cuddling handjob',
#  'cum bath',
#  'cum bubble',
#  'cum in ass',
#  'cum in bowl',
#  'cum in clothes',
#  'cum in container',
#  'cum in cup',
#  'cum in footwear',
#  'cum in mouth',
#  'cum in navel',
#  'cum in nose',
#  'cum in panties',
#  'cum in pussy',
#  'cum in throat',
#  'cum inflation',
#  'cum on armpits',
#  'cum on ass',
#  'cum on back',
#  'cum on body',
#  'cum on breasts',
#  'cum on chest',
#  'cum on clothes',
#  'cum on eyewear',
#  'cum on feet',
#  'cum on fingers',
#  'cum on floor',
#  'cum on food',
#  'cum on gloves',
#  'cum on hair',
#  'cum on hands',
#  'cum on headwear',
#  'cum on legs',
#  'cum on lips',
#  'cum on male',
#  'cum on object',
#  'cum on pectorals',
#  'cum on penis',
#  'cum on pussy',
#  'cum on self',
#  'cum on sheets',
#  'cum on skirt',
#  'cum on stomach',
#  'cum on tail',
#  'cum on tongue',
#  'cum overflow',
#  'cum pool',
#  'cum string',
#  'cum swap',
#  'cum through clothes',
#  'cumdrip',
#  'cumdrip onto panties',
#  'cumdump',
#  'cunnilingus through clothes',
#  'cuntboy',
#  'dark labia',
#  'dark penis',
#  'deep penetration',
#  'deepthroat',
#  'defloration',
#  'dilation belt',
#  'dilation tape',
#  'dildo gag',
#  'dildo harness',
#  'dildo reveal',
#  'dildo riding',
#  'dildo under clothes',
#  'dildo under panties',
#  'disembodied penis',
#  'dog penis',
#  'double anal',
#  'double breast sucking',
#  'double dildo',
#  'double handjob',
#  'double insertion',
#  'double penetration',
#  'double vaginal',
#  'dress aside',
#  'ear sex',
#  'egg implantation',
#  'ejaculating while penetrated',
#  'ejaculation',
#  'ejaculation under clothes',
#  'electrostimulation',
#  'emotionless sex',
#  'excessive cum',
#  'excessive pussy juice',
#  'extra penises',
#  'extreme gaping',
#  'facial',
#  'fallopian tubes',
#  'fellatio under mask',
#  'female ejaculation',
#  'female ejaculation through clothes',
#  'female footjob',
#  'fingering from behind',
#  'fisting',
#  'food insertion',
#  'foot pussy',
#  'forced lactation',
#  'forced orgasm',
#  'foreskin',
#  'foreskin insertion',
#  'foreskin pull',
#  'frenulum piercing',
#  'fucked silly',
#  'full-package futanari',
#  'fundoshi aside',
#  'futa on male',
#  'futa with futa',
#  'futa with male',
#  'futanari masturbation',
#  'futanari pov',
#  'futasub',
#  'gangbang',
#  'gigantic penis',
#  'girthy penis',
#  'glansjob',
#  'glory hole',
#  'gloved handjob',
#  'gokkun',
#  'golden shower',
#  'group incest',
#  'guided penetration',
#  'hairjob',
#  'half-erect',
#  "hand in another's panties",
#  "hand on another's penis",
#  'hand on own penis',
#  'handjob over clothes',
#  'hands on penis',
#  'handsfree ejaculation',
#  'handsfree paizuri',
#  'happy facial',
#  'head pinned down',
#  'heart-shaped pubic hair',
#  'horse dildo',
#  'horse penis',
#  'hug and suck',
#  'huge clitoris',
#  'huge dildo',
#  'huge penis',
#  'huge testicles',
#  'human toilet',
#  'hymen',
#  'imminent cunnilingus',
#  'imminent paizuri',
#  'imminent vaginal',
#  'implied rape',
#  'internal cumshot',
#  'intravaginal futanari',
#  'irrumatio',
#  'jewel butt plug',
#  'josou seme',
#  'just the tip',
#  'juxtaposition',
#  'kissing penis',
#  'kneepit sex',
#  'knotted penis',
#  'knotting',
#  'koonago',
#  'labia piercing',
#  'large insertion',
#  'large penis',
#  'large testicles',
#  'licking cum',
#  'licking penis',
#  'licking testicle',
#  'lipstick mark on ass',
#  'lipstick mark on penis',
#  'lipstick mark on testicles',
#  'lipstick ring',
#  'lolidom',
#  'long labia',
#  'long nipples',
#  'love train',
#  'male on futa',
#  'male spitroast',
#  'male underwear aside',
#  'mating press',
#  'milking handjob',
#  'mmf threesome',
#  'mounting',
#  'mouth insertion',
#  'multiple anal',
#  'multiple condoms',
#  'multiple penises',
#  'multiple vaginal',
#  'mutual fingering',
#  'mutual masturbation',
#  'mutual orgasm',
#  'naizuri',
#  'naked skirt',
#  'necrophilia',
#  'netorase',
#  'newhalf',
#  'newhalf with female',
#  'newhalf with male',
#  'nipple bells',
#  'nipple biting',
#  'nipple penetration',
#  'nipple tag',
#  'nipple torture',
#  'nipples pressed together',
#  'no anus',
#  'no testicles',
#  'nose hook',
#  'nursing handjob',
#  'object insertion from behind',
#  'orange pubic hair',
#  'orgasm denial',
#  'orgy',
#  'ovaries',
#  'oyakodon (sex)',
#  'paizuri on lap',
#  'paizuri over clothes',
#  'paizuri under clothes',
#  'panties around one ankle',
#  'panties on penis',
#  'panty gag',
#  'pecjob',
#  'peeing in cup',
#  'pegging',
#  'penetration through clothes',
#  'penis and testicles touching',
#  'penis biting',
#  'penis grab',
#  'penis milking',
#  'penis on ass',
#  'penis on face',
#  'penis on head',
#  'penis on pussy',
#  'penis on stomach',
#  'penis out',
#  'penis over eyes',
#  'penis over one eye',
#  'penis piercing',
#  'penis ribbon',
#  'penis sheath',
#  'penis size difference',
#  'penis tentacle',
#  'penis to breast',
#  "penis under another's clothes",
#  'penises touching',
#  'perineum',
#  'perpendicular paizuri',
#  'phimosis',
#  'piercing pull',
#  'piledriver (sex)',
#  'pointless condom',
#  'precum drip',
#  'precum string',
#  'precum through clothes',
#  'premature ejaculation',
#  'presenting another',
#  'presenting pussy',
#  'projectile cum',
#  'prolapse',
#  'prone bone',
#  'prostate',
#  'prostate milking',
#  'public masturbation',
#  'public use',
#  'public vibrator',
#  'puckered anus',
#  'pull out',
#  'purple nipples',
#  'pussy jewelry',
#  'pussy juice on fingers',
#  'pussy press',
#  'queen of spades symbol',
#  'rabbit vibrator',
#  'rectal prolapse',
#  'requesting internal cumshot',
#  'reverse cowgirl position',
#  'reverse fellatio',
#  'reverse footjob',
#  'reverse grip handjob',
#  'reverse nursing handjob',
#  'reverse paizuri',
#  'reverse spitroast',
#  'reverse suspended congress',
#  'reverse upright straddle',
#  'rope walking',
#  'rough sex',
#  'rusty trombone',
#  'sagging testicles',
#  'saliva on penis',
#  'saliva swap',
#  'scary sex',
#  'scat',
#  'sex machine',
#  'sex toy pull',
#  'sexual coaching',
#  'shared object insertion',
#  'shimaidon (sex)',
#  'shoejob',
#  'shorts aside',
#  'small penis',
#  'small penis humiliation',
#  'small testicles',
#  'smegma',
#  'smelling penis',
#  'soapland',
#  'sounding',
#  'spiked dildo',
#  'spiked penis',
#  'spitroast',
#  'spread anus',
#  'spread anus under clothes',
#  'squatting cowgirl position',
#  'squeezing testicles',
#  'standing cunnilingus',
#  'standing double penetration',
#  'standing missionary',
#  'standing sex',
#  'stealth fellatio',
#  'stealth masturbation',
#  'straddling paizuri',
#  'sucking male nipple',
#  'suction cup dildo',
#  'surrounded by penises',
#  'suspended congress',
#  'tachihanabishi',
#  'tail insertion',
#  'tail masturbation',
#  'taker pov',
#  'tentacle sex',
#  'tentaclejob',
#  'testicle grab',
#  'testicle sucking',
#  'testicles on face',
#  'thigh sex',
#  'thong aside',
#  'throat bulge',
#  'toddlercon',
#  'tonguejob',
#  'too many sex toys',
#  'triple penetration',
#  'tucked penis',
#  'twitching penis',
#  'two-footed footjob',
#  'two-handed handjob',
#  'underwater sex',
#  'ungagged',
#  'unwanted creampie',
#  'urethra',
#  'urethral beads',
#  'urethral insertion',
#  'used artificial vagina',
#  'used condom on penis',
#  'uterine prolapse',
#  'vaginal object insertion',
#  'veiny penis',
#  'veiny testicles',
#  'vibrator bulge',
#  'vibrator in anus',
#  'vibrator on clitoris',
#  'vibrator on penis',
#  'virgin',
#  'vomiting cum'}

# %%
print(len(general_general_tags))
print(len(general_sensitive_tag_counts))
print(len(general_questionable_tags))
print(len(general_explicit_tags))
# Out:
# 51457
# 12114
# 249
# 434

# %%
(
    len(general_general_tags)
    + len(general_sensitive_tag_counts)
    + len(general_questionable_tags)
    + len(general_explicit_tags)
)
# Out:
# 64254

# %% [markdown]
# ## Create copyright/character tag list

# %%
copyright_tags = set()
character_tags = set()

copyright_tag_counts = {}
character_tag_counts = {}


def load_copyright_and_character_tags(examples):
    for i, copyright in enumerate(examples["copyright"]):
        if copyright is None:
            copyright = "original"
        for tag in copyright.split(", "):
            copyright_tags.add(tag)
            if tag not in copyright_tag_counts:
                copyright_tag_counts[tag] = 1
            else:
                copyright_tag_counts[tag] += 1
    for i, character in enumerate(examples["character"]):
        if character is None:
            continue
        for tag in character.split(", "):
            character_tags.add(tag)
            if tag not in character_tag_counts:
                character_tag_counts[tag] = 1
            else:
                character_tag_counts[tag] += 1


ds.map(load_copyright_and_character_tags, batched=True)
# Out:
# Map:   0%|          | 0/6574005 [00:00<?, ? examples/s]
# Dataset({
#     features: ['id', 'copyright', 'character', 'artist', 'general', 'meta', 'rating', 'score', 'created_at'],
#     num_rows: 6574005
# })

# %%
copyright_tag_counts
# Out:
# {'sora no iro mizu no iro': 130,
#  'original': 1007957,
#  'bastard!!': 192,
#  'dragon quest': 10925,
#  'dragon quest v': 1624,
#  'slayers': 1126,
#  'milk junkies': 70,
#  'milk junkies 2': 21,
#  'nhk (broadcaster)': 96,
#  'shinobi hanafuda': 9,
#  'yotsubato!': 1298,
#  'kamichu!': 260,
#  'fate/stay night': 34771,
#  'fate (series)': 277240,
#  'love hina': 614,
#  'yurine ~onee-sama ga oshiete kureta~': 19,
#  'ragnarok online': 10064,
#  'vampire (game)': 7941,
#  'maria-sama ga miteru': 2809,
#  'kinnikuman': 287,
#  'street fighter': 20016,
#  'gunslinger girl': 456,
#  'idolmaster': 191811,
#  'idolmaster (classic)': 33476,
#  'idolmaster 1': 3646,
#  'apple inc.': 767,
#  'bleach': 8660,
#  'fate/hollow ataraxia': 3542,
#  'kanon': 2387,
#  'shichinin no online gamers': 55,
#  'betterman': 59,
#  'future gpx cyber formula': 72,
#  'yuusha ou gaogaigar': 404,
#  'yuusha ou gaogaigar final': 151,
#  'yuusha series': 664,
#  'yuusha tokkyuu might gaine': 51,
#  'disgaea': 4785,
#  'makai senki disgaea': 1177,
#  'gagraphic': 208,
#  'futabu': 83,
#  'onegai teacher': 399,
#  'sixty nine 2': 4,
#  'real life': 6453,
#  'makai tenshi djibril': 283,
#  'giant robo': 181,
#  'cannonball ~neko neko machine mou-race!~': 59,
#  'final fantasy': 56363,
#  'final fantasy x': 1831,
#  'final fantasy x-2': 483,
#  'tsukuyomi moonphase': 309,
#  'honoo no haramase tenkousei ue': 4,
#  'yami to boushi to hon no tabibito': 340,
#  'neon genesis evangelion: eva to yukai na nakama-tachi': 5,
#  'top wo nerae!': 436,
#  'xenogears': 944,
#  'mamanyonyo': 5,
#  'seiai gakuen fechi ka': 20,
#  'gundam': 38165,
#  'gundam seed': 3632,
#  'gundam seed destiny': 2234,
#  'words worth': 153,
#  'final fantasy unlimited': 80,
#  'munekyun! heart de koi shi-te-ru': 17,
#  'full metal panic!': 709,
#  'angel wish': 37,
#  'dungeons & dolls': 1,
#  'sakura relaxation': 6,
#  'mario (series)': 17171,
#  'mario strikers': 74,
#  'super mario strikers': 31,
#  'touhou': 789702,
#  'after (game)': 136,
#  'grappler baki': 326,
#  'mahou sensei negima!': 2795,
#  'cardcaptor sakura': 6800,
#  'galaxy angel': 1444,
#  'lovers (game)': 151,
#  'blood+': 280,
#  'sweet apricot': 6,
#  'happiness!': 542,
#  'nurse witch komugi-chan': 289,
#  'boin': 75,
#  'xenosaga': 1477,
#  'tsubasa no hatameki': 13,
#  'hate shinaku aoi kono sora no shita de....': 56,
#  'kasou genjitsu': 11,
#  'to heart (series)': 6316,
#  'to heart 2': 5205,
#  'la pucelle': 322,
#  'final fantasy vii': 16623,
#  'tsukihime': 7565,
#  'otome wa boku ni koishiteru': 231,
#  'futari wa precure': 2495,
#  'precure': 42897,
#  'shirley (manga)': 91,
#  'metroid': 5382,
#  'metroid (classic)': 41,
#  'neon genesis evangelion': 24344,
#  'dilbert': 4,
#  'macintosh': 157,
#  'os-tan': 3137,
#  'genshiken': 729,
#  'shuffle!': 901,
#  'jigoku shoujo': 703,
#  'shintaisou': 40,
#  'choujuushin gravion': 95,
#  'ichigo mashimaro': 1010,
#  'with you': 120,
#  'onetama': 14,
#  'onegai my melody': 979,
#  'sanrio': 2670,
#  'xenosaga episode i': 173,
#  'afternoon (magazine)': 19,
#  'yokohama kaidashi kikou': 172,
#  'kunoichi (game)': 37,
#  'tenohira wo taiyou ni': 19,
#  'nodame cantabile': 32,
#  'happy lesson': 59,
#  'zoids': 866,
#  'zoids genesis': 474,
#  'fushigi no umi no nadia': 1024,
#  'gainax': 269,
#  'yukizakura': 2,
#  'higurashi no naku koro ni': 9261,
#  'pokemon': 194564,
#  'pokemon (anime)': 14559,
#  'pokemon rse (anime)': 854,
#  'gundam zz': 1519,
#  'my-hime': 1381,
#  'lime-iro senkitan': 51,
#  'megami magazine': 5274,
#  'final fantasy vii advent children': 1252,
#  'eureka seven': 1213,
#  'eureka seven (series)': 1309,
#  'maid in heaven': 35,
#  'maid in heaven supers': 9,
#  'temptation': 52,
#  'temptation h': 19,
#  'pink no ayumi!': 35,
#  'dragon quest viii': 830,
#  'kagetsu tooya': 151,
#  'ai shi~kyu~': 4,
#  'true blue': 24,
#  'gunparade march': 65,
#  'haibane renmei': 431,
#  'aishiteruze baby': 28,
#  'yakitate!! japan': 217,
#  'to heart': 1171,
#  'izayoi no hanayome': 104,
#  'pani poni dash!': 1171,
#  'makai senki disgaea 2': 663,
#  'princess crown': 96,
#  'tsuyokiss': 211,
#  'tick! tack!': 46,
#  'teizokurei daydream': 7,
#  'utakata': 83,
#  'comiket 66': 8,
#  'nanako-san-teki na nichijou': 3,
#  'futari ecchi': 48,
#  'breath of fire': 1891,
#  'breath of fire iii': 336,
#  'meimeimei!': 4,
#  'onegai ohoshisama': 16,
#  'dead or alive': 5019,
#  'shukketsubo': 7,
#  'ukagaka': 395,
#  'kaze no tani no nausicaa': 664,
#  'linux': 73,
#  'yumeria': 67,
#  'ringetsu': 73,
#  'gad guard': 102,
#  'boukun habanero': 116,
#  'rahxephon': 82,
#  'night wizard': 233,
#  'night wizard mahou taisen': 8,
#  'pangya': 1525,
#  'melty blood': 2290,
#  'supacchu!': 14,
#  'marlboro': 98,
#  'ashita no nadja': 144,
#  'konjiki no gash!!': 207,
#  'ojamajo doremi': 672,
#  'pastel chime': 117,
#  'wild arms': 1367,
#  'wild arms 1': 280,
#  'rave': 51,
#  'ufo princess valkyrie': 39,
#  'elemental gelade': 77,
#  'final fantasy xi': 3054,
#  'saya no uta': 633,
#  'guilty gear': 15414,
#  'rozen maiden': 8016,
#  'papikon': 10,
#  'princess tutu': 370,
#  'shinrabanshou': 2210,
#  'akahori gedou hour rabuge': 12,
#  'radix': 2,
#  'zettai seigi love pheromone': 3,
#  'excel saga': 89,
#  'overman king gainer': 251,
#  'marshmallow times': 12,
#  'puni puni poemi': 12,
#  'shoujo kakumei utena': 1043,
#  'pink sniper': 50,
#  'puppetmuppet': 12,
#  'gosick': 516,
#  'gosicks': 5,
#  'usaneko': 5,
#  'shikigami no shiro': 45,
#  'shikigami no shiro ii': 9,
#  'omoikkiri kagaku adventure sounanda': 14,
#  'realize': 12,
#  'mushihime-sama': 147,
#  'breath of fire ii': 744,
#  'fate/unlimited blade works': 247,
#  'aruruw to asobo!!': 6,
#  'utawarerumono': 1724,
#  'bukatsu kikaku': 24,
#  'kusari': 37,
#  'kidou senkan nadesico': 943,
#  'kizuato': 225,
#  'fushigiboshi no futago hime': 441,
#  'grand theft auto': 310,
#  'grand theft auto: san andreas': 71,
#  'zero no tsukaima': 3209,
#  'natsunone': 20,
#  'capcom fighting jam': 789,
#  'chikansha thomas 2': 6,
#  'shishunki': 22,
#  'level justice': 5,
#  'yukiuta': 17,
#  'moomin': 808,
#  'top wo nerae 2!': 412,
#  'binchou-tan': 41,
#  'zone of the enders': 269,
#  'zone of the enders: dolores i': 16,
#  'snk': 3507,
#  'the king of fighters': 11306,
#  'super robot wars': 4158,
#  'super robot wars judgement': 119,
#  'air (visual novel)': 1587,
#  'alice in wonderland': 3440,
#  'gunxsword': 147,
#  'samurai spirits': 2876,
#  'shakugan no shana': 2397,
#  'd.gray-man': 710,
#  'noein': 97,
#  'stratos 4': 110,
#  'machikado no boulanger': 3,
#  'missing blue': 7,
#  'angel/dust neo': 20,
#  'angel flavor': 83,
#  'kakyuusei 2': 309,
#  'downtown no gaki no tsukai ya arahende!!': 223,
#  'wagaya no oinari-sama': 125,
#  'kimi kiss': 1058,
#  'death note': 1156,
#  'suigetsu': 634,
#  'quiz magic academy': 1263,
#  'kore ga watashi no goshujin-sama': 262,
#  'hinatabokko': 35,
#  'berserk': 1687,
#  'my-otome': 935,
#  'fatal fury': 4195,
#  'type-moon': 995,
#  'presence': 27,
#  'magical tale': 34,
#  'mobile suit gundam': 2717,
#  'kimi ga nozomu eien': 502,
#  'xenosaga episode ii': 54,
#  '2002 fifa world cup': 6,
#  'futakoi': 190,
#  'ninin ga shinobuden': 243,
#  'tsuki wa higashi ni hi wa nishi ni': 88,
#  'uchuu no stellvia': 283,
#  'world cup': 841,
#  'yuukyuu gensoukyoku': 42,
#  'the end of evangelion': 180,
#  'wonder momo': 59,
#  'as you like': 7,
#  'white album': 150,
#  'white album (series)': 292,
#  '.hack//': 808,
#  '.hack//tasogare no udewa densetsu': 121,
#  'black cat (series)': 136,
#  'pure pure': 148,
#  'planetarian': 249,
#  'futaba channel': 1260,
#  'naisho no houkago': 3,
#  'gear senshi dendou': 42,
#  'kyouhaku 2': 33,
#  'gokujou seitokai': 83,
#  'monster (manga)': 114,
#  'da capo': 1035,
#  'da capo i': 406,
#  'kuso miso technique': 383,
#  'warzard': 121,
#  'seifuku rakuen': 40,
#  'shaman king': 524,
#  'summon night': 1390,
#  'summon night 3': 556,
#  'mushishi': 314,
#  'chiyu 12-sai': 7,
#  'netrunmon': 7,
#  'aquarian age': 181,
#  'newstars': 1,
#  'ryuusei sentai musumet': 10,
#  'sony': 444,
#  'versailles no bara': 191,
#  'spiral (manga)': 12,
#  'gekiganger 3': 7,
#  '2channel': 356,
#  'akiiro renka': 57,
#  'mahoraba': 175,
#  'yoake mae yori ruri iro na': 466,
#  'canvas 2': 98,
#  'gensou suikoden': 1535,
#  'gensou suikoden iv': 161,
#  'ichigeki sacchuu!! hoihoi-san': 86,
#  'wonder festival': 217,
#  'wonder festival mascots': 32,
#  'aoi sora no neosphere': 40,
#  'kaleido star': 228,
#  'kango shichauzo 3': 3,
#  'sweet devil': 13,
#  'sakura musubi': 162,
#  'nippon ichi': 335,
#  'phantom kingdom': 194,
#  'mujin wakusei survive': 128,
#  'yogurting': 36,
#  'akibablog': 11,
#  'di gi charat': 1539,
#  'futa majo': 5,
#  'kara no kyoukai': 2508,
#  'chokotto sister': 64,
#  'lunar': 116,
#  'lunar: the silver star': 61,
#  'lamune': 56,
#  'busou renkin': 221,
#  'sangokushi (yokoyama mitsuteru)': 14,
#  'hina! hina! hina!': 1,
#  'alma ~zutto soba ni...~': 15,
#  'beat angel escalayer': 166,
#  'moekan': 34,
#  'wind a breath of heart': 74,
#  'iriya no sora ufo no natsu': 75,
#  'sorauta': 51,
#  'death meta': 2,
#  'lyrical nanoha': 20315,
#  'mahou shoujo lyrical nanoha': 9818,
#  'radiata stories': 61,
#  'clannad': 4734,
#  'cosmos no sora ni': 11,
#  'blue sky ~aozora-sou no yukai na nakama tachi~': 1,
#  'sexfriend': 90,
#  'tenshi no inai 12-gatsu': 124,
#  "mahou shoujo lyrical nanoha a's": 4953,
#  'comic party': 277,
#  'majokko a la mode': 64,
#  'solty rei': 76,
#  'chobits': 466,
#  'space channel 5': 108,
#  'ichigo 100 percent': 274,
#  'mahoromatic': 375,
#  'yakitate croissant': 7,
#  'bishoku': 2,
#  'mizuiro': 64,
#  'senkou no ronde': 215,
#  "clover heart's": 36,
#  'nanaka 6/17': 6,
#  'shuukan watashi no onii-chan': 8,
#  'azumanga daioh': 1985,
#  'to heart 2 xrated': 128,
#  'mahou senshi princess tear': 2,
#  'rozen maiden traumend': 22,
#  'aquarion (series)': 976,
#  'sousei no aquarion': 77,
#  'bokusatsu tenshi dokuro-chan': 240,
#  'nangoku dominion': 12,
#  'atlanta hawks': 9,
#  'national basketball association': 222,
#  'phoenix suns': 11,
#  'slam dunk (series)': 995,
#  'mabinogi': 1705,
#  'tsukushite ageru no!': 7,
#  'futakoi alternative': 23,
#  'touji no sato': 22,
#  'embodiment of scarlet devil': 1128,
#  'paradise kiss': 3,
#  'kamen rider': 6797,
#  'kamen rider hibiki (series)': 161,
#  'last story wa anata e': 3,
#  'animaga': 17,
#  'full moon wo sagashite': 143,
#  'basilisk (manga)': 91,
#  'petopetosan': 23,
#  'brigadoon': 85,
#  'moetan': 287,
#  'doraemon': 1177,
#  'saint seiya': 1097,
#  "girl's avenue": 116,
#  'wacom': 248,
#  'bobobo-bo bo-bobo': 212,
#  'londonexpo': 2,
#  'lupin iii': 996,
#  'microman': 9,
#  'jinki': 235,
#  'beck': 11,
#  'nanatsuiro drops': 278,
#  'xenosaga the animation': 1,
#  'd4 princess': 9,
#  'space adventure cobra': 157,
#  'namco': 193,
#  'danbooru (site)': 32,
#  'apricot-tei monogatari': 2,
#  'konneko': 69,
#  'summon night 2': 312,
#  'jingai makyou': 108,
#  'kaidan kidan mononoke yashiki': 1,
#  'ghost in the shell': 1493,
#  'magical antique': 40,
#  'petit monster': 10,
#  'kokoro toshokan': 29,
#  'school days': 558,
#  "tengoku heaven's prison": 1,
#  'boukyaku no senritsu': 14,
#  'muv-luv': 2601,
#  'waga mama capriccio': 40,
#  'akira (manga)': 553,
#  'bemani': 449,
#  'chunichi dragons': 94,
#  'hanshin tigers': 122,
#  'nippon professional baseball': 773,
#  'saber marionette j': 206,
#  'peace maker kurogane': 12,
#  'scrapped princess': 72,
#  'nijiura maids': 738,
#  'tales of (series)': 12457,
#  'tales of eternia': 382,
#  'pia carrot (series)': 329,
#  'pia carrot e youkoso!! 3': 158,
#  'megami magazine creators': 68,
#  'lunch box (manga)': 15,
#  'kill bill': 107,
#  'sister princess': 711,
#  'soul link': 89,
#  'zettai shounen': 16,
#  'battle programmer shirase': 39,
#  'rikujou boueitai mao-chan': 15,
#  'dengeki hime': 234,
#  'matantei loki ragnarok': 34,
#  'shaft': 119,
#  'school rumble': 772,
#  'harumachi kagerou': 2,
#  'yui shop': 13,
#  'mega man (classic)': 2631,
#  'mega man (series)': 8446,
#  'naruto (series)': 12406,
#  'naruto shippuuden': 4249,
#  'g-taste': 142,
#  'the ring': 900,
#  'tamayura ~ryoujoku side~': 5,
#  'the god of death': 30,
#  'harry potter (series)': 1334,
#  'hellboy (comic)': 98,
#  'wizarding world': 1518,
#  'may queen': 26,
#  'hellsing': 856,
#  'tanaha': 6,
#  'keroro gunsou': 1237,
#  'record of lodoss war': 507,
#  'nee chanto shiyou yo!': 49,
#  'nee chanto shiyou yo! 2': 15,
#  'lost in blue': 4,
#  'oneechanbara': 133,
#  'hi no tsuki': 6,
#  'abenobashi mahou shoutengai': 101,
#  'hobo-san to issho!': 17,
#  'gantz': 447,
#  'witchblade': 422,
#  'dear my friend': 23,
#  'hanaukyou maid tai': 21,
#  'scryed': 260,
#  'f-ism': 578,
#  'ikari shinji raising project': 40,
#  'r.o.d the tv': 198,
#  'read or die': 489,
#  'yuibashi': 14,
#  'lineage': 201,
#  'lineage 2': 151,
#  'seikai no senki': 160,
#  'g gundam': 1125,
#  'ai yori aoshi': 149,
#  'purupuru shirts!': 2,
#  'taisen hot gimmick': 57,
#  'taisen hot gimmick 5': 8,
#  'after war gundam x': 343,
#  'urusei yatsura': 2264,
#  'terminator (series)': 339,
#  'the terminator': 237,
#  'heartbreak ~koi no triangle chuuihou~': 5,
#  'pururun cafe': 15,
#  'black lagoon': 1644,
#  'texhnolyze': 18,
#  'sumomomo momomo': 79,
#  'muteki choujin zambot 3': 67,
#  'snow fox': 153,
#  'boy meets girl': 50,
#  'edelweiss (otaku beam)': 1,
#  'hidamari sketch': 2423,
#  'flcl': 701,
#  'comic rin': 170,
#  "char's deleted affair": 37,
#  'peace@pieces': 149,
#  'phantasy star': 4957,
#  'phantasy star online': 164,
#  'puppet princess': 5,
#  'milkyway': 15,
#  'milkyway 2': 5,
#  'essence lost': 1,
#  'trigun': 1184,
#  'tales of the abyss': 1645,
#  'zeta gundam': 1871,
#  'tekken': 3583,
#  'fu-ta-ba': 4,
#  'bishoujo senshi sailor moon': 13103,
#  'bashamichi': 135,
#  'daibanchou': 67,
#  'eiyuu densetsu': 4795,
#  'shiroki majo': 9,
#  'soulcalibur': 2329,
#  'soulcalibur iii': 97,
#  'tenshi de akuma': 3,
#  'sega': 526,
#  'shiritsu akihabara gakuen': 9,
#  'shiritsu akihabara gakuen fandisk akibako': 1,
#  'seiken densetsu': 1988,
#  'seiken densetsu 3': 1576,
#  'narue no sekai': 29,
#  'tombow mono': 127,
#  'ju-on': 28,
#  'the grudge': 30,
#  'brave soul': 86,
#  'suika (visual novel)': 29,
#  'univ ~ai omatase~': 6,
#  'akiiro ouka': 6,
#  'dragon ball': 16106,
#  'dragon ball z': 7712,
#  'majo no takkyuubin': 953,
#  'men in black': 88,
#  'one - kagayaku kisetsu e': 203,
#  'chicchana yukitsukai sugar': 37,
#  'born freaks!': 16,
#  'court no naka no tenshi-tachi': 6,
#  'bless ~close your eyes open your mind~': 2,
#  'sis x miko': 7,
#  'bronze parrot': 30,
#  'rumble roses': 242,
#  'tail tale': 16,
#  'naruto': 7231,
#  'sakura taisen': 1420,
#  'sakura taisen iii': 343,
#  'yotsunoha': 147,
#  'binzume yousei': 66,
#  'star wars': 2444,
#  'megatokyo': 10,
#  'stray little devil': 22,
#  'aria (manga)': 2113,
#  'drainagecity': 2,
#  'meguri hitohira.': 7,
#  'samurai champloo': 165,
#  'ma ga ochiru yoru': 10,
#  'komorebi ni yureru tamashii no koe': 41,
#  'anonono': 11,
#  'fullmetal alchemist': 4129,
#  'mainichi suki shite': 3,
#  'pancho de bravo!': 4,
#  'futari de marvel shichaimasu!': 4,
#  'majiresu!! ~omatase little wing~': 15,
#  'imouto kansatsu nikki 2': 20,
#  'triangle soft': 1,
#  'pugyuru': 6,
#  'macross': 8313,
#  'macross 7': 573,
#  'ace attorney': 4321,
#  'natsuiro ~hoshifuru kohan no natsuyasumi~': 9,
#  'shuffle! on the stage': 2,
#  'summer days': 32,
#  'touhou (pc-98)': 10378,
#  'ikkitousen': 2229,
#  'ikusa megami': 1,
#  'ikusa megami (series)': 35,
#  'meishoku no reiki': 5,
#  'dousoukai refrain': 4,
#  'girls bravo': 102,
#  'kage kara mamoru!': 57,
#  "pop'n music": 577,
#  'answer dead': 6,
#  'piyona pikona': 4,
#  'virgin snow': 2,
#  'natural 2 duo': 5,
#  'marginal': 4,
#  'kannazuki no miko': 431,
#  'megami magazine deluxe': 128,
#  'dead or alive 4': 16,
#  'angelic serenade': 32,
#  'cosmic baton girl comet-san': 53,
#  'howl no ugoku shiro': 517,
#  'present for you': 7,
#  'ghost in the shell stand alone complex': 565,
#  'beatmania iidx': 1176,
#  'tenjou tenge': 190,
#  'angel sanctuary': 56,
#  'dengeki moeou': 1452,
#  'techgian': 51,
#  'omc': 136,
#  '21 two one': 6,
#  'sore wa maichiru sakura no you ni': 17,
#  'onitama': 2,
#  'da pantsu!!': 2,
#  'imouto ~sweet&bitter~': 1,
#  'sugar sugar rune': 46,
#  'panda-z': 3,
#  'tonari no totoro': 669,
#  'popotan': 133,
#  'routes': 50,
#  'animal yokochou': 23,
#  'kill love': 2,
#  'saimoe': 23,
#  'tecmo': 1,
#  'hand maid may': 49,
#  'homemaid': 11,
#  'tv tokyo': 19,
#  'geneon': 7,
#  'sunrise (company)': 228,
#  'kamiuta': 2,
#  'da capo second season': 12,
#  'ryuuko no ken': 1109,
#  'ai shimai tsubomi': 4,
#  'purple-core': 3,
#  'final fantasy iv': 2058,
#  'koi q!': 24,
#  'one piece': 18340,
#  'sacred plume': 3,
#  'maji miko': 2,
#  "queen's blade": 5314,
#  'ore no natsuyasumi': 47,
#  'pokemon (classic anime)': 2765,
#  'chou no yume': 10,
#  'kao no nai tsuki': 257,
#  'shouyon! kodomo challenge': 17,
#  'neon genesis evangelion: iron maiden': 39,
#  'hermit complex': 5,
#  'congratu-rape': 4,
#  'super smash bros.': 7685,
#  'the legend of zelda': 21334,
#  'short cuts': 20,
#  's na kanojo': 10,
#  'aa megami-sama': 1057,
#  "den'ei shoujo": 41,
#  'dynamite beauty': 1,
#  'hajime no ippo': 94,
#  'heart catch izumi-chan': 6,
#  'meitantei conan': 2477,
#  'nanako sos': 4,
#  'otenki onee-san': 1,
#  'ping pong club': 10,
#  'ranma 1/2': 3450,
#  'rough (manga)': 3,
#  'shinrei chousa shitsu: office rei': 1,
#  'henshin!': 36,
#  'henshin! 2': 5,
#  'may-be soft': 13,
#  'mousou dairinin': 41,
#  'the matrix': 101,
#  'mayu ~yuki no knife~': 1,
#  'gemini (game)': 1,
#  'donkey kong (series)': 694,
#  'game & watch': 173,
#  'sakura machizaka stories': 26,
#  'sensei ga oshiete ageru': 18,
#  'comic mujin': 11,
#  'asa no konai yoru ni dakarete -eternal night-': 3,
#  'onegai twins': 187,
#  'ubuntu': 9,
#  'candy (art book)': 53,
#  'genmukan': 102,
#  'osu mesu time slip!': 4,
#  'futari wa precure max heart': 543,
#  "nikutai kin'yuu dou": 4,
#  'eyeshield 21': 362,
#  'star ocean': 2845,
#  'star ocean till the end of time': 838,
#  'firefox': 161,
#  'elysion': 203,
#  'sound horizon': 796,
#  'mono gokoro mono musume': 15,
#  'doki doki majo shinpan': 106,
#  'quilt (game)': 134,
#  'kodomo no jikan': 679,
#  'gedo senki': 22,
#  'studio ghibli': 1018,
#  'monster hunter (series)': 7789,
#  'monster hunter g': 9,
#  "mcdonald's": 2056,
#  'tears to tiara': 80,
#  'spalding': 26,
#  'armageddon (movie)': 8,
#  'suzumiya haruhi no yuuutsu': 18916,
#  'kateikyoushi no onee-san': 42,
#  'floralia': 65,
#  'mahou shoujo twinkle': 6,
#  'madou monogatari': 908,
#  'puyopuyo': 3220,
#  'kokoro navi': 58,
#  'alice no yakata 7': 16,
#  'suzumiya keimu shoukan': 9,
#  'osananajimi na kanojo': 3,
#  'gakuen tengoku (manga)': 3,
#  'defcon one': 5,
#  'kazoku koukan dl04': 2,
#  'demonbane': 437,
#  'fukuramikake': 6,
#  'shimaima': 12,
#  'maburaho': 160,
#  'pastel chime continue': 65,
#  'bakuretsu tenshi': 141,
#  'circus (studio)': 78,
#  'unmei no keitouju': 14,
#  'blood the last vampire': 27,
#  'galge.com': 409,
#  'victorian romance emma': 83,
#  'tsugumomo': 529,
#  'koi neko': 4,
#  'elfen lied': 250,
#  'shojokyu': 8,
#  'pure x cure': 12,
#  'comiket 69': 4,
#  'oshioki sweetie': 166,
#  'winnie the pooh': 176,
#  'dears': 67,
#  'zombie loan': 12,
#  'kokan hunter 2': 2,
#  'little busters!': 4956,
#  'dragon quest iv': 1761,
#  'platinum wind': 17,
#  'trickster': 221,
#  'ama no miko hime': 4,
#  'saishuu shiken kujira': 25,
#  'school festa': 8,
#  'hajimete doushi (zero)': 6,
#  'to heart 2 ad': 350,
#  'etsusa oohashi': 39,
#  'white princess': 11,
#  'blame!': 479,
#  'advance wars': 173,
#  'atlach-nacha': 60,
#  'pokemon gsc': 1964,
#  'alto': 33,
#  'memories off': 323,
#  'memories off#5': 34,
#  'tenkuu no symphonia': 13,
#  'final fantasy iii': 363,
#  'moon childe': 6,
#  'fight ippatsu! juuden-chan!!': 49,
#  'yakin byoutou': 145,
#  'kashimashi': 167,
#  "denny's": 14,
#  'tomoyo after': 64,
#  'katamari damacy': 90,
#  'super doll licca-chan': 26,
#  'gundam sentinel': 217,
#  'advance of zeta': 118,
#  'sengoku blade': 54,
#  'futarijime': 3,
#  'nursery rhyme': 92,
#  'parfait chocolat second brew': 46,
#  'komorebi no namikimichi': 23,
#  'canvas (cocktail soft)': 52,
#  'ochiba no mau koro': 5,
#  'munekyun heartful cafe': 15,
#  'present pretty': 11,
#  'jojo no kimyou na bouken': 25594,
#  'ragnarok online 2: gate of the world': 17,
#  'kizumono no shoujo': 6,
#  'wasurenagusa': 16,
#  'hikari to mizu no daphne': 41,
#  'cosplex': 16,
#  'kachi-kachi yama': 6,
#  'sankaido shop': 1,
#  'colorful kanan': 83,
#  'windows xp': 86,
#  'air gear': 203,
#  'kujibiki unbalance': 122,
#  'minami-ke': 925,
#  'mizu no kakera': 7,
#  'tenshi no kakera the lost article of memory': 3,
#  'angels blue': 5,
#  'ayatsuri burumaa': 11,
#  'karin (manga)': 74,
#  'sabae no ou': 1,
#  'album no naka no hohoemi': 1,
#  'aquaplus': 196,
#  'leaf (studio)': 62,
#  'densha otoko': 21,
#  'getsumento heiki miina': 84,
#  'akane maniax': 19,
#  'sakura no uta': 60,
#  'patissier na nyanko': 9,
#  'gotcha force': 20,
#  'ryuu ga gotoku (series)': 929,
#  'ryuu ga gotoku 1': 141,
#  'ryuu ga gotoku kiwami': 51,
#  'noir (anime)': 104,
#  'airashiku midara ni': 1,
#  'itsudatte my santa!': 3,
#  'kamisama no iutoori': 21,
#  'soukou kihei votoms': 250,
#  'dessert love': 1,
#  'akai ibara': 31,
#  'fushigi mahou fun fun pharmacy': 37,
#  'imouto de ikou!': 8,
#  'inuyasha': 1790,
#  'granado espada': 172,
#  'madlax': 23,
#  'sensei daisuki': 6,
#  'agatha christie no meitantei poirot to marple': 52,
#  'ekokuice': 68,
#  'microsoft': 333,
#  'microsoft windows': 390,
#  'strike witches: kurenai no majo-tachi': 807,
#  'world witches series': 21783,
#  'onedari sweetie': 3,
#  'lust ~saiin joutai~': 1,
#  'headphone + musume': 25,
#  'hajimete no orusuban': 67,
#  'super robot wars 64': 12,
#  'daiakuji': 66,
#  'all nippon airways': 48,
#  'graduation (series)': 13,
#  'sotsugyou next graduation': 6,
#  'makai tenshi djibril 2': 76,
#  'b-daman': 38,
#  'b-densetsu! battle b-daman': 3,
#  'agent aika': 714,
#  'aika (series)': 832,
#  'angelic layer': 79,
#  'argento soma': 7,
#  'bishoujo yuugekitai battle skipper': 15,
#  'captain tsubasa': 67,
#  'cinderella boy': 4,
#  'cosplay complex': 1,
#  "dennou sentai voogie's angel": 10,
#  'dragon half': 79,
#  'el hazard': 90,
#  'f-zero': 370,
#  'f-zero falcon densetsu': 6,
#  'fushigi no kuni no miyuki-chan': 7,
#  'gankutsuou': 85,
#  'gatekeepers': 14,
#  'ginga ojou-sama densetsu yuna': 98,
#  'golden boy': 92,
#  'guilty gear xx': 1245,
#  'gundam 08th ms team': 371,
#  'gungrave': 31,
#  'idol project': 14,
#  'kaitou saint tail': 147,
#  'kiddy grade': 266,
#  'langrisser': 340,
#  'magic knight rayearth': 615,
#  'mahou senshi louie': 29,
#  'marmalade boy': 14,
#  'megami paradise': 101,
#  'moldiver': 11,
#  'otaku no seiza': 1,
#  'otaku no video': 27,
#  'puchi puri yucie': 35,
#  'shima shima tora no shimajirou': 4,
#  'shin megami tensei': 1737,
#  'shin megami tensei devil children': 16,
#  'slayers great': 1,
#  'super robot wars the lord of elemental': 241,
#  'tales of destiny': 274,
#  'tobe! isami': 12,
#  'twinbee': 93,
#  'valkyrie profile (series)': 625,
#  'weiss kreuz': 2,
#  'zoku zoku mura no obake-tachi': 1,
#  'kono minikuku mo utsukushii sekai': 22,
#  'carnival (game)': 3,
#  'himekishi lilia': 13,
#  'kafun shoujo chuuihou!': 21,
#  'dokkoida': 35,
#  'bible black': 171,
#  'demento': 127,
#  'dyogrammaton': 28,
#  'contra': 45,
#  'contra: shattered soldier': 5,
#  'shin contra': 2,
#  'serial experiments lain': 830,
#  'osananajimi (game)': 2,
#  'hand maid mai': 2,
#  'shinkon gattai godannar!!': 186,
#  'hikaru no go': 263,
#  'medarot': 390,
#  'shino-sensei no yuuwaku jugyou': 7,
#  'ni-hao!': 7,
#  'choujuushin gravion zwei': 34,
#  "grimm's fairy tales": 579,
#  'little red riding hood': 1599,
#  'yakin byoutou ni': 37,
#  'rabuyan': 13,
#  'yu-gi-oh!': 17885,
#  'yu-gi-oh! gx': 2154,
#  'muv-luv alternative': 1971,
#  'cross channel': 70,
#  'dragon quest iii': 2499,
#  'breath of fire iv': 386,
#  'breath of fire v': 437,
#  'grenadier (manga)': 28,
#  'bohemian rhapsody': 52,
#  'queen (band)': 115,
#  'comic kairakuten': 384,
#  'cartagra': 80,
#  'nakaba 1': 18,
#  'counter-strike': 39,
#  'counter-strike (series)': 99,
#  'counter-strike neo': 1,
#  'rez': 4,
#  'akibakei kanojo': 45,
#  'angel maid': 4,
#  'mitama ~shinobi~': 59,
#  'mamakan': 7,
#  "his master's voice": 25,
#  'romancing saga': 210,
#  'saga': 1334,
#  'namco x capcom': 166,
#  'hikagemono': 2,
#  'fire emblem': 69411,
#  'fire emblem: mystery of the emblem': 3578,
#  'nhk ni youkoso!': 199,
#  'kazoku keikaku': 16,
#  'comic megastore h': 40,
#  'planetes': 47,
#  'asagiri no miko': 24,
#  'kobeya': 247,
#  'najica dengeki sakusen': 46,
#  'chaos angels': 18,
#  'okusama wa mahou shoujo': 32,
#  'melonbooks': 1952,
#  'tiara (symphony)': 2,
#  'shining (series)': 1266,
#  'shining tears': 175,
#  'sapphism no gensou': 39,
#  'messe sanoh': 11,
#  'angel links': 47,
#  'loe ~legend of enomoto~': 3,
#  'messerschmitt': 6,
#  'kouchuu ouja mushiking': 17,
#  'mushiking': 114,
#  'ikenai shutter chance!': 6,
#  'the 3rd super robot wars alpha': 48,
#  'cyberbots': 168,
#  'bakumatsu rouman': 230,
#  'rocket no natsu': 14,
#  'speed grapher': 24,
#  'kagami no naka no orgel': 5,
#  'nogizaka haruka no himitsu': 181,
#  'ultimate girl': 25,
#  'lingerie senshi papillon rose': 13,
#  'super robot wars original generation': 1082,
#  'little tail bronx': 108,
#  'tail concerto': 39,
#  'mako-chan to asobou!': 1,
#  'onmyou taisenki': 21,
#  'the big o': 242,
#  'mahou shoujo pretty sammy': 94,
#  'macross zero': 120,
#  'futa nari 4 sisters': 1,
#  'shitsuraku no kamijo': 1,
#  'toshiue no hito': 12,
#  'i asked for scrambled': 16,
#  'kareshi kanojo no jijou': 63,
#  'aoi umi no tristia': 48,
#  'wandaba style': 22,
#  'tasogare': 23,
#  'saw (movie)': 72,
#  'sangokushi taisen': 455,
#  'time capsule haru': 1,
#  're leaf': 109,
#  'alteil': 55,
#  'kenran butou sai': 77,
#  'battle athletes': 155,
#  'leaf fight': 8,
#  'marvel': 7995,
#  'spider-man (series)': 3490,
#  'final romance 4': 19,
#  'panic!! kerokero kingdom': 8,
#  'kfc': 626,
#  'yuuhi no mukougawa': 10,
#  ...}

# %%
# remove too few tags (less than 100)
copyright_tag_counts = {k: v for k, v in copyright_tag_counts.items() if v >= 100}
character_tag_counts = {k: v for k, v in character_tag_counts.items() if v >= 100}

# %%
copyright_tag_counts
# Out:
# {'sora no iro mizu no iro': 130,
#  'original': 1007957,
#  'bastard!!': 192,
#  'dragon quest': 10925,
#  'dragon quest v': 1624,
#  'slayers': 1126,
#  'yotsubato!': 1298,
#  'kamichu!': 260,
#  'fate/stay night': 34771,
#  'fate (series)': 277240,
#  'love hina': 614,
#  'ragnarok online': 10064,
#  'vampire (game)': 7941,
#  'maria-sama ga miteru': 2809,
#  'kinnikuman': 287,
#  'street fighter': 20016,
#  'gunslinger girl': 456,
#  'idolmaster': 191811,
#  'idolmaster (classic)': 33476,
#  'idolmaster 1': 3646,
#  'apple inc.': 767,
#  'bleach': 8660,
#  'fate/hollow ataraxia': 3542,
#  'kanon': 2387,
#  'yuusha ou gaogaigar': 404,
#  'yuusha ou gaogaigar final': 151,
#  'yuusha series': 664,
#  'disgaea': 4785,
#  'makai senki disgaea': 1177,
#  'gagraphic': 208,
#  'onegai teacher': 399,
#  'real life': 6453,
#  'makai tenshi djibril': 283,
#  'giant robo': 181,
#  'final fantasy': 56363,
#  'final fantasy x': 1831,
#  'final fantasy x-2': 483,
#  'tsukuyomi moonphase': 309,
#  'yami to boushi to hon no tabibito': 340,
#  'top wo nerae!': 436,
#  'xenogears': 944,
#  'gundam': 38165,
#  'gundam seed': 3632,
#  'gundam seed destiny': 2234,
#  'words worth': 153,
#  'full metal panic!': 709,
#  'mario (series)': 17171,
#  'touhou': 789702,
#  'after (game)': 136,
#  'grappler baki': 326,
#  'mahou sensei negima!': 2795,
#  'cardcaptor sakura': 6800,
#  'galaxy angel': 1444,
#  'lovers (game)': 151,
#  'blood+': 280,
#  'happiness!': 542,
#  'nurse witch komugi-chan': 289,
#  'xenosaga': 1477,
#  'to heart (series)': 6316,
#  'to heart 2': 5205,
#  'la pucelle': 322,
#  'final fantasy vii': 16623,
#  'tsukihime': 7565,
#  'otome wa boku ni koishiteru': 231,
#  'futari wa precure': 2495,
#  'precure': 42897,
#  'metroid': 5382,
#  'neon genesis evangelion': 24344,
#  'macintosh': 157,
#  'os-tan': 3137,
#  'genshiken': 729,
#  'shuffle!': 901,
#  'jigoku shoujo': 703,
#  'ichigo mashimaro': 1010,
#  'with you': 120,
#  'onegai my melody': 979,
#  'sanrio': 2670,
#  'xenosaga episode i': 173,
#  'yokohama kaidashi kikou': 172,
#  'zoids': 866,
#  'zoids genesis': 474,
#  'fushigi no umi no nadia': 1024,
#  'gainax': 269,
#  'higurashi no naku koro ni': 9261,
#  'pokemon': 194564,
#  'pokemon (anime)': 14559,
#  'pokemon rse (anime)': 854,
#  'gundam zz': 1519,
#  'my-hime': 1381,
#  'megami magazine': 5274,
#  'final fantasy vii advent children': 1252,
#  'eureka seven': 1213,
#  'eureka seven (series)': 1309,
#  'dragon quest viii': 830,
#  'kagetsu tooya': 151,
#  'haibane renmei': 431,
#  'yakitate!! japan': 217,
#  'to heart': 1171,
#  'izayoi no hanayome': 104,
#  'pani poni dash!': 1171,
#  'makai senki disgaea 2': 663,
#  'tsuyokiss': 211,
#  'breath of fire': 1891,
#  'breath of fire iii': 336,
#  'dead or alive': 5019,
#  'ukagaka': 395,
#  'kaze no tani no nausicaa': 664,
#  'gad guard': 102,
#  'boukun habanero': 116,
#  'night wizard': 233,
#  'pangya': 1525,
#  'melty blood': 2290,
#  'ashita no nadja': 144,
#  'konjiki no gash!!': 207,
#  'ojamajo doremi': 672,
#  'pastel chime': 117,
#  'wild arms': 1367,
#  'wild arms 1': 280,
#  'final fantasy xi': 3054,
#  'saya no uta': 633,
#  'guilty gear': 15414,
#  'rozen maiden': 8016,
#  'princess tutu': 370,
#  'shinrabanshou': 2210,
#  'overman king gainer': 251,
#  'shoujo kakumei utena': 1043,
#  'gosick': 516,
#  'mushihime-sama': 147,
#  'breath of fire ii': 744,
#  'fate/unlimited blade works': 247,
#  'utawarerumono': 1724,
#  'kidou senkan nadesico': 943,
#  'kizuato': 225,
#  'fushigiboshi no futago hime': 441,
#  'grand theft auto': 310,
#  'zero no tsukaima': 3209,
#  'capcom fighting jam': 789,
#  'moomin': 808,
#  'top wo nerae 2!': 412,
#  'zone of the enders': 269,
#  'snk': 3507,
#  'the king of fighters': 11306,
#  'super robot wars': 4158,
#  'super robot wars judgement': 119,
#  'air (visual novel)': 1587,
#  'alice in wonderland': 3440,
#  'gunxsword': 147,
#  'samurai spirits': 2876,
#  'shakugan no shana': 2397,
#  'd.gray-man': 710,
#  'stratos 4': 110,
#  'kakyuusei 2': 309,
#  'downtown no gaki no tsukai ya arahende!!': 223,
#  'wagaya no oinari-sama': 125,
#  'kimi kiss': 1058,
#  'death note': 1156,
#  'suigetsu': 634,
#  'quiz magic academy': 1263,
#  'kore ga watashi no goshujin-sama': 262,
#  'berserk': 1687,
#  'my-otome': 935,
#  'fatal fury': 4195,
#  'type-moon': 995,
#  'mobile suit gundam': 2717,
#  'kimi ga nozomu eien': 502,
#  'futakoi': 190,
#  'ninin ga shinobuden': 243,
#  'uchuu no stellvia': 283,
#  'world cup': 841,
#  'the end of evangelion': 180,
#  'white album': 150,
#  'white album (series)': 292,
#  '.hack//': 808,
#  '.hack//tasogare no udewa densetsu': 121,
#  'black cat (series)': 136,
#  'pure pure': 148,
#  'planetarian': 249,
#  'futaba channel': 1260,
#  'monster (manga)': 114,
#  'da capo': 1035,
#  'da capo i': 406,
#  'kuso miso technique': 383,
#  'warzard': 121,
#  'shaman king': 524,
#  'summon night': 1390,
#  'summon night 3': 556,
#  'mushishi': 314,
#  'aquarian age': 181,
#  'sony': 444,
#  'versailles no bara': 191,
#  '2channel': 356,
#  'mahoraba': 175,
#  'yoake mae yori ruri iro na': 466,
#  'gensou suikoden': 1535,
#  'gensou suikoden iv': 161,
#  'wonder festival': 217,
#  'kaleido star': 228,
#  'sakura musubi': 162,
#  'nippon ichi': 335,
#  'phantom kingdom': 194,
#  'mujin wakusei survive': 128,
#  'di gi charat': 1539,
#  'kara no kyoukai': 2508,
#  'lunar': 116,
#  'busou renkin': 221,
#  'beat angel escalayer': 166,
#  'lyrical nanoha': 20315,
#  'mahou shoujo lyrical nanoha': 9818,
#  'clannad': 4734,
#  'tenshi no inai 12-gatsu': 124,
#  "mahou shoujo lyrical nanoha a's": 4953,
#  'comic party': 277,
#  'chobits': 466,
#  'space channel 5': 108,
#  'ichigo 100 percent': 274,
#  'mahoromatic': 375,
#  'senkou no ronde': 215,
#  'azumanga daioh': 1985,
#  'to heart 2 xrated': 128,
#  'aquarion (series)': 976,
#  'bokusatsu tenshi dokuro-chan': 240,
#  'national basketball association': 222,
#  'slam dunk (series)': 995,
#  'mabinogi': 1705,
#  'embodiment of scarlet devil': 1128,
#  'kamen rider': 6797,
#  'kamen rider hibiki (series)': 161,
#  'full moon wo sagashite': 143,
#  'moetan': 287,
#  'doraemon': 1177,
#  'saint seiya': 1097,
#  "girl's avenue": 116,
#  'wacom': 248,
#  'bobobo-bo bo-bobo': 212,
#  'lupin iii': 996,
#  'jinki': 235,
#  'nanatsuiro drops': 278,
#  'space adventure cobra': 157,
#  'namco': 193,
#  'summon night 2': 312,
#  'jingai makyou': 108,
#  'ghost in the shell': 1493,
#  'school days': 558,
#  'muv-luv': 2601,
#  'akira (manga)': 553,
#  'bemani': 449,
#  'hanshin tigers': 122,
#  'nippon professional baseball': 773,
#  'saber marionette j': 206,
#  'nijiura maids': 738,
#  'tales of (series)': 12457,
#  'tales of eternia': 382,
#  'pia carrot (series)': 329,
#  'pia carrot e youkoso!! 3': 158,
#  'kill bill': 107,
#  'sister princess': 711,
#  'dengeki hime': 234,
#  'shaft': 119,
#  'school rumble': 772,
#  'mega man (classic)': 2631,
#  'mega man (series)': 8446,
#  'naruto (series)': 12406,
#  'naruto shippuuden': 4249,
#  'g-taste': 142,
#  'the ring': 900,
#  'harry potter (series)': 1334,
#  'wizarding world': 1518,
#  'hellsing': 856,
#  'keroro gunsou': 1237,
#  'record of lodoss war': 507,
#  'oneechanbara': 133,
#  'abenobashi mahou shoutengai': 101,
#  'gantz': 447,
#  'witchblade': 422,
#  'scryed': 260,
#  'f-ism': 578,
#  'r.o.d the tv': 198,
#  'read or die': 489,
#  'lineage': 201,
#  'lineage 2': 151,
#  'seikai no senki': 160,
#  'g gundam': 1125,
#  'ai yori aoshi': 149,
#  'after war gundam x': 343,
#  'urusei yatsura': 2264,
#  'terminator (series)': 339,
#  'the terminator': 237,
#  'black lagoon': 1644,
#  'snow fox': 153,
#  'hidamari sketch': 2423,
#  'flcl': 701,
#  'comic rin': 170,
#  'peace@pieces': 149,
#  'phantasy star': 4957,
#  'phantasy star online': 164,
#  'trigun': 1184,
#  'tales of the abyss': 1645,
#  'zeta gundam': 1871,
#  'tekken': 3583,
#  'bishoujo senshi sailor moon': 13103,
#  'bashamichi': 135,
#  'eiyuu densetsu': 4795,
#  'soulcalibur': 2329,
#  'sega': 526,
#  'seiken densetsu': 1988,
#  'seiken densetsu 3': 1576,
#  'tombow mono': 127,
#  'dragon ball': 16106,
#  'dragon ball z': 7712,
#  'majo no takkyuubin': 953,
#  'one - kagayaku kisetsu e': 203,
#  'rumble roses': 242,
#  'naruto': 7231,
#  'sakura taisen': 1420,
#  'sakura taisen iii': 343,
#  'yotsunoha': 147,
#  'star wars': 2444,
#  'aria (manga)': 2113,
#  'samurai champloo': 165,
#  'fullmetal alchemist': 4129,
#  'macross': 8313,
#  'macross 7': 573,
#  'ace attorney': 4321,
#  'touhou (pc-98)': 10378,
#  'ikkitousen': 2229,
#  'girls bravo': 102,
#  "pop'n music": 577,
#  'kannazuki no miko': 431,
#  'megami magazine deluxe': 128,
#  'howl no ugoku shiro': 517,
#  'ghost in the shell stand alone complex': 565,
#  'beatmania iidx': 1176,
#  'tenjou tenge': 190,
#  'dengeki moeou': 1452,
#  'omc': 136,
#  'tonari no totoro': 669,
#  'popotan': 133,
#  'sunrise (company)': 228,
#  'ryuuko no ken': 1109,
#  'final fantasy iv': 2058,
#  'one piece': 18340,
#  "queen's blade": 5314,
#  'pokemon (classic anime)': 2765,
#  'kao no nai tsuki': 257,
#  'super smash bros.': 7685,
#  'the legend of zelda': 21334,
#  'aa megami-sama': 1057,
#  'meitantei conan': 2477,
#  'ranma 1/2': 3450,
#  'the matrix': 101,
#  'donkey kong (series)': 694,
#  'game & watch': 173,
#  'onegai twins': 187,
#  'genmukan': 102,
#  'futari wa precure max heart': 543,
#  'eyeshield 21': 362,
#  'star ocean': 2845,
#  'star ocean till the end of time': 838,
#  'firefox': 161,
#  'elysion': 203,
#  'sound horizon': 796,
#  'doki doki majo shinpan': 106,
#  'quilt (game)': 134,
#  'kodomo no jikan': 679,
#  'studio ghibli': 1018,
#  'monster hunter (series)': 7789,
#  "mcdonald's": 2056,
#  'suzumiya haruhi no yuuutsu': 18916,
#  'madou monogatari': 908,
#  'puyopuyo': 3220,
#  'demonbane': 437,
#  'maburaho': 160,
#  'bakuretsu tenshi': 141,
#  'galge.com': 409,
#  'tsugumomo': 529,
#  'elfen lied': 250,
#  'oshioki sweetie': 166,
#  'winnie the pooh': 176,
#  'little busters!': 4956,
#  'dragon quest iv': 1761,
#  'trickster': 221,
#  'to heart 2 ad': 350,
#  'blame!': 479,
#  'advance wars': 173,
#  'pokemon gsc': 1964,
#  'memories off': 323,
#  'final fantasy iii': 363,
#  'yakin byoutou': 145,
#  'kashimashi': 167,
#  'gundam sentinel': 217,
#  'advance of zeta': 118,
#  'jojo no kimyou na bouken': 25594,
#  'air gear': 203,
#  'kujibiki unbalance': 122,
#  'minami-ke': 925,
#  'aquaplus': 196,
#  'ryuu ga gotoku (series)': 929,
#  'ryuu ga gotoku 1': 141,
#  'noir (anime)': 104,
#  'soukou kihei votoms': 250,
#  'inuyasha': 1790,
#  'granado espada': 172,
#  'microsoft': 333,
#  'microsoft windows': 390,
#  'strike witches: kurenai no majo-tachi': 807,
#  'world witches series': 21783,
#  'agent aika': 714,
#  'aika (series)': 832,
#  'f-zero': 370,
#  'guilty gear xx': 1245,
#  'gundam 08th ms team': 371,
#  'kaitou saint tail': 147,
#  'kiddy grade': 266,
#  'langrisser': 340,
#  'magic knight rayearth': 615,
#  'megami paradise': 101,
#  'shin megami tensei': 1737,
#  'super robot wars the lord of elemental': 241,
#  'tales of destiny': 274,
#  'valkyrie profile (series)': 625,
#  'bible black': 171,
#  'demento': 127,
#  'serial experiments lain': 830,
#  'shinkon gattai godannar!!': 186,
#  'hikaru no go': 263,
#  'medarot': 390,
#  "grimm's fairy tales": 579,
#  'little red riding hood': 1599,
#  'yu-gi-oh!': 17885,
#  'yu-gi-oh! gx': 2154,
#  'muv-luv alternative': 1971,
#  'dragon quest iii': 2499,
#  'breath of fire iv': 386,
#  'breath of fire v': 437,
#  'queen (band)': 115,
#  'comic kairakuten': 384,
#  'romancing saga': 210,
#  'saga': 1334,
#  'namco x capcom': 166,
#  'fire emblem': 69411,
#  'fire emblem: mystery of the emblem': 3578,
#  'nhk ni youkoso!': 199,
#  'kobeya': 247,
#  'melonbooks': 1952,
#  'shining (series)': 1266,
#  'shining tears': 175,
#  'mushiking': 114,
#  'cyberbots': 168,
#  'bakumatsu rouman': 230,
#  'nogizaka haruka no himitsu': 181,
#  'super robot wars original generation': 1082,
#  'little tail bronx': 108,
#  'the big o': 242,
#  'macross zero': 120,
#  'sangokushi taisen': 455,
#  're leaf': 109,
#  'battle athletes': 155,
#  'marvel': 7995,
#  'spider-man (series)': 3490,
#  'kfc': 626,
#  "the king of fighters '97": 135,
#  'tsubasa chronicle': 220,
#  'dirty pair': 504,
#  'doukutsu monogatari': 366,
#  'galaxy angel rune': 183,
#  'tom and jerry': 134,
#  'c.c. lemon': 314,
#  'vandread': 116,
#  'hunter x hunter': 4243,
#  'mermaid melody pichi pichi pitch': 621,
#  'kamen rider blade (series)': 254,
#  'rance (series)': 1235,
#  'pita ten': 155,
#  'mega man battle network (series)': 877,
#  'last exile': 335,
#  'street fighter ii (series)': 905,
#  'street fighter iii (series)': 1243,
#  'street fighter zero (series)': 2143,
#  'final fantasy vi': 2597,
#  'yu yu hakusho': 950,
#  'juuni kokuki': 239,
#  'fire emblem: thracia 776': 697,
#  'kusari hime: euthanasia': 104,
#  'ico': 288,
#  'hayate no gotoku!': 2240,
#  'fruits basket': 213,
#  'justice gakuen': 549,
#  'shiritsu justice gakuen': 244,
#  'stardust crusaders': 4595,
#  '4chan': 455,
#  'metal gear (series)': 2903,
#  'metal gear solid': 1105,
#  'super blackjack': 328,
#  'taiho shichauzo': 326,
#  'saru getchu': 406,
#  'south park': 644,
#  'dungeons and dragons': 1346,
#  'pac-man (game)': 351,
#  'dewprism': 143,
#  'da capo ii': 460,
#  'hokuto no ken': 816,
#  'pikmin (series)': 975,
#  'garou: mark of the wolves': 484,
#  "heaven's feel": 787,
#  'sakura taisen v': 204,
#  'pia carrot e youkoso!! g.o.': 102,
#  'atelier (series)': 6763,
#  'atelier marie': 113,
#  'metal slug': 949,
#  'phantom brave': 174,
#  'kidou keisatsu patlabor': 399,
#  'resort boin': 234,
#  'tales of symphonia': 1349,
#  'devil may cry (series)': 2093,
#  'cutie honey': 301,
#  'chibi maruko-chan': 119,
#  'ys': 542,
#  'final fantasy tactics': 2023,
#  'asobi ni iku yo!': 276,
#  'romancing saga minstrel song': 122,
#  "wcdonald's": 131,
#  'rosario+vampire': 767,
#  'athena (series)': 178,
#  'tales of legendia': 271,
#  'newtype': 1059,
#  'crossbone gundam': 225,
#  'gundam f91': 226,
#  'mother (game)': 1544,
#  'mother 2': 938,
#  'coca-cola': 437,
#  'sen to chihiro no kamikakushi': 739,
#  'beauty and the beast': 168,
#  'disney': 957,
#  'sentimental graffiti': 258,
#  'ghost sweeper mikami': 168,
#  'xxxholic': 187,
#  'spectral (series)': 147,
#  'magic: the gathering': 454,
#  'ginga tetsudou 999': 184,
#  'final fantasy v': 1969,
#  'sky girls': 223,
#  'lucky star': 10768,
#  'fatal frame': 614,
#  'fatal frame 2': 240,
#  'pringles': 181,
#  'chrono crusade': 213,
#  'final fantasy xii': 1139,
#  'nintendo': 1453,
#  'strike witches zero': 361,
#  'virtual on': 272,
#  'gundam 0080': 365,
#  'imperishable night': 641,
#  'comic aun': 366,
#  'google': 239,
#  'touhou sangetsusei': 122,
#  'druaga no tou': 317,
#  'xenosaga episode iii': 486,
#  'dungeon and fighter': 3679,
#  'doukyuusei 2': 312,
#  'katawa shoujo': 1146,
#  'bakuretsu hunters': 160,
#  'pokemon frlg': 3637,
#  'hentai key': 185,
#  'the legend of zelda: twilight princess': 3215,
#  'dead or alive xtreme': 488,
#  'variable geo': 107,
#  'mega man zero (series)': 1128,
#  'mega man legends (series)': 544,
#  'final fantasy i': 302,
#  'djmax': 318,
#  'djmax portable': 167,
#  'guilty gear x': 255,
#  'fire emblem: the blazing blade': 4425,
#  'pokemon rse': 3283,
#  'fire emblem: genealogy of the holy war': 3462,
#  'fii-tan the figure': 128,
#  'pokemon: the electric tale of pikachu': 238,
#  'strike witches': 15059,
#  'turn a gundam': 726,
#  'valkyrie no densetsu': 210,
#  'final fantasy crystal chronicles': 139,
#  'powerpuff girls': 657,
#  'yu-gi-oh! duel monsters': 3589,
#  'chrono trigger': 989,
#  'mahou no tenshi creamy mami': 145,
#  'tokimeki memorial': 1093,
#  'tokimeki memorial 2': 337,
#  'kidou senkan nadesico - prince of darkness': 100,
#  'waku waku 7': 177,
#  'digimon': 5742,
#  'digimon frontier': 235,
#  'star ocean the second story': 781,
#  'transformers': 3733,
#  'legend of mana': 196,
#  'ever 17': 146,
#  'hentai kamen': 116,
#  'hamtaro (series)': 129,
#  'dragon quest ii': 627,
#  'narutaru': 158,
#  'zoids chaotic century': 124,
#  'mahou shoujo lyrical nanoha strikers': 9347,
#  'tenkuu no shiro laputa': 419,
#  'joshi kousei': 102,
#  'dr pepper': 342,
#  'eternity sword series': 163,
#  'kino no tabi': 1026,
#  'highschool of the dead': 889,
#  'taimanin (series)': 3208,
#  'taimanin asagi': 1111,
#  'tenchi muyou!': 831,
#  'persona': 25095,
#  'persona 3': 6483,
#  'renkin san-kyuu magical pokaan': 583,
#  'gorillaz': 122,
#  'looney tunes': 195,
#  'capcom': 1586,
#  'resident evil': 5201,
#  'kingdom hearts': 2836,
#  'kingdom hearts ii': 614,
#  'powerpuff girls z': 516,
#  'resident evil 4': 1204,
#  'dragon ball gt': 990,
#  'tomb raider': 235,
#  'pokemon adventures': 2768,
#  'pokemon tcg': 853,
#  'phantasy star universe': 167,
#  'toki wo kakeru shoujo': 271,
#  'pumpkin scissors': 105,
#  'resident evil 3: nemesis': 464,
#  'marvel vs. capcom': 375,
#  'resident evil 1': 145,
#  'sono hanabira ni kuchizuke wo': 876,
#  'ookami (game)': 720,
#  'toradora!': 3471,
#  'metal gear solid 3: snake eater': 297,
#  'fate/kaleid liner prisma illya': 8585,
#  'bra-ban!': 131,
#  'rurouni kenshin': 603,
#  'simoun': 494,
#  'galgrease': 254,
#  'code geass': 11143,
#  'zegapain': 182,
#  'digimon adventure': 1316,
#  'pokemon dppt (anime)': 1432,
#  'the legend of zelda: ocarina of time': 2592,
#  'dirge of cerberus final fantasy vii': 106,
#  'shin sangoku musou': 713,
#  'prism ark': 111,
#  'incise soul': 111,
#  'futari wa precure splash star': 753,
#  'aerisdies': 114,
#  "shijou saikyou no deshi ken'ichi": 202,
#  'digimon adventure 02': 402,
#  'tokyo mew mew': 522,
#  '.hack//g.u.': 307,
#  'katekyo hitman reborn!': 996,
#  'strawberry panic!': 461,
#  'final fantasy viii': 1604,
#  'devil may cry 3': 461,
#  'jigoku sensei nube': 202,
#  'gintama': 3290,
#  'arcana heart': 1256,
#  'yozakura quartet': 187,
#  'to love-ru': 5594,
#  'parasite eve': 209,
#  'super real mahjong': 961,
#  'digimon tamers': 430,
#  'cyborg 009': 130,
#  'spice and wolf': 2809,
#  'majutsushi orphen': 296,
#  'tenchuu': 128,
#  'doukyuusei': 448,
#  'ouran high school host club': 275,
#  'cowboy bebop': 965,
#  'nitroplus': 4263,
#  'goodsmile company': 387,
#  'pokemon dppt': 9838,
#  'galhound': 205,
#  'metal gear solid 4: guns of the patriots': 301,
#  'key (company)': 653,
#  'full metal jacket': 101,
#  'shinkyoku soukai polyphonica': 312,
#  'metroid fusion': 160,
#  'ef': 514,
#  'suguri': 340,
#  'lost universe': 237,
#  'idolmaster xenoglossia': 239,
#  'gensou suikoden v': 399,
#  'acchi kocchi': 124,
#  'h2o footprints in the sand': 101,
#  'coyote ragtime show': 117,
#  'gegege no kitarou': 2825,
#  'touka gettan': 139,
#  'gensou suikoden i': 293,
#  "dengeki g's": 343,
#  'x-men': 1013,
#  'virtua fighter': 368,
#  'otogi-juushi akazukin': 162,
#  'wikipedia': 103,
#  'time bokan (series)': 669,
#  'yatterman': 563,
#  'castlevania (series)': 1187,
#  'super mario bros. 1': 625,
#  'dc comics': 5115,
#  'dragon quest vi': 403,
#  'gundam wing': 973,
#  'starcraft': 255,
#  'final fantasy ix': 2176,
#  'kannagi': 1530,
#  'tokimeki memorial 1': 204,
#  'kaitou tenshi twin angel': 207,
#  'twin angel': 235,
#  'harukanaru toki no naka de': 140,
#  'mugen no fantasia': 141,
#  'koihime musou': 1762,
#  'getbackers': 149,
#  'majin tantei nougami neuro': 176,
#  'kaibutsu oujo': 320,
#  'cream lemon': 182,
#  'dragon ball (classic)': 1810,
#  'predator (movie)': 209,
#  'outlaw star': 184,
#  'devilman': 380,
#  'mirai nikki': 878,
#  'dr. slump': 295,
#  'sakigake!! cromartie koukou': 106,
#  'tenkuu no escaflowne': 146,
#  'ikkitousen dragon destiny': 125,
#  'sora no kiseki': 759,
#  'pizza hut': 441,
#  'resident evil 0': 111,
#  'silent hill (series)': 707,
#  'silent hill 2': 290,
#  'silent hill 3': 228,
#  'luminous arc': 153,
#  'zone of the enders 2': 169,
#  'choujikuu yousai macross': 849,
#  'macross: do you remember love?': 413,
#  'grandia': 727,
#  'grandia ii': 118,
#  'momotarou densetsu': 158,
#  'wild arms 3': 243,
#  'tennis no ouji-sama': 251,
#  'bubblegum crisis': 119,
#  'fatal frame 3': 150,
#  'wild arms 5': 186,
#  'sekirei': 426,
#  'gag manga biyori': 131,
#  'seisenshi dunbine': 293,
#  'initial d': 222,
#  'busou shinki': 1177,
#  'victory gundam': 382,
#  'fantasy earth': 289,
#  'fantasy earth zero': 738,
#  'gundam 0083': 567,
#  'suzumiya haruhi-chan no yuuutsu': 179,
#  'akagi: yami ni oritatta tensai': 309,
#  'fukumoto mahjong': 341,
#  'fate/prototype': 4139,
#  'mega man x (series)': 1729,
#  "berry's": 101,
#  'ai tenshi densetsu wedding peach': 111,
#  'gakuen utopia manabi straight!': 252,
#  'trigger heart exelica': 116,
#  'maison ikkoku': 154,
#  'kingdom hearts i': 237,
#  'gensou suikoden iii': 195,
#  'sazae-san': 171,
#  'wild flower': 102,
#  'kaze no klonoa': 173,
#  'advent cirno': 232,
#  '.hack//games': 104,
#  'tamiya incorporated': 125,
#  'ultra series': 1433,
#  'moyashimon': 270,
#  'the elder scrolls': 589,
#  'castlevania: portrait of ruin': 173,
#  'mononoke hime': 748,
#  "foster's home for imaginary friends": 274,
#  'the grim adventures of billy & mandy': 117,
#  'thomas the tank engine': 105,
#  'sengoku rance': 427,
#  'devil summoner': 364,
#  'megami tensei': 154,
#  'persona 1': 263,
#  'persona 2': 469,
#  'persona 2 tsumi': 159,
#  'shin megami tensei iii: nocturne': 298,
#  'soul hackers': 168,
#  'final fight': 835,
#  'ninja gaiden': 187,
#  'codename: kids next door': 100,
#  'godzilla (series)': 1379,
#  'claymore (series)': 581,
#  'mega man zx': 740,
#  'warioware': 947,
#  'dodonpachi': 161,
#  'summon night 4': 127,
#  'comic penguin club': 235,
#  'rune factory': 864,
#  'alien (1979)': 114,
#  'alien (series)': 223,
#  'mortal kombat (series)': 346,
#  'warcraft': 1970,
#  'world of warcraft': 1735,
#  'doom (series)': 650,
#  'the beatles': 114,
#  'jikkyou powerful pro yakyuu': 376,
#  'power pro kun pocket': 208,
#  'lotus land story': 194,
#  'transformers: generation 1': 367,
#  'houshin engi': 381,
#  'sangoku musou 1': 186,
#  'aladdin (disney)': 198,
#  'cinderella': 303,
#  'sleeping beauty': 247,
#  'snow white and the seven dwarfs': 234,
#  'the little mermaid': 419,
#  'ganbare goemon': 221,
#  'gouma reifuden izuna': 123,
#  'sengoku musou': 581,
#  'sengoku musou 2': 122,
#  'kim possible (series)': 212,
#  'ar tonelico': 1318,
#  'ar tonelico i': 380,
#  'silver rain': 132,
#  'kamen rider kabuto (series)': 226,
#  'warhammer fantasy': 134,
#  'shadow of the colossus': 285,
#  'roman (sound horizon)': 143,
#  'black jack (series)': 292,
#  'final fantasy tactics advance': 203,
#  'tales of destiny 2': 308,
#  'teenage mutant ninja turtles': 268,
#  'olympics': 213,
#  'getter robo': 619,
#  'kimagure orange road': 188,
#  'tetris': 222,
#  'toranoana': 1448,
#  'super sentai': 1107,
#  'galaga': 3692,
#  'leon the professional': 125,
#  'duel masters': 240,
#  'comic lo': 199,
#  'resident evil 2': 538,
#  'mugen senshi valis': 166,
#  'meshimase idol': 116,
#  'chou shittou caduceus': 151,
#  'ace combat': 563,
#  'ginga eiyuu densetsu': 277,
#  'ace combat zero': 115,
#  'pepsi': 450,
#  'cthulhu mythos': 609,
#  'shining wind': 289,
#  'journey to the west': 689,
#  'kamen rider agito (series)': 167,
#  'kamen rider black (series)': 154,
#  'kiseijuu': 109,
#  'bandai': 349,
#  'city hunter': 196,
#  'puyopuyo~n': 109,
#  'monster farm': 226,
#  'ikazuchi no senshi raidy': 124,
#  'castlevania: symphony of the night': 143,
#  'digimon savers': 105,
#  'needless': 154,
#  'magna carta': 107,
#  'gensou suikoden ii': 410,
#  'comic tenma': 130,
#  'halo (series)': 500,
#  'densetsu kyojin ideon': 126,
#  'zettai karen children': 443,
#  'wwe': 120,
#  'umi monogatari': 181,
#  'i want you': 122,
#  'wild arms 2': 487,
#  'zaregoto series': 193,
#  'tamagotchi': 183,
#  'viper': 313,
#  'tengen toppa gurren lagann': 8576,
#  'pokemon ranger': 136,
#  'shining musume': 111,
#  "bakusou kyoudai let's & go!!": 243,
#  'mazinger (series)': 651,
#  "char's counterattack": 948,
#  'felarya': 157,
#  'fire emblem: the binding blade': 3119,
#  'toaru majutsu no index': 20072,
#  'toaru majutsu no index: old testament': 847,
#  'juusenki l-gaim': 125,
#  'mazinger z': 440,
#  'shin getter robo': 241,
#  'crayon shin-chan': 397,
#  'wrestle angels': 575,
#  'genmu senki leda': 173,
#  'hello kitty': 623,
#  'mad max': 141,
#  'yume nikki': 1845,
#  'snow white': 419,
#  'dream hunter rem': 175,
#  'little match girl': 108,
#  'dragon quest i': 158,
#  'ano ko wa toshi densetsu': 240,
#  'emil chronicle online': 301,
#  'anpanman': 167,
#  'kurenai no buta': 150,
#  'robotech': 207,
#  'the lion king': 121,
#  'steel ball run': 2128,
#  'romancing saga 2': 191,
#  'metroid: zero mission': 121,
#  'world masterpiece theater': 143,
#  'kakyuusei': 367,
#  'gakkou de seishun!': 124,
#  'battle angel alita': 255,
#  'gundam card builder': 137,
#  'star trek': 182,
#  'oretachi ni tsubasa wa nai': 114,
#  'honest axe': 183,
#  'suzumiya haruhi no shoushitsu': 1421,
#  'the king of fighters 2001': 153,
#  'square enix': 644,
#  'tekkaman blade': 113,
#  'kamikaze kaitou jeanne': 185,
#  'casshern (series)': 148,
#  'shounen jump': 194,
#  'haou taikei ryuu knight': 164,
#  'animage': 171,
#  'rakudai ninja rantarou': 288,
#  'my life as a teenage robot': 157,
#  'eiken': 124,
#  'mario kart': 650,
#  'grandia i': 512,
#  'beyblade': 281,
#  'jet set radio': 221,
#  'the simpsons': 186,
#  'street fighter ex (series)': 126,
#  'chrono cross': 814,
#  'mahou shoujo ai': 114,
#  'romancing saga 3': 152,
#  'macross plus': 151,
#  'half-life (series)': 160,
#  'pokemon rgby': 2450,
#  'kamen rider (1st series)': 210,
#  'mother 3': 693,
#  'the legend of zelda: the wind waker': 1106,
#  'tetsuwan birdy': 181,
#  'batman (series)': 1826,
#  'five star stories': 165,
#  'corrector yui': 111,
#  'gundam msv': 200,
#  'ao no roku-gou': 208,
#  'tales of phantasia': 465,
#  'uchuu senkan yamato': 1039,
#  'street fighter iv (series)': 2080,
#  'tales of rebirth': 126,
#  'eternal arcadia': 116,
#  'animedia': 183,
#  'saga frontier': 289,
#  'fate/zero': 10934,
#  'svc chaos': 124,
#  'mother 1': 151,
#  'arc the lad': 564,
#  'akazukin chacha': 100,
#  'dancouga (series)': 121,
#  'mahoujin guruguru': 301,
#  'tear ring saga': 131,
#  'cyberpunk (series)': 2804,
#  'dr. mario (game)': 126,
#  'marl kingdom': 257,
#  'rhapsody': 177,
#  'osu! tatakae! ouendan': 130,
#  'beast wars': 236,
#  'shadow hearts': 207,
#  'ghostbusters': 155,
#  'internet explorer': 186,
#  'avatar: the last airbender': 857,
#  'avatar legends': 1825,
#  'pokemon emerald': 797,
#  'soukyuu no fafner': 477,
#  'm.u.g.e.n': 2248,
#  'nagato yuki-chan no shoushitsu': 193,
#  'metal gear solid 2: sons of liberty': 176,
#  'bokujou monogatari': 270,
#  'kamen rider black rx (series)': 103,
#  'super metroid': 107,
#  'paper mario': 531,
#  'paper mario: the thousand year door': 197,
#  'nazo no kanojo x': 248,
#  'final fantasy ii': 294,
#  'red bull': 427,
#  'greek mythology': 369,
#  'peanuts': 372,
#  'super robot wars og saga mugen no frontier': 529,
#  'ookiku furikabutte': 199,
#  'tekken 6': 171,
#  'comic megastore': 134,
#  'seto no hanayome': 402,
#  'teen titans': 1218,
#  'dragon quest dai no daibouken': 297,
#  ...}

# %%
copyright_tags = [tag for tag in copyright_tags if tag in copyright_tag_counts]
character_tags = [tag for tag in character_tags if tag in character_tag_counts]

# %%
len(copyright_tags)
# Out:
# 3439

# %%
len(character_tags)
# Out:
# 12171

# %% [markdown]
# ## Save tags

# %%
with open("./general-general.txt", "w", encoding="utf-8") as file:
    file.write("\n".join(general_general_tags))
with open("./general-sensitive.txt", "w", encoding="utf-8") as file:
    file.write("\n".join(general_sensitive_tags))
with open("./general-questionable.txt", "w", encoding="utf-8") as file:
    file.write("\n".join(general_questionable_tags))
with open("./general-explicit.txt", "w", encoding="utf-8") as file:
    file.write("\n".join(general_explicit_tags))
with open("./copyright.txt", "w", encoding="utf-8") as file:
    file.write("\n".join(copyright_tags))
with open("./character.txt", "w", encoding="utf-8") as file:
    file.write("\n".join(character_tags))
