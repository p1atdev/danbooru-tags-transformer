# %% [markdown]
# ## Imports

# %%
from datasets import load_dataset, Dataset
from tokenizers import Tokenizer, AddedToken, Regex
from tokenizers.models import WordLevel
from tokenizers.pre_tokenizers import Split
from tokenizers.normalizers import Lowercase
from transformers import PreTrainedTokenizerFast

# %%
import matplotlib.pyplot as plt
import numpy as np
import json
from tqdm import tqdm

# %%
DATASET_REPO_ID = "isek-ai/danbooru-tags-2024"
DATASET_NAME = "202402-at20240326"
DATASET_SPLIT = "train"

# %% [markdown]
# ## Load dataset

# %%
def prepare_dataset():
    ds = load_dataset(DATASET_REPO_ID, name=DATASET_NAME, split=DATASET_SPLIT)
    print(ds)
    return ds


ds = prepare_dataset()
# Out:
# Dataset({
#     features: ['id', 'copyright', 'character', 'artist', 'general', 'meta', 'rating', 'score', 'created_at'],
#     num_rows: 7124975
# })

# %%
def load_from_json(path: str):
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f)


def save_to_json(data, path: str):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

# %% [markdown]
# ## Investigate the dataset

# %%
def get_count_map(column_name: str):
    count_map = {}

    for text in tqdm(ds[column_name]):
        if text is None:
            continue
        for tag in text.split(", "):
            if tag not in count_map:
                count_map[tag] = 1
            count_map[tag] += 1

    count_map = {
        k: v for k, v in sorted(count_map.items(), key=lambda x: x[1], reverse=True)
    }
    return count_map


general_tags_count_map = get_count_map("general")
save_to_json(general_tags_count_map, "./tmp/general_tags_count_map.json")
general_tags_count_map
# Out:
# 100%|██████████| 7124975/7124975 [00:30<00:00, 234279.24it/s]
# {'1girl': 5071347,
#  'solo': 4233465,
#  'long hair': 3626142,
#  'breasts': 2868312,
#  'looking at viewer': 2693349,
#  'blush': 2479142,
#  'smile': 2355676,
#  'open mouth': 1938878,
#  'short hair': 1893313,
#  'blue eyes': 1482719,
#  'simple background': 1417790,
#  'shirt': 1381800,
#  'large breasts': 1321698,
#  'skirt': 1321065,
#  'blonde hair': 1301381,
#  'multiple girls': 1296493,
#  'brown hair': 1258113,
#  'black hair': 1219721,
#  'long sleeves': 1198509,
#  'hair ornament': 1168485,
#  'white background': 1161490,
#  '1boy': 1113347,
#  'gloves': 1109069,
#  'red eyes': 1075554,
#  'dress': 1044181,
#  'hat': 1026066,
#  'thighhighs': 1025587,
#  'holding': 1024716,
#  'bow': 980035,
#  'navel': 968152,
#  'animal ears': 946708,
#  'ribbon': 931157,
#  'hair between eyes': 922360,
#  'closed mouth': 878554,
#  '2girls': 853719,
#  'cleavage': 844904,
#  'jewelry': 828390,
#  'bare shoulders': 812866,
#  'very long hair': 780557,
#  'sitting': 779450,
#  'medium breasts': 765635,
#  'twintails': 765380,
#  'brown eyes': 742110,
#  'standing': 734702,
#  'nipples': 709352,
#  'green eyes': 707488,
#  'jacket': 702004,
#  'blue hair': 700505,
#  'underwear': 699922,
#  'school uniform': 682345,
#  'purple eyes': 666807,
#  'collarbone': 653253,
#  'tail': 631464,
#  'white shirt': 630080,
#  'full body': 624850,
#  'upper body': 596996,
#  'panties': 574818,
#  'white hair': 564083,
#  'yellow eyes': 563533,
#  'closed eyes': 561754,
#  'swimsuit': 560031,
#  'pink hair': 548691,
#  'monochrome': 542279,
#  'grey hair': 529989,
#  'ahoge': 526517,
#  'braid': 522717,
#  'hair ribbon': 521960,
#  'purple hair': 520624,
#  'male focus': 518079,
#  'flower': 510623,
#  'ponytail': 510503,
#  'ass': 505875,
#  'weapon': 504332,
#  'multicolored hair': 502466,
#  'short sleeves': 498314,
#  'sidelocks': 483201,
#  'comic': 472692,
#  'heart': 466389,
#  'thighs': 462811,
#  ':d': 462263,
#  'hetero': 455949,
#  'hair bow': 452971,
#  'cowboy shot': 440322,
#  'pantyhose': 439616,
#  'outdoors': 437390,
#  'earrings': 434668,
#  'greyscale': 428015,
#  'bikini': 422962,
#  'sweat': 422290,
#  'red hair': 420978,
#  'pleated skirt': 415717,
#  'nude': 413510,
#  'small breasts': 411566,
#  'frills': 401870,
#  'hairband': 396241,
#  'parted lips': 396080,
#  'open clothes': 384474,
#  'boots': 383146,
#  'censored': 381035,
#  'lying': 375323,
#  'horns': 373315,
#  'teeth': 370069,
#  'multiple boys': 364120,
#  'wings': 364004,
#  'food': 360587,
#  'necktie': 359298,
#  'one eye closed': 358327,
#  'detached sleeves': 356672,
#  'sky': 355525,
#  'shorts': 345419,
#  'japanese clothes': 342911,
#  'green hair': 342469,
#  'shoes': 342315,
#  'sleeveless': 341402,
#  'penis': 332984,
#  'alternate costume': 331755,
#  'black gloves': 331249,
#  'collared shirt': 323681,
#  'choker': 320788,
#  'barefoot': 314797,
#  'socks': 308992,
#  'tongue': 307005,
#  'glasses': 306788,
#  'pussy': 306198,
#  'pointy ears': 306056,
#  'pants': 303922,
#  'solo focus': 295956,
#  'day': 292461,
#  'virtual youtuber': 285901,
#  'serafuku': 282581,
#  'puffy sleeves': 281150,
#  'hairclip': 278952,
#  'artist name': 278649,
#  'indoors': 278291,
#  'medium hair': 274323,
#  'belt': 271956,
#  'black thighhighs': 270349,
#  'fang': 267720,
#  'hand up': 267240,
#  'elbow gloves': 263709,
#  'midriff': 257546,
#  'looking back': 243428,
#  'cloud': 242860,
#  'white gloves': 241406,
#  'signature': 239083,
#  'bowtie': 235672,
#  'hood': 235147,
#  'sword': 233823,
#  'black skirt': 233036,
#  'dark skin': 231184,
#  'cat ears': 231128,
#  '2boys': 230896,
#  'blunt bangs': 229026,
#  'hair flower': 228945,
#  'official alternate costume': 227898,
#  'tongue out': 223665,
#  'pink eyes': 219457,
#  'sailor collar': 217698,
#  'wide sleeves': 217148,
#  'spread legs': 216916,
#  'miniskirt': 216309,
#  'stomach': 215823,
#  'fingerless gloves': 214667,
#  'sex': 213152,
#  'black footwear': 212803,
#  'grey background': 211728,
#  'on back': 211208,
#  'tears': 210247,
#  'cum': 210067,
#  '3girls': 208697,
#  'armpits': 206100,
#  'twitter username': 203230,
#  'kimono': 202564,
#  'white dress': 200560,
#  'holding weapon': 199926,
#  'off shoulder': 198522,
#  'necklace': 198086,
#  'striped clothes': 197840,
#  'hair bun': 195427,
#  'nail polish': 194126,
#  'star (symbol)': 193711,
#  'looking at another': 192845,
#  'mole': 192788,
#  'from behind': 192202,
#  'hair over one eye': 191196,
#  'water': 190202,
#  'bag': 188787,
#  'rabbit ears': 188063,
#  'orange hair': 187215,
#  'blurry': 186318,
#  'chibi': 184727,
#  'grin': 184408,
#  'sweatdrop': 183234,
#  'clothes lift': 181132,
#  'black dress': 181075,
#  'scarf': 179178,
#  'cape': 178333,
#  'two-tone hair': 177720,
#  'white thighhighs': 177374,
#  'black eyes': 176765,
#  'speech bubble': 176138,
#  'english text': 174956,
#  'streaked hair': 174775,
#  'halo': 174441,
#  'from side': 173497,
#  'open jacket': 173413,
#  'armor': 172790,
#  'bra': 172493,
#  'yuri': 172268,
#  'vest': 171707,
#  'huge breasts': 170640,
#  'apron': 170234,
#  'arm up': 167582,
#  'feet': 167525,
#  'red bow': 167496,
#  'black jacket': 165201,
#  'coat': 165047,
#  'character name': 164577,
#  'white panties': 164425,
#  'mosaic censoring': 163716,
#  'leotard': 163662,
#  'high heels': 162775,
#  ':o': 160247,
#  'vaginal': 159764,
#  'collar': 157796,
#  'sweater': 157283,
#  'arms up': 156627,
#  'bracelet': 154404,
#  'dated': 153341,
#  'blue sky': 153174,
#  'twin braids': 151719,
#  'flat chest': 151592,
#  'uniform': 150234,
#  'crop top': 149431,
#  'side ponytail': 148900,
#  'animal ear fluff': 148198,
#  'red ribbon': 147517,
#  'black shirt': 147397,
#  'cup': 146570,
#  'aqua eyes': 146037,
#  'dark-skinned female': 145915,
#  'black pantyhose': 143741,
#  'parted bangs': 142439,
#  'puffy short sleeves': 142345,
#  'covered nipples': 142062,
#  'fingernails': 141866,
#  'blue skirt': 141761,
#  'two side up': 141244,
#  'completely nude': 140675,
#  'tree': 139488,
#  'hands up': 139450,
#  'looking to the side': 137755,
#  'grey eyes': 136744,
#  'v-shaped eyebrows': 136666,
#  'orange eyes': 135390,
#  'legs': 134191,
#  'neckerchief': 133935,
#  'sleeves past wrists': 131284,
#  'sketch': 130305,
#  'symbol-shaped pupils': 130224,
#  'cat tail': 129779,
#  'eyelashes': 129069,
#  'groin': 128611,
#  'fur trim': 127743,
#  'see-through': 126901,
#  'wet': 126894,
#  'wrist cuffs': 126240,
#  'hand on own hip': 125544,
#  'lips': 124877,
#  'loli': 123290,
#  'strapless': 122315,
#  'head tilt': 121768,
#  'clothing cutout': 121676,
#  'gun': 121492,
#  'pillow': 121385,
#  'zettai ryouiki': 121308,
#  'maid': 121260,
#  'plaid': 120492,
#  'multiple views': 120122,
#  'mole under eye': 120009,
#  'toes': 119943,
#  'bar censor': 119939,
#  'torn clothes': 119461,
#  'fox ears': 119221,
#  'one-piece swimsuit': 118085,
#  'sash': 117717,
#  'book': 117493,
#  'sleeveless dress': 117367,
#  'sleeveless shirt': 117246,
#  'maid headdress': 116955,
#  'feet out of frame': 116939,
#  'short shorts': 116793,
#  'bare arms': 116656,
#  'gradient background': 116020,
#  'v': 115319,
#  'ascot': 115239,
#  'pubic hair': 114524,
#  'black panties': 114238,
#  'shiny skin': 114117,
#  'cosplay': 113901,
#  'sparkle': 113870,
#  'pokemon (creature)': 113620,
#  'muscular': 112705,
#  'fake animal ears': 112658,
#  'petals': 111714,
#  'bare legs': 110903,
#  'no humans': 110898,
#  'kneehighs': 110359,
#  'window': 109374,
#  'thigh strap': 108311,
#  'black bow': 108310,
#  'single braid': 107404,
#  'covered navel': 107287,
#  'neck ribbon': 106799,
#  'black ribbon': 106510,
#  'hoodie': 106142,
#  'black choker': 105914,
#  'upper teeth only': 105805,
#  'gradient hair': 105673,
#  'detached collar': 105359,
#  'buttons': 104779,
#  'tattoo': 104661,
#  'uncensored': 104647,
#  'dutch angle': 104176,
#  'double bun': 104159,
#  'dress shirt': 104150,
#  'black legwear': 104055,
#  'blurry background': 103499,
#  'profile': 102494,
#  'open shirt': 102349,
#  'sideboob': 100796,
#  'kneeling': 100763,
#  'makeup': 100464,
#  'blood': 100384,
#  'bell': 100105,
#  'floating hair': 99117,
#  'hug': 99103,
#  'military': 98727,
#  'mask': 98428,
#  'aqua hair': 98349,
#  'colored skin': 98290,
#  'swept bangs': 98101,
#  'saliva': 97975,
#  'skindentation': 97595,
#  'capelet': 97521,
#  'facial hair': 97291,
#  'bodysuit': 96760,
#  'leaning forward': 96710,
#  '4girls': 95995,
#  'anus': 95970,
#  'black pants': 95942,
#  'blue dress': 95747,
#  'shadow': 94910,
#  'night': 94838,
#  'pov': 94558,
#  'copyright name': 94085,
#  'pussy juice': 93123,
#  'black bikini': 93057,
#  'bed': 93012,
#  'no bra': 92475,
#  ':3': 91622,
#  '4koma': 91280,
#  'heterochromia': 91080,
#  'depth of field': 90839,
#  'blue bow': 90239,
#  'nose blush': 90211,
#  'alternate hairstyle': 90096,
#  'red skirt': 90050,
#  'border': 89907,
#  'turtleneck': 89628,
#  'fruit': 89315,
#  'fox tail': 89003,
#  'blue background': 88591,
#  'highleg': 88238,
#  'expressionless': 88227,
#  'low twintails': 87882,
#  'siblings': 87832,
#  'military uniform': 87702,
#  'underboob': 87683,
#  'frown': 87458,
#  'witch hat': 87453,
#  'rose': 87399,
#  'horse ears': 87171,
#  '^_^': 87169,
#  'watermark': 87018,
#  'one side up': 86666,
#  'black shorts': 86597,
#  'bird': 86593,
#  'on bed': 86374,
#  'cameltoe': 86171,
#  'cum in pussy': 86149,
#  'no panties': 85952,
#  'scar': 85770,
#  'glowing': 85726,
#  'headband': 85563,
#  'beret': 83646,
#  'ocean': 83620,
#  'brown footwear': 83533,
#  'soles': 83484,
#  'animal': 83224,
#  'halterneck': 83190,
#  'wavy hair': 83130,
#  'bottomless': 83085,
#  'side-tie bikini bottom': 83039,
#  'holding hands': 82980,
#  'fangs': 82947,
#  'bed sheet': 82815,
#  'leaf': 82775,
#  'piercing': 82540,
#  'thick thighs': 82471,
#  'chain': 82440,
#  'playboy bunny': 82391,
#  'headphones': 82097,
#  'arm support': 81287,
#  'white jacket': 81133,
#  'from above': 80917,
#  'holding sword': 80736,
#  'embarrassed': 80619,
#  'white socks': 80544,
#  'hair intakes': 79886,
#  'chinese clothes': 78962,
#  'white bikini': 78412,
#  'back': 78158,
#  'ass visible through thighs': 77962,
#  'horse girl': 77845,
#  'thick eyebrows': 77714,
#  'no shoes': 77387,
#  'facial mark': 77342,
#  'phone': 77335,
#  'blush stickers': 77311,
#  'plaid skirt': 77062,
#  'abs': 76744,
#  'chair': 76492,
#  'looking down': 76343,
#  'umbrella': 76137,
#  'white footwear': 76113,
#  'bandages': 75961,
#  'thigh boots': 75671,
#  'erection': 75660,
#  'sandals': 75642,
#  'beach': 75523,
#  'half-closed eyes': 75459,
#  'muscular male': 75284,
#  'headgear': 75235,
#  'on side': 74912,
#  'female pubic hair': 74819,
#  'floral print': 74120,
#  '6+girls': 73841,
#  'short dress': 73297,
#  'bob cut': 73268,
#  'heart-shaped pupils': 73227,
#  'wariza': 72887,
#  'drill hair': 72832,
#  'garter straps': 72804,
#  'pectorals': 72693,
#  'red dress': 72567,
#  'black hat': 72564,
#  'sunglasses': 72337,
#  'obi': 72269,
#  'arms behind back': 72178,
#  'happy': 71802,
#  'traditional media': 71531,
#  'pink background': 71441,
#  'frilled dress': 70827,
#  'shirt lift': 70801,
#  'flying sweatdrops': 70667,
#  'hood down': 70428,
#  'stuffed toy': 70399,
#  'mouth hold': 70371,
#  'eating': 70317,
#  'clothes pull': 70275,
#  'grabbing': 70062,
#  'testicles': 69980,
#  'dark-skinned male': 69862,
#  'squatting': 69706,
#  'cleavage cutout': 69663,
#  'blue shirt': 69620,
#  'white skirt': 69597,
#  'transparent background': 69547,
#  'crossed arms': 68966,
#  'light brown hair': 68928,
#  'table': 68583,
#  'thigh gap': 68435,
#  'black socks': 68301,
#  'from below': 68220,
#  'white legwear': 68152,
#  'wavy mouth': 68141,
#  'holding food': 67985,
#  'ring': 67854,
#  'leg up': 67718,
#  'hair tubes': 67590,
#  'blue jacket': 67444,
#  'bound': 67270,
#  'white flower': 67105,
#  'wolf ears': 67000,
#  'black hairband': 66577,
#  'parody': 66322,
#  'moon': 65819,
#  'scrunchie': 65695,
#  'white bow': 65586,
#  'eyepatch': 65546,
#  'standing on one leg': 65515,
#  'skirt lift': 65445,
#  'sunlight': 65440,
#  'cat girl': 65013,
#  'oral': 64981,
#  'formal': 64574,
#  'trembling': 64511,
#  'topless': 64476,
#  'cat': 64458,
#  'demon girl': 64450,
#  'cardigan': 64149,
#  'mob cap': 63952,
#  'magical girl': 63098,
#  'backpack': 62873,
#  'looking away': 62766,
#  'cellphone': 62667,
#  'own hands together': 62365,
#  'demon horns': 62103,
#  'pantyshot': 61908,
#  'eyes visible through hair': 61865,
#  'crossed legs': 61768,
#  'frilled skirt': 61666,
#  'cover': 61287,
#  'tank top': 61003,
#  'cloudy sky': 60989,
#  'grass': 60976,
#  'crying': 60963,
#  'sharp teeth': 60940,
#  'single hair bun': 60607,
#  'blazer': 60558,
#  'suspenders': 60471,
#  'suit': 60392,
#  'high ponytail': 60378,
#  'sleeping': 60342,
#  'helmet': 60329,
#  'feathers': 60269,
#  '3boys': 59538,
#  'bottle': 59256,
#  'stuffed animal': 59172,
#  'x hair ornament': 59065,
#  'cum on body': 59008,
#  'underwear only': 58782,
#  'blue ribbon': 58769,
#  'portrait': 58746,
#  'black background': 58653,
#  'frilled sleeves': 58629,
#  'bdsm': 58571,
#  'fox girl': 58390,
#  'plant': 58323,
#  'light smile': 58309,
#  'bara': 58166,
#  'antenna hair': 58098,
#  'looking up': 57969,
#  'striped': 57925,
#  'school swimsuit': 57289,
#  'cross': 57264,
#  "grabbing another's breast": 57246,
#  'pink bow': 57000,
#  'bug': 56814,
#  'denim': 56782,
#  'hat ribbon': 56744,
#  'fire': 56712,
#  'red necktie': 56654,
#  'knee boots': 56630,
#  ';d': 56546,
#  'crown': 56495,
#  'lifted by self': 56092,
#  'tiara': 55825,
#  'outstretched arms': 55782,
#  'red flower': 55763,
#  'couple': 55598,
#  'katana': 55538,
#  'aged down': 54940,
#  'juliet sleeves': 54706,
#  'straddling': 54663,
#  'breasts out': 54640,
#  'motion lines': 54578,
#  'black nails': 54500,
#  'crossover': 54383,
#  'ear piercing': 54275,
#  'robot': 54140,
#  'on stomach': 54131,
#  'spiked hair': 54037,
#  'curtains': 54032,
#  'sisters': 53920,
#  'polka dot': 53868,
#  'fellatio': 53836,
#  'outstretched arm': 53807,
#  'knife': 53701,
#  'slit pupils': 53632,
#  '?': 53595,
#  'wing collar': 53454,
#  'bat wings': 53364,
#  'pointing': 53123,
#  'bright pupils': 52703,
#  'animal print': 52578,
#  'bent over': 52532,
#  'red shirt': 52290,
#  'elf': 52186,
#  'clenched teeth': 52139,
#  '>_<': 52121,
#  'white hat': 52085,
#  'white border': 51941,
#  'lingerie': 51839,
#  'striped thighhighs': 51682,
#  'girl on top': 51662,
#  '5girls': 51434,
#  'blue sailor collar': 51318,
#  'sex from behind': 51203,
#  'undressing': 50992,
#  'tassel': 50990,
#  'gem': 50971,
#  'sneakers': 50864,
#  'hand on own chest': 50849,
#  'black leotard': 50819,
#  't-shirt': 50818,
#  'monster girl': 50743,
#  'rabbit tail': 50672,
#  'holding gun': 50639,
#  'white apron': 50629,
#  'head wings': 50202,
#  'yaoi': 50195,
#  'red footwear': 50176,
#  'red bowtie': 50065,
#  'bondage': 50011,
#  'furry': 49977,
#  'shoulder armor': 49871,
#  'messy hair': 49835,
#  'holding cup': 49752,
#  'horse tail': 49661,
#  'tan': 49656,
#  'green skirt': 49641,
#  'goggles': 49569,
#  'all fours': 49524,
#  'hair bobbles': 49433,
#  'lipstick': 49386,
#  'brooch': 49369,
#  'short twintails': 49286,
#  'building': 48949,
#  'black headwear': 48902,
#  'polearm': 48839,
#  'fishnets': 48761,
#  'black bra': 48732,
#  'otoko no ko': 48518,
#  'staff': 48363,
#  '1other': 48253,
#  'shaded face': 48098,
#  'group sex': 47996,
#  'loafers': 47747,
#  'straight hair': 47730,
#  'crescent': 47494,
#  'star (sky)': 47335,
#  'towel': 47310,
#  'letterboxed': 47303,
#  'feathered wings': 47231,
#  'cherry blossoms': 47126,
#  'bandaid': 46963,
#  'single thighhigh': 46907,
#  'clenched hand': 46835,
#  'pink dress': 46733,
#  'strapless leotard': 46551,
#  'box': 46505,
#  'kiss': 46477,
#  'grey shirt': 46357,
#  '^^^': 46167,
#  'black necktie': 46140,
#  'hat bow': 46101,
#  'facing viewer': 46006,
#  'extra ears': 45834,
#  'hooded jacket': 45658,
#  'eyewear on head': 45610,
#  'yellow background': 45606,
#  'no pants': 45571,
#  'multiple tails': 45491,
#  'demon tail': 45459,
#  'drooling': 45424,
#  'steam': 45388,
#  'bike shorts': 45348,
#  'armband': 45336,
#  'wind': 45195,
#  'dog ears': 45049,
#  'butterfly': 44956,
#  'instrument': 44788,
#  'night sky': 44737,
#  'casual': 44684,
#  'foreshortening': 44549,
#  'child': 44376,
#  'panty pull': 44297,
#  'pale skin': 44282,
#  'white ribbon': 44155,
#  'gauntlets': 44112,
#  'revealing clothes': 44112,
#  'rope': 44046,
#  'surprised': 44026,
#  'candy': 44012,
#  'knees up': 44012,
#  'sheath': 43971,
#  'china dress': 43878,
#  'adapted costume': 43849,
#  'breast press': 43844,
#  'ribbon trim': 43839,
#  'multicolored clothes': 43832,
#  'sex toy': 43830,
#  'cover page': 43680,
#  'colored inner hair': 43446,
#  'pink panties': 43413,
#  'red background': 43305,
#  'between breasts': 43137,
#  'wristband': 43126,
#  'hakama': 43002,
#  'puffy long sleeves': 42877,
#  'eyebrows': 42788,
#  'wet clothes': 42783,
#  'couch': 42781,
#  'hair over shoulder': 42691,
#  'blouse': 42647,
#  'skin fang': 42587,
#  'anal': 42471,
#  'musical note': 42378,
#  'veil': 42340,
#  'scenery': 42149,
#  'arms behind head': 42094,
#  'red jacket': 42084,
#  'red nails': 41994,
#  'genderswap': 41828,
#  'nature': 41749,
#  'breath': 41711,
#  'lace trim': 41675,
#  'scar on face': 41611,
#  'pink flower': 41610,
#  'side braid': 41592,
#  'covering privates': 41445,
#  'third eye': 41424,
#  'mole under mouth': 41411,
#  'light blush': 41371,
#  'waist apron': 41299,
#  'male pubic hair': 41293,
#  'smartphone': 41208,
#  'pelvic curtain': 41023,
#  'large pectorals': 41019,
#  'strapless dress': 41006,
#  'microphone': 40950,
#  'ejaculation': 40709,
#  '...': 40655,
#  'skirt set': 40534,
#  'christmas': 40530,
#  'areolae': 40451,
#  'light particles': 40426,
#  'facial': 40395,
#  'anger vein': 40351,
#  'beard': 40237,
#  'baseball cap': 40110,
#  'claws': 40060,
#  'string bikini': 39921,
#  'interlocked fingers': 39898,
#  'web address': 39880,
#  'striped panties': 39680,
#  'toenails': 39469,
#  'bridal gauntlets': 39345,
#  'cloak': 39341,
#  'breasts apart': 39169,
#  'index finger raised': 39137,
#  'highleg leotard': 39092,
#  'peaked cap': 39058,
#  'red neckerchief': 38843,
#  'white pupils': 38642,
#  'purple dress': 38481,
#  'low ponytail': 38390,
#  'white headwear': 38372,
#  'glowing eyes': 38286,
#  'short hair with long locks': 38235,
#  'white pantyhose': 38016,
#  'semi-rimless eyewear': 37963,
#  'side-tie panties': 37927,
#  'two-tone background': 37885,
#  'jingle bell': 37742,
#  'grey skirt': 37729,
#  'convenient censoring': 37619,
#  'hand fan': 37418,
#  'motor vehicle': 37399,
#  'mecha': 37247,
#  'buckle': 37240,
#  'bow panties': 37192,
#  'front-tie top': 37155,
#  'twin drills': 37108,
#  'carrying': 37029,
#  'pink nails': 37028,
#  'clothes writing': 37005,
#  'hair flaps': 36984,
#  'areola slip': 36961,
#  'pom pom (clothes)': 36898,
#  'maid apron': 36796,
#  'sleeves past fingers': 36725,
#  'yellow bow': 36722,
#  'hood up': 36688,
#  'forehead': 36659,
#  'micro bikini': 36619,
#  'androgynous': 36351,
#  'neck bell': 36346,
#  'corset': 36340,
#  'blue nails': 36336,
#  'angry': 36226,
#  'hand on own face': 36221,
#  'wolf tail': 36193,
#  'black belt': 36161,
#  'close-up': 36044,
#  'clothing aside': 35955,
#  'skin tight': 35954,
#  'cum on breasts': 35895,
#  'o-ring': 35883,
#  'holding phone': 35759,
#  'eyeshadow': 35719,
#  'rifle': 35599,
#  'french braid': 35543,
#  'cropped jacket': 35461,
#  'white sleeves': 35447,
#  'meme': 35433,
#  'hakama skirt': 35426,
#  'lace': 35374,
#  'outside border': 35335,
#  'spoken heart': 35332,
#  'low-tied long hair': 35313,
#  'cropped legs': 35222,
#  'tentacles': 35188,
#  'no headwear': 35144,
#  'crossed bangs': 35139,
#  'tokin hat': 34982,
#  'eye contact': 34917,
#  'curvy': 34906,
#  'brown gloves': 34815,
#  'paizuri': 34790,
#  'plate': 34719,
#  'red gloves': 34685,
#  ':<': 34673,
#  'black wings': 34567,
#  'faceless': 34531,
#  'restrained': 34495,
#  'bikini top only': 34463,
#  'snow': 34456,
#  'colored sclera': 34438,
#  'black coat': 34428,
#  'spikes': 34402,
#  'full moon': 34401,
#  'mary janes': 34372,
#  'tearing up': 34317,
#  'side slit': 34308,
#  'gift': 34272,
#  'science fiction': 34249,
#  'holding book': 34212,
#  'alternate breast size': 34133,
#  'blue bikini': 34130,
#  'licking': 34118,
#  'patreon username': 34089,
#  ':p': 34054,
#  'camisole': 34033,
#  'finger to mouth': 33661,
#  'desk': 33608,
#  'strap slip': 33538,
#  'ball': 33403,
#  'armlet': 33292,
#  'green bow': 33141,
#  'arm at side': 33049,
#  'lens flare': 33034,
#  'single horn': 32959,
#  'dragon horns': 32871,
#  'gold trim': 32851,
#  'blue flower': 32783,
#  'blue necktie': 32780,
#  'floating': 32708,
#  'sleeves rolled up': 32686,
#  'hair scrunchie': 32668,
#  'genderswap (mtf)': 32643,
#  'drinking glass': 32608,
#  'seiza': 32498,
#  'white sailor collar': 32480,
#  'black sailor collar': 32455,
#  'pink skirt': 32400,
#  'light purple hair': 32321,
#  'single glove': 32304,
#  'pink ribbon': 32290,
#  'santa hat': 32234,
#  'after sex': 32216,
#  'wading': 32203,
#  'puffy nipples': 32170,
#  'knee up': 32116,
#  'clenched hands': 32048,
#  'half updo': 32001,
#  'smoke': 31986,
#  'wide hips': 31949,
#  'between legs': 31927,
#  'handgun': 31926,
#  'zipper': 31887,
#  'tareme': 31870,
#  'brown background': 31865,
#  'veins': 31847,
#  'open coat': 31816,
#  'starry sky': 31779,
#  'demon wings': 31709,
#  'blue shorts': 31546,
#  'tsurime': 31518,
#  'dual persona': 31487,
#  'heavy breathing': 31484,
#  'pendant': 31479,
#  'single earring': 31441,
#  'happy birthday': 31430,
#  'freckles': 31430,
#  'green background': 31405,
#  'pink shirt': 31401,
#  'pencil skirt': 31398,
#  'outline': 31351,
#  'topless male': 31332,
#  'track jacket': 31248,
#  'fish': 31187,
#  'ribbed sweater': 31181,
#  'high heel boots': 31156,
#  'alcohol': 31107,
#  'frilled apron': 31104,
#  'cowgirl position': 31044,
#  'spot color': 30851,
#  'purple background': 30851,
#  'sweater vest': 30768,
#  'masturbation': 30752,
#  'tray': 30738,
#  'cross-laced footwear': 30636,
#  'asymmetrical legwear': 30620,
#  'arm behind back': 30515,
#  'swim ring': 30477,
#  'handjob': 30458,
#  'black vest': 30400,
#  'clothed female nude male': 30344,
#  'headset': 30300,
#  '!': 30249,
#  'reflection': 30179,
#  'frilled bikini': 30124,
#  'forest': 30093,
#  'upskirt': 30021,
#  'white skin': 30004,
#  'hair rings': 29967,
#  'cake': 29941,
#  'mature male': 29908,
#  'pocket': 29898,
#  'legs up': 29886,
#  'beads': 29865,
#  'partially submerged': 29784,
#  'one-hour drawing challenge': 29705,
#  'vertical-striped clothes': 29672,
#  'clothed sex': 29498,
#  'personification': 29465,
#  'bulge': 29455,
#  'backlighting': 29383,
#  'green dress': 29332,
#  'walking': 29309,
#  'long fingernails': 29246,
#  'unworn headwear': 29215,
#  'frilled shirt collar': 29198,
#  'halloween': 29170,
#  'legs apart': 29134,
#  'dress lift': 29122,
#  'toned': 29066,
#  'black-framed eyewear': 28971,
#  'arm behind head': 28953,
#  'round eyewear': 28863,
#  'brown pantyhose': 28847,
#  'purple bow': 28824,
#  'mole on breast': 28787,
#  'broom': 28693,
#  'high-waist skirt': 28693,
#  'pouch': 28658,
#  'long skirt': 28645,
#  'short ponytail': 28637,
#  'thong': 28628,
#  'condom': 28612,
#  'crossdressing': 28581,
#  'red bikini': 28571,
#  'blue footwear': 28534,
#  'cropped torso': 28528,
#  'crying with eyes open': 28483,
#  'out of frame': 28467,
#  'angel wings': 28422,
#  'cuffs': 28299,
#  'dot nose': 28191,
#  'one eye covered': 28191,
#  'white bra': 28160,
#  'black bowtie': 28158,
#  'yellow shirt': 28147,
#  'purple skirt': 28122,
#  'gym uniform': 28086,
#  'rain': 28083,
#  'hand in own hair': 28033,
#  'goggles on head': 27946,
#  'bubble': 27900,
#  'flying': 27793,
#  'red-framed eyewear': 27760,
#  'epaulettes': 27750,
#  'cumdrip': 27640,
#  'curly hair': 27592,
#  'age difference': 27520,
#  'high collar': 27520,
#  'brown jacket': 27497,
#  ...}

# %%
# cached data
general_tags_count_map = load_from_json("./tmp/general_tags_count_map.json")

# %% [markdown]
# ### plot the distribution of counts

# %% [markdown]
# #### general

# %%
# plot the distribution of counts
general_tags_counts = [count for name, count in general_tags_count_map.items()]

# %%
general_tags_counts[0]
# Out:
# 5071347

# %%
len(general_tags_counts)
# Out:
# 74574

# %%
plt.hist(general_tags_counts, bins=100, range=(1, 1000))
# plt.yscale("log")
plt.xlabel("Count")
plt.ylabel("Frequency")
plt.title("Distribution of general tags counts")
plt.show()

# %%
popular_general_tags = [
    name for name, count in general_tags_count_map.items() if count > 200
]
save_to_json(popular_general_tags, "./tmp/popular_general_tags.json")
len(popular_general_tags)
# Out:
# 13253

# %% [markdown]
# #### copyright tags

# %%
copyright_tags_count_map = get_count_map("copyright")
save_to_json(copyright_tags_count_map, "./tmp/copyright_tags_count_map.json")
copyright_tags_count_map

# %%
copyright_tags_count_map = load_from_json("./tmp/copyright_tags_count_map.json")

# %%
copyright_tags_counts = [count for name, count in copyright_tags_count_map.items()]

# %%
# plot
plt.hist(copyright_tags_counts, bins=100, range=(1, 1000))
# plt.yscale("log")
plt.xlabel("Count")
plt.ylabel("Frequency")
plt.title("Distribution of copyright tags counts")
plt.show()

# %%
popular_copyright_tags = [
    # 登場回数100回未満ののコピーライトタグは、プロンプトに入れても生成されない可能性が高いため、除外する
    name
    for name, count in copyright_tags_count_map.items()
    if count > 100
]
save_to_json(popular_copyright_tags, "./tmp/popular_copyright_tags.json")
len(popular_copyright_tags)
# Out:
# 3691

# %% [markdown]
# #### charachter tags

# %%
character_tags_count_map = get_count_map("character")
save_to_json(character_tags_count_map, "./tmp/character_tags_count_map.json")
character_tags_count_map
# Out:
# 100%|██████████| 7124975/7124975 [00:03<00:00, 2078803.18it/s]
# {'hatsune miku': 88910,
#  'hakurei reimu': 72973,
#  'kirisame marisa': 66328,
#  'remilia scarlet': 49042,
#  'flandre scarlet': 47613,
#  'izayoi sakuya': 43678,
#  'admiral (kancolle)': 36980,
#  'artoria pendragon (fate)': 35253,
#  'kochiya sanae': 33749,
#  'alice margatroid': 33392,
#  'patchouli knowledge': 33072,
#  'konpaku youmu': 32761,
#  'cirno': 32703,
#  'komeiji koishi': 31383,
#  'yakumo yukari': 30727,
#  'shameimaru aya': 27102,
#  'reisen udongein inaba': 25616,
#  'fujiwara no mokou': 25355,
#  'komeiji satori': 24381,
#  'hong meiling': 23938,
#  'akemi homura': 23883,
#  'kaname madoka': 22910,
#  'saigyouji yuyuko': 22820,
#  'inubashiri momiji': 21395,
#  'kaga (kancolle)': 20944,
#  'yakumo ran': 18977,
#  'kagamine rin': 18880,
#  'kaenbyou rin': 18121,
#  'konpaku youmu (ghost)': 18052,
#  'moriya suwako': 17939,
#  'rumia': 17845,
#  'shimakaze (kancolle)': 17511,
#  'kazami yuuka': 17292,
#  'miki sayaka': 17090,
#  'reiuji utsuho': 16982,
#  'chen': 16827,
#  'ganyu (genshin impact)': 16459,
#  'saber (fate)': 16434,
#  'hibiki (kancolle)': 16255,
#  'mash kyrielight': 15885,
#  'tatara kogasa': 15815,
#  'kawashiro nitori': 15630,
#  'kamishirasawa keine': 15613,
#  'shigure (kancolle)': 15584,
#  'hinanawi tenshi': 15260,
#  'sakura kyoko': 14693,
#  'tomoe mami': 14642,
#  'houraisan kaguya': 14278,
#  'koakuma': 14059,
#  'mystia lorelei': 13979,
#  'souryuu asuka langley': 13326,
#  'kongou (kancolle)': 13290,
#  'inaba tewi': 13246,
#  'ibuki suika': 13155,
#  'nazrin': 12681,
#  'inazuma (kancolle)': 12656,
#  'warrior of light (ff14)': 12596,
#  'hijiri byakuren': 12559,
#  'akagi (kancolle)': 12327,
#  'kagamine len': 12320,
#  'link': 12181,
#  'raiden shogun': 12084,
#  'tamamo (fate)': 12001,
#  'houjuu nue': 11916,
#  'lumine (genshin impact)': 11671,
#  'houshou marine': 11479,
#  'fujimaru ritsuka (male)': 11416,
#  'tenryuu (kancolle)': 11352,
#  'yasaka kanako': 11264,
#  'yuudachi (kancolle)': 11257,
#  'fujimaru ritsuka (female)': 11231,
#  'yagokoro eirin': 11158,
#  'megurine luka': 11127,
#  'sensei (blue archive)': 10984,
#  "jeanne d'arc alter (fate)": 10938,
#  'gawr gura': 10906,
#  'mizuhashi parsee': 10886,
#  'fubuki (kancolle)': 10749,
#  'abigail williams (fate)': 10666,
#  'ikazuchi (kancolle)': 10644,
#  'pikachu': 10210,
#  'hu tao (genshin impact)': 10104,
#  'zuikaku (kancolle)': 10033,
#  'akatsuki (kancolle)': 10012,
#  'akiyama mio': 9945,
#  'toyosatomimi no miko': 9643,
#  'hamakaze (kancolle)': 9562,
#  'haruna (kancolle)': 9469,
#  'nagato (kancolle)': 9398,
#  'nero claudius (fate)': 9397,
#  'morichika rinnosuke': 9309,
#  'inkling player character': 9302,
#  'suzumiya haruhi': 9269,
#  'kagiyama hina': 9214,
#  'princess zelda': 9180,
#  'hoshiguma yuugi': 9104,
#  'tifa lockhart': 9067,
#  'shigure kai ni (kancolle)': 9040,
#  'kashima (kancolle)': 9010,
#  'fate testarossa': 9008,
#  'nishizumi miho': 8895,
#  'mononobe no futo': 8745,
#  'tohsaka rin': 8713,
#  'daiyousei': 8687,
#  'wriggle nightbug': 8676,
#  'nakano azusa': 8653,
#  'asuna (blue archive)': 8640,
#  'shanghai doll': 8632,
#  'rem (re:zero)': 8536,
#  '2b (nier:automata)': 8535,
#  'shirakami fubuki': 8527,
#  'usami renko': 8505,
#  'shiki eiki': 8481,
#  'nagato yuki': 8427,
#  'misaka mikoto': 8400,
#  'onozuka komachi': 8321,
#  'suzuya (kancolle)': 8319,
#  'ryuujou (kancolle)': 8270,
#  'maribel hearn': 8177,
#  'illyasviel von einzbern': 8152,
#  'hirasawa yui': 8137,
#  'kyubey': 8127,
#  'yuuka (blue archive)': 8096,
#  'yae miko': 8092,
#  'gotoh hitori': 8045,
#  'yuudachi kai ni (kancolle)': 8039,
#  'scathach (fate)': 8023,
#  'imaizumi kagerou': 8008,
#  'zhongli (genshin impact)': 7999,
#  'producer (idolmaster)': 7923,
#  'ayanami rei': 7790,
#  'inkling girl': 7740,
#  'manjuu (azur lane)': 7670,
#  'houshou (kancolle)': 7644,
#  'toramaru shou': 7569,
#  'takamachi nanoha': 7534,
#  'joseph joestar': 7458,
#  'usada pekora': 7450,
#  "jeanne d'arc (fate)": 7390,
#  'matoi ryuuko': 7330,
#  'aether (genshin impact)': 7266,
#  'serval (kemono friends)': 7218,
#  'yor briar': 7134,
#  'hoshimachi suisei': 7093,
#  'murakumo (kancolle)': 7054,
#  'himekaidou hatate': 7038,
#  'tainaka ritsu': 7013,
#  'amatsukaze (kancolle)': 7002,
#  'megumin': 6954,
#  'mona (genshin impact)': 6900,
#  'kaku seiga': 6865,
#  'nishikino maki': 6862,
#  'kafuu chino': 6861,
#  'ushio (kancolle)': 6839,
#  "jeanne d'arc alter (avenger) (fate)": 6822,
#  'dawn (pokemon)': 6811,
#  'sonoda umi': 6806,
#  'shiroko (blue archive)': 6805,
#  'tojo nozomi': 6784,
#  'okita souji (fate)': 6772,
#  'shibuya rin': 6771,
#  'keqing (genshin impact)': 6732,
#  'yukikaze (kancolle)': 6685,
#  "ninomae ina'nis": 6685,
#  'nanami chiaki': 6664,
#  'mori calliope': 6654,
#  'murasa minamitsu': 6649,
#  'lillie (pokemon)': 6632,
#  'atago (kancolle)': 6584,
#  'minato aqua': 6584,
#  'northern ocean princess': 6569,
#  'gardevoir': 6549,
#  'yamato (kancolle)': 6542,
#  'shoukaku (kancolle)': 6509,
#  'kujo jotaro': 6476,
#  'yuzuki yukari': 6446,
#  'doodle sensei (blue archive)': 6423,
#  'tamamo no mae (fate/extra)': 6406,
#  'ayase eli': 6373,
#  'yazawa nico': 6365,
#  'nagae iku': 6322,
#  'akebono (kancolle)': 6317,
#  'kaito (vocaloid)': 6313,
#  'joseph joestar (young)': 6290,
#  'hata no kokoro': 6286,
#  'ibaraki kasen': 6234,
#  'trainer (umamusume)': 6203,
#  'hina (blue archive)': 6170,
#  'chun-li': 6163,
#  'doctor (arknights)': 6136,
#  'pyra (xenoblade)': 6088,
#  'nekomata okayu': 6052,
#  'kinomoto sakura': 6037,
#  'kitakami (kancolle)': 6036,
#  'shuten douji (fate)': 6024,
#  'amiya (arknights)': 6005,
#  'makima (chainsaw man)': 6001,
#  'byleth (fire emblem)': 5990,
#  'gilgamesh (fate)': 5983,
#  'cloud strife': 5982,
#  'soga no tojiko': 5982,
#  'kasodani kyouko': 5901,
#  'kurodani yamame': 5892,
#  'miyako yoshika': 5888,
#  'toki (blue archive)': 5875,
#  'may (pokemon)': 5873,
#  'kumoi ichirin': 5839,
#  'rensouhou-chan': 5828,
#  'rosa (pokemon)': 5827,
#  'matou sakura': 5810,
#  'ooyodo (kancolle)': 5781,
#  'darjeeling (girls und panzer)': 5755,
#  'astolfo (fate)': 5735,
#  'marnie (pokemon)': 5700,
#  'hoshii miki': 5694,
#  'venti (genshin impact)': 5615,
#  'prinz eugen (kancolle)': 5584,
#  'tokoyami towa': 5583,
#  'cu chulainn (fate)': 5566,
#  'kijin seija': 5555,
#  'clownpiece': 5553,
#  'takanashi kiara': 5511,
#  'hilda (pokemon)': 5504,
#  'mutsu (kancolle)': 5466,
#  'asashio (kancolle)': 5457,
#  'kotobuki tsumugi': 5447,
#  'female admiral (kancolle)': 5446,
#  'mythra (xenoblade)': 5431,
#  'texas (arknights)': 5430,
#  'nishizumi maho': 5423,
#  'tatsuta (kancolle)': 5400,
#  'hiiragi kagami': 5393,
#  'mordred (fate)': 5391,
#  'samus aran': 5384,
#  'klee (genshin impact)': 5368,
#  'nanashi mumei': 5366,
#  'kamisato ayaka': 5361,
#  'kirby': 5346,
#  'kaban (kemono friends)': 5336,
#  'itsumi erika': 5296,
#  'ouro kronii': 5275,
#  'rice shower (umamusume)': 5274,
#  'princess peach': 5272,
#  'sekibanki': 5240,
#  'aki minoriko': 5233,
#  'emiya shirou': 5224,
#  'minamoto no raikou (fate)': 5223,
#  'meiko (vocaloid)': 5216,
#  'dio brando': 5195,
#  'hieda no akyuu': 5163,
#  'junko (touhou)': 5160,
#  'tartaglia (genshin impact)': 5155,
#  'minami kotori': 5144,
#  'mika (blue archive)': 5139,
#  'watson amelia': 5135,
#  'c.c.': 5110,
#  'ooi (kancolle)': 5094,
#  'archer (fate)': 5084,
#  'mejiro mcqueen (umamusume)': 5082,
#  'sendai (kancolle)': 5057,
#  'furina (genshin impact)': 5055,
#  'anchovy (girls und panzer)': 5051,
#  'musashi (kancolle)': 5049,
#  'bismarck (kancolle)': 5042,
#  'aerith gainsborough': 5035,
#  'izumi konata': 5031,
#  'eula (genshin impact)': 5023,
#  'tsukino usagi': 5008,
#  'akashi (kancolle)': 5000,
#  'caesar anthonio zeppeli': 4994,
#  'paimon (genshin impact)': 4986,
#  'asuna (sao)': 4980,
#  'daiwa scarlet (umamusume)': 4971,
#  'gawr gura (1st costume)': 4951,
#  'shirogane noel': 4949,
#  'takao (kancolle)': 4948,
#  'gloria (pokemon)': 4944,
#  'aris (blue archive)': 4909,
#  'nahida (genshin impact)': 4907,
#  'amami haruka': 4903,
#  'shiranui (kancolle)': 4888,
#  'sukuna shinmyoumaru': 4839,
#  'sakura miko': 4837,
#  'shenhe (genshin impact)': 4825,
#  'futatsuiwa mamizou': 4806,
#  "hk416 (girls' frontline)": 4804,
#  'okita souji (koha-ace)': 4796,
#  'scaramouche (genshin impact)': 4796,
#  'koharu (blue archive)': 4787,
#  'souryuu (kancolle)': 4783,
#  'sazanami (kancolle)': 4767,
#  'medusa (fate)': 4765,
#  'akiyama yukari': 4749,
#  'nero claudius (fate/extra)': 4731,
#  'skadi (arknights)': 4717,
#  'byleth (female) (fire emblem)': 4707,
#  'samidare (kancolle)': 4698,
#  'taihou (azur lane)': 4697,
#  'hoshino (blue archive)': 4695,
#  'aki shizuha': 4685,
#  'yoko littner': 4672,
#  'yamashiro (kancolle)': 4665,
#  'komaeda nagito': 4653,
#  'asuna (bunny) (blue archive)': 4638,
#  'shijou takane': 4627,
#  'letty whiterock': 4592,
#  'senketsu': 4587,
#  'amane kanata': 4587,
#  'mordred (fate/apocrypha)': 4575,
#  'hiei (kancolle)': 4570,
#  'ookami mio': 4568,
#  'kosaka honoka': 4551,
#  'inugami korone': 4549,
#  'wo-class aircraft carrier': 4548,
#  'watanabe you': 4548,
#  'oozora subaru': 4548,
#  'gumi': 4541,
#  'd.va (overwatch)': 4541,
#  'bb (fate)': 4533,
#  'ro-500 (kancolle)': 4514,
#  'kasumi (kancolle)': 4509,
#  'karin (blue archive)': 4500,
#  'ash ketchum': 4490,
#  'kiryuuin satsuki': 4481,
#  'hecatia lapislazuli': 4481,
#  'suigintou': 4476,
#  'kisaragi chihaya': 4467,
#  'boo tao (genshin impact)': 4455,
#  'iowa (kancolle)': 4443,
#  'kikuchi makoto': 4433,
#  'nishikigi chisato': 4421,
#  'gold ship (umamusume)': 4419,
#  'shirasaka koume': 4417,
#  'kirishima (kancolle)': 4399,
#  'yumemi riamu': 4376,
#  'verniy (kancolle)': 4374,
#  'morrigan aensland': 4369,
#  'minase iori': 4368,
#  'nami (one piece)': 4349,
#  'oshino shinobu': 4346,
#  'oma kokichi': 4326,
#  'cynthia (pokemon)': 4305,
#  'agnes tachyon (umamusume)': 4299,
#  'atago (azur lane)': 4283,
#  'bremerton (azur lane)': 4274,
#  'frieren': 4257,
#  'saber alter': 4254,
#  'houshou marine (1st costume)': 4254,
#  'shimamura uzuki': 4250,
#  'oyama mahiro': 4246,
#  'tokai teio (umamusume)': 4232,
#  'anya (spy x family)': 4232,
#  'xiao (genshin impact)': 4228,
#  'hoshizora rin': 4214,
#  'uruha rushia': 4214,
#  'midoriya izuku': 4199,
#  'yukihana lamy': 4186,
#  'sakamata chloe': 4186,
#  'aqua (konosuba)': 4167,
#  'cammy white': 4158,
#  "jeanne d'arc (ruler) (fate)": 4155,
#  'ex-keine': 4152,
#  'higuchi madoka': 4147,
#  'prinz eugen (azur lane)': 4146,
#  'hinata hajime': 4136,
#  'ganaha hibiki': 4134,
#  'yuubari (kancolle)': 4131,
#  'red (pokemon)': 4130,
#  'meltryllis (fate)': 4128,
#  'shishiro botan': 4116,
#  'takagaki kaede': 4110,
#  'sagisawa fumika': 4101,
#  'formidable (azur lane)': 4087,
#  'power (chainsaw man)': 4056,
#  'kiso (kancolle)': 4055,
#  'hiryuu (kancolle)': 4034,
#  'zero two (darling in the franxx)': 4020,
#  'son goku': 3991,
#  'karyl (princess connect!)': 3984,
#  'wakasagihime': 3975,
#  'djeeta (granblue fantasy)': 3962,
#  'miyamoto musashi (fate)': 3952,
#  'ultimate madoka': 3950,
#  'saihara shuichi': 3920,
#  'kishin sagume': 3900,
#  'ikari shinji': 3897,
#  'graf zeppelin (kancolle)': 3877,
#  'suletta mercury': 3873,
#  'asahina mikuru': 3856,
#  'ereshkigal (fate)': 3828,
#  'serena (pokemon)': 3826,
#  'selene (pokemon)': 3813,
#  'kitagawa marin': 3797,
#  'corrin (fire emblem)': 3783,
#  'lucina (fire emblem)': 3778,
#  'medusa (rider) (fate)': 3773,
#  'ishtar (fate)': 3741,
#  'murasaki shion': 3727,
#  'kuroki tomoko': 3723,
#  'jougasaki mika': 3718,
#  'lappland (arknights)': 3700,
#  'lily white': 3697,
#  'belfast (azur lane)': 3687,
#  'la+ darknesss': 3684,
#  'koizumi hanayo': 3672,
#  'takatsuki yayoi': 3670,
#  'hestia (danmachi)': 3668,
#  'inoue takina': 3658,
#  'uraraka ochako': 3642,
#  'ahri (league of legends)': 3641,
#  'kanzaki ranko': 3640,
#  'sirius (azur lane)': 3636,
#  'mario': 3628,
#  'black rock shooter (character)': 3625,
#  'bowsette': 3609,
#  'naka (kancolle)': 3608,
#  'toki (bunny) (blue archive)': 3604,
#  'takebe saori': 3598,
#  'kiryu coco': 3593,
#  'sailor moon': 3588,
#  'furude rika': 3584,
#  'nilou (genshin impact)': 3583,
#  'kita ikuyo': 3559,
#  'kyon': 3556,
#  'zuihou (kancolle)': 3536,
#  'stocking (psg)': 3527,
#  'trailblazer (honkai: star rail)': 3527,
#  'cu chulainn (fate/stay night)': 3518,
#  'haruno sakura': 3507,
#  'eevee': 3498,
#  'tsushima yoshiko': 3497,
#  'nakiri ayame': 3497,
#  'commander (azur lane)': 3496,
#  'super sonico': 3489,
#  'fairy (kancolle)': 3476,
#  'usada pekora (1st costume)': 3476,
#  'mari (blue archive)': 3472,
#  'yelan (genshin impact)': 3472,
#  'kisume': 3467,
#  'monster hunter (character)': 3466,
#  'narukami yuu': 3466,
#  'takarada rikka': 3464,
#  'seaport princess': 3460,
#  'arona (blue archive)': 3454,
#  'kiana kaslana': 3449,
#  'naganami (kancolle)': 3448,
#  'fu hua': 3443,
#  'denji (chainsaw man)': 3429,
#  'kakyoin noriaki': 3427,
#  'i-19 (kancolle)': 3426,
#  'shiranui flare': 3426,
#  'ichinose shiki': 3424,
#  'silence suzuka (umamusume)': 3424,
#  'hanako (blue archive)': 3420,
#  'gokou ruri': 3408,
#  'nitta minami': 3406,
#  'mirko': 3399,
#  'kisaki (blue archive)': 3392,
#  'tachibana arisu': 3369,
#  'fischl (genshin impact)': 3365,
#  'kujo jolyne': 3360,
#  'edelgard von hresvelg': 3358,
#  'ako (blue archive)': 3352,
#  'hakos baelz': 3348,
#  'murasame (kancolle)': 3346,
#  'aru (blue archive)': 3337,
#  'unicorn (azur lane)': 3332,
#  'manhattan cafe (umamusume)': 3330,
#  'misty (pokemon)': 3325,
#  'medicine melancholy': 3308,
#  'barnaby brooks jr.': 3294,
#  'sanya v. litvyak': 3292,
#  'doremy sweet': 3287,
#  'barbara (genshin impact)': 3283,
#  'suzuran (arknights)': 3282,
#  'kokkoro (princess connect!)': 3278,
#  'giorno giovanna': 3272,
#  'yamakaze (kancolle)': 3249,
#  'miorine rembran': 3248,
#  'maya (kancolle)': 3244,
#  'rio (blue archive)': 3239,
#  'lunasa prismriver': 3238,
#  'kay (girls und panzer)': 3237,
#  'eila ilmatar juutilainen': 3233,
#  'bakugou katsuki': 3233,
#  "ump45 (girls' frontline)": 3232,
#  'natsuiro matsuri': 3231,
#  'chloe von einzbern': 3230,
#  'sangonomiya kokomi': 3227,
#  'ijichi nijika': 3224,
#  'jonathan joestar': 3220,
#  'sakurauchi riko': 3213,
#  'gojou satoru': 3204,
#  'yuki miku': 3193,
#  'florence nightingale (fate)': 3193,
#  'i-58 (kancolle)': 3191,
#  'anastasia (idolmaster)': 3190,
#  'jean (genshin impact)': 3189,
#  'kirito': 3185,
#  "ch'en (arknights)": 3185,
#  'futaba anzu': 3184,
#  'kaburagi t. kotetsu': 3168,
#  'mikasa ackerman': 3165,
#  'yagami hayate': 3163,
#  'usami sumireko': 3162,
#  'nakano nino': 3162,
#  'kotomine kirei': 3161,
#  'katyusha (girls und panzer)': 3152,
#  'robin (fire emblem)': 3145,
#  'shimada arisu': 3141,
#  'nice nature (umamusume)': 3140,
#  'koshimizu sachiko': 3131,
#  'uzumaki naruto': 3123,
#  'motoori kosuzu': 3122,
#  'kafka (honkai: star rail)': 3116,
#  'jack the ripper (fate/apocrypha)': 3108,
#  'kama (fate)': 3107,
#  'exusiai (arknights)': 3086,
#  'hiiragi tsukasa': 3084,
#  'reisalin stout': 3084,
#  'iskandar (fate)': 3083,
#  'shirai kuroko': 3076,
#  'akigumo (kancolle)': 3076,
#  'monkey d. luffy': 3058,
#  'kayoko (blue archive)': 3049,
#  'leon (pokemon)': 3046,
#  'ayanami (azur lane)': 3043,
#  'fern (sousou no frieren)': 3041,
#  'pecorine (princess connect!)': 3029,
#  'miyu (blue archive)': 3025,
#  'ruby rose': 3023,
#  'plana (blue archive)': 3021,
#  'waver velvet': 3020,
#  'hyuuga hinata': 3017,
#  'raihan (pokemon)': 3014,
#  'emilia (re:zero)': 3013,
#  'mercy (overwatch)': 3011,
#  'shirogane naoto': 2992,
#  'z1 leberecht maass (kancolle)': 2987,
#  'corrin (female) (fire emblem)': 2987,
#  "kal'tsit (arknights)": 2982,
#  'taihou (kancolle)': 2977,
#  'narmaya (granblue fantasy)': 2975,
#  'ryuuguu rena': 2970,
#  'bronya zaychik': 2970,
#  'hoto cocoa': 2968,
#  'momoi (blue archive)': 2967,
#  'bridget (guilty gear)': 2958,
#  'star sapphire': 2956,
#  'nakano miku': 2955,
#  'surtr (arknights)': 2953,
#  'higashikata josuke': 2951,
#  'yorigami shion': 2951,
#  'ceres fauna': 2948,
#  'kizuna akari': 2938,
#  'nia teppelin': 2935,
#  'nico robin': 2933,
#  'sheryl nome': 2933,
#  'jougasaki rika': 2931,
#  'fusou (kancolle)': 2930,
#  'hasumi (blue archive)': 2925,
#  'iono (pokemon)': 2925,
#  'kuma (kancolle)': 2924,
#  'z3 max schultz (kancolle)': 2924,
#  'miura azusa': 2923,
#  'satono diamond (umamusume)': 2917,
#  'reizei mako': 2910,
#  'warspite (kancolle)': 2910,
#  'shiranui mai': 2908,
#  'oda nobunaga (fate)': 2907,
#  'tatsumaki': 2902,
#  'common raccoon (kemono friends)': 2902,
#  'takami chika': 2901,
#  'aisaka taiga': 2898,
#  'roronoa zoro': 2888,
#  'aoba (kancolle)': 2888,
#  'mayuzumi fuyuko': 2881,
#  'maekawa miku': 2877,
#  'kaedehara kazuha': 2877,
#  'weiss schnee': 2875,
#  'elizabeth bathory (fate)': 2873,
#  'hagiwara yukiho': 2865,
#  'artoria pendragon (lancer) (fate)': 2847,
#  'pyonta': 2846,
#  'oboro (kancolle)': 2846,
#  'octoling player character': 2845,
#  'kumano (kancolle)': 2840,
#  'raiden mei': 2838,
#  'bea (pokemon)': 2837,
#  'luna child': 2831,
#  'shirakami fubuki (1st costume)': 2828,
#  'kirigiri kyoko': 2826,
#  'i-401 (kancolle)': 2819,
#  'nitocris (fate)': 2818,
#  'nessa (pokemon)': 2809,
#  'izumi sagiri': 2800,
#  'mudrock (arknights)': 2800,
#  'non-human admiral (kancolle)': 2798,
#  'alice (alice in wonderland)': 2796,
#  'don-chan (usada pekora)': 2795,
#  'illustrious (azur lane)': 2793,
#  'holo': 2791,
#  'shokuhou misaki': 2786,
#  'tokitsukaze (kancolle)': 2785,
#  'sonic the hedgehog': 2784,
#  'satonaka chie': 2784,
#  'satsuki (kancolle)': 2768,
#  'kazusa (blue archive)': 2768,
#  'kiyohime (fate)': 2767,
#  'lelouch vi britannia': 2762,
#  'midorikawa nao': 2762,
#  'sunny milk': 2761,
#  'boko (girls und panzer)': 2754,
#  'fennec (kemono friends)': 2753,
#  'kitasan black (umamusume)': 2752,
#  'uzuki (kancolle)': 2749,
#  'hyuuga (kancolle)': 2744,
#  'yoimiya (genshin impact)': 2744,
#  'makise kurisu': 2740,
#  'mogami (kancolle)': 2738,
#  'mankanshoku mako': 2737,
#  'yoshida yuuko (machikado mazoku)': 2734,
#  'noa (blue archive)': 2734,
#  'dark magician girl': 2732,
#  'yamada ryo': 2729,
#  'akizuki ritsuko': 2728,
#  'ashigara (kancolle)': 2721,
#  'beatrice (umineko)': 2719,
#  'kise yayoi': 2709,
#  'akari (pokemon)': 2709,
#  'han juri': 2706,
#  'amamiya ren': 2703,
#  'amber (genshin impact)': 2699,
#  'charlotte (madoka magica)': 2693,
#  'kagerou (kancolle)': 2691,
#  'kamado nezuko': 2682,
#  'tomoe gozen (fate)': 2682,
#  'urakaze (kancolle)': 2675,
#  'kiyoshimo (kancolle)': 2675,
#  'shiratsuyu (kancolle)': 2669,
#  'midori (blue archive)': 2668,
#  'mutsuki (blue archive)': 2668,
#  'mika (girls und panzer)': 2667,
#  'kirima syaro': 2659,
#  'enoshima junko': 2650,
#  'nagisa kaworu': 2642,
#  'twilight (spy x family)': 2627,
#  'hayami kanade': 2625,
#  'jintsuu (kancolle)': 2622,
#  'unzan': 2618,
#  'kousaka kirino': 2617,
#  'houjou satoko': 2608,
#  'dizzy (guilty gear)': 2604,
#  'w (arknights)': 2602,
#  'kouzuki kallen': 2599,
#  'eren yeager': 2598,
#  'isokaze (kancolle)': 2591,
#  'callie (splatoon)': 2591,
#  'ram (re:zero)': 2588,
#  'symboli rudolf (umamusume)': 2585,
#  'karin (bunny) (blue archive)': 2579,
#  'hatsuyuki (kancolle)': 2577,
#  'special week (umamusume)': 2573,
#  'diluc (genshin impact)': 2573,
#  'qiqi (genshin impact)': 2572,
#  'unryuu (kancolle)': 2565,
#  'rotom': 2558,
#  'atlanta (kancolle)': 2557,
#  'miyu edelfelt': 2552,
#  'accelerator (toaru majutsu no index)': 2539,
#  'yuuki makoto (persona 3)': 2534,
#  'miyafuji yoshika': 2533,
#  "wa2000 (girls' frontline)": 2531,
#  'arcueid brunestud': 2530,
#  'chitanda eru': 2522,
#  'michishio (kancolle)': 2518,
#  'nakano yotsuba': 2518,
#  'taigei (kancolle)': 2516,
#  'erica hartmann': 2512,
#  'emiya kiritsugu': 2506,
#  "yorigami jo'on": 2506,
#  'shiroko (swimsuit) (blue archive)': 2505,
#  'akitsu maru (kancolle)': 2502,
#  'saratoga (kancolle)': 2493,
#  'hishikawa rikka': 2491,
#  'kamijou touma': 2473,
#  'kanna kamui': 2466,
#  'marie (splatoon)': 2463,
#  'lana (pokemon)': 2463,
#  'morgan le fay (fate)': 2457,
#  'yukine chris': 2455,
#  'rowlet': 2447,
#  'nia (xenoblade)': 2445,
#  'diarmuid ua duibhne (lancer) (fate)': 2444,
#  'tachibana kanade': 2437,
#  'ui (blue archive)': 2436,
#  'katsushika hokusai (fate)': 2433,
#  'hatsuzuki (kancolle)': 2431,
#  'aoki reika': 2427,
#  'yahagi (kancolle)': 2421,
#  'march 7th (honkai: star rail)': 2420,
#  'kaenbyou rin (cat)': 2417,
#  'laffey (azur lane)': 2417,
#  'enterprise (azur lane)': 2412,
#  'stelle (honkai: star rail)': 2411,
#  'harusame (kancolle)': 2408,
#  'hakui koyori': 2407,
#  'makinami mari illustrious': 2405,
#  'futami mami': 2404,
#  'akai haato': 2396,
#  'gertrud barkhorn': 2395,
#  'tippy (gochiusa)': 2392,
#  'uchiha sasuke': 2391,
#  'takao (azur lane)': 2389,
#  'shana': 2386,
#  'yura (kancolle)': 2381,
#  'merlin prismriver': 2379,
#  'itadori yuuji': 2379,
#  'ethan (pokemon)': 2375,
#  'toga himiko': 2362,
#  'asakura ryouko': 2361,
#  'arima kana': 2357,
#  'saori (blue archive)': 2356,
#  'rosalina': 2351,
#  'tsukino mito': 2349,
#  'yuuka (track) (blue archive)': 2344,
#  'hifumi (blue archive)': 2341,
#  'lyrica prismriver': 2321,
#  'tamamo cat (fate)': 2320,
#  'isuzu hana': 2319,
#  'mostima (arknights)': 2318,
#  'hex maniac (pokemon)': 2317,
#  'irys (hololive)': 2310,
#  't-head admiral': 2307,
#  'simon (ttgl)': 2306,
#  'gran (granblue fantasy)': 2305,
#  'sakurai momoka': 2302,
#  'haguro (kancolle)': 2302,
#  'matara okina': 2302,
#  'mutsuki (kancolle)': 2299,
#  'akagi (azur lane)': 2298,
#  'louise francoise le blanc de la valliere': 2290,
#  'p-head producer': 2285,
#  'napoleon bonaparte (fate)': 2283,
#  'neru (blue archive)': 2281,
#  'inkling boy': 2277,
#  'senjougahara hitagi': 2274,
#  'ohtsuki yui': 2274,
#  'ranka lee': 2272,
#  're-class battleship': 2269,
#  'kashiwazaki sena': 2263,
#  'hilbert (pokemon)': 2262,
#  'hino akane (smile precure!)': 2262,
#  'blue oak': 2260,
#  'yang xiao long': 2257,
#  'hanekawa tsubasa': 2255,
#  'akamatsu kaede': 2250,
#  'matsuura kanan': 2241,
#  'u-511 (kancolle)': 2238,
#  'akizuki (kancolle)': 2237,
#  "ninomae ina'nis (1st costume)": 2230,
#  'kurosawa dia': 2227,
#  "ump9 (girls' frontline)": 2220,
#  'tsunomaki watame': 2220,
#  'kaga (azur lane)': 2218,
#  'piplup': 2216,
#  'artoria caster (fate)': 2214,
#  'baobhan sith (fate)': 2214,
#  'ushiromiya battler': 2213,
#  "jeanne d'arc alter (swimsuit berserker) (fate)": 2212,
#  'shinku': 2206,
#  'kyonko': 2206,
#  'tone (kancolle)': 2203,
#  'abukuma (kancolle)': 2201,
#  'wanderer (genshin impact)': 2200,
#  'touhoku kiritan': 2196,
#  'watson amelia (1st costume)': 2195,
#  'asakura toru': 2189,
#  'fushiguro megumi': 2187,
#  'toshinou kyouko': 2182,
#  'oguri cap (umamusume)': 2182,
#  'kazama iroha': 2182,
#  'vodka (umamusume)': 2177,
#  'lum': 2175,
#  'shikinami (kancolle)': 2172,
#  'houjou hibiki': 2171,
#  'i-8 (kancolle)': 2170,
#  'akagi miria': 2169,
#  'kagari atsuko': 2167,
#  'akuma homura': 2167,
#  'nonna (girls und panzer)': 2165,
#  'junketsu': 2161,
#  'kamikaze (kancolle)': 2157,
#  'omaru polka': 2156,
#  'ia (vocaloid)': 2155,
#  'dodoco (genshin impact)': 2151,
#  'charizard': 2150,
#  'kisaragi (kancolle)': 2150,
#  'sakamata chloe (1st costume)': 2150,
#  "takodachi (ninomae ina'nis)": 2147,
#  'futami ami': 2144,
#  'sonia (pokemon)': 2144,
#  'android 18': 2137,
#  'bb (fate/extra)': 2137,
#  'kochou shinobu': 2137,
#  'saten ruiko': 2134,
#  'ningguang (genshin impact)': 2134,
#  'takanashi rikka': 2133,
#  'aida mana': 2131,
#  'adventurer (ff11)': 2130,
#  'kunikida hanamaru': 2119,
#  'bb (swimsuit mooncancer) (fate)': 2111,
#  'mash kyrielight (dangerous beast)': 2105,
#  'lysithea von ordelia': 2104,
#  'pola (kancolle)': 2102,
#  'phosphophyllite': 2101,
#  'miyuki (kancolle)': 2097,
#  'anastasia (fate)': 2086,
#  'harukawa maki': 2078,
#  'perrine h. clostermann': 2077,
#  'fou (fate)': 2077,
#  'hachimiya meguru': 2077,
#  'inugami korone (1st costume)': 2077,
#  'gambier bay (kancolle)': 2076,
#  'sanji (one piece)': 2075,
#  'hilda valentine goneril': 2075,
#  'lyra (pokemon)': 2072,
#  'raising heart': 2068,
#  'charlotte e. yeager': 2068,
#  'twin turbo (umamusume)': 2068,
#  'kujikawa rise': 2065,
#  'miyako (blue archive)': 2063,
#  'kurumi erika': 2058,
#  'morikubo nono': 2058,
#  'tamamo no mae (swimsuit lancer) (fate)': 2058,
#  'nonomi (blue archive)': 2054,
#  'nero claudius (swimsuit caster) (fate)': 2053,
#  'honda mio': 2052,
#  'kousaka tamaki': 2051,
#  'mihono bourbon (umamusume)': 2050,
#  'amagi yukiko': 2048,
#  'ise (kancolle)': 2047,
#  'panty (psg)': 2046,
#  'darkness (konosuba)': 2042,
#  'lyn (fire emblem)': 2038,
#  'ikamusume': 2038,
#  'battleship princess': 2038,
#  "springfield (girls' frontline)": 2035,
#  'fukumaru koito': 2032,
#  'hoshizora miyuki': 2031,
#  'lucario': 2028,
#  'lio fotia': 2028,
#  'kicchou yachie': 2028,
#  'sessyoin kiara': 2027,
#  'ibaraki douji (fate)': 2026,
#  'kasane teto': 2022,
#  'akaza akari': 2021,
#  'sakura miku': 2018,
#  'mallow (pokemon)': 2017,
#  'yu mei-ren (fate)': 2017,
#  'hassan of serenity (fate)': 2014,
#  'shinki (touhou)': 2013,
#  'ryougi shiki': 2010,
#  "jun'you (kancolle)": 2007,
#  'shinjou akane': 2005,
#  'la+ darknesss (1st costume)': 2001,
#  'yuzu (blue archive)': 2000,
#  'makigumo (kancolle)': 1994,
#  'mori calliope (1st costume)': 1988,
#  'i-168 (kancolle)': 1986,
#  'yuugumo (kancolle)': 1983,
#  'lynette bishop': 1981,
#  'shinomiya kaguya': 1980,
#  'nian (arknights)': 1977,
#  'kudamaki tsukasa': 1977,
#  'kurosawa ruby': 1975,
#  'morpeko': 1975,
#  'shoebill (kemono friends)': 1973,
#  'neptune (neptunia)': 1968,
#  'sonozaki mion': 1967,
#  'miyamoto frederica': 1967,
#  'specter (arknights)': 1967,
#  'mayano top gun (umamusume)': 1961,
#  'lilith aensland': 1952,
#  'brendan (pokemon)': 1952,
#  'seiran (touhou)': 1952,
#  'gangut (kancolle)': 1952,
#  'jinx (league of legends)': 1948,
#  'shima rin': 1942,
#  'suiseiseki': 1937,
#  'meltryllis (swimsuit lancer) (fate)': 1937,
#  'iori (blue archive)': 1935,
#  'higashiyama kobeni': 1934,
#  'mizuno ami': 1932,
#  'seele vollerei': 1928,
#  'nachi (kancolle)': 1922,
#  'hibiki (blue archive)': 1922,
#  'izuna (blue archive)': 1918,
#  'alhaitham (genshin impact)': 1918,
#  'jakuzure nonon': 1916,
#  'satou kazuma': 1912,
#  'mysterious heroine xx (fate)': 1911,
#  'momosuzu nene': 1911,
#  'lize helesta': 1910,
#  'kaeya (genshin impact)': 1910,
#  'noumi kudryavka': 1909,
#  'krista lenz': 1906,
#  'gotland (kancolle)': 1905,
#  'albedo (genshin impact)': 1905,
#  'vegeta': 1904,
#  'angelina (arknights)': 1903,
#  'asui tsuyu': 1901,
#  'tedeza rize': 1899,
#  'blake belladonna': 1899,
#  'akatsuki kirika': 1898,
#  'orange pekoe (girls und panzer)': 1897,
#  'irisviel von einzbern': 1894,
#  'endeavor (boku no hero academia)': 1890,
#  'ujimatsu chiya': 1887,
#  'hanako (swimsuit) (blue archive)': 1886,
#  'choukai (kancolle)': 1885,
#  'aino minako': 1881,
#  'katsuki yuuri': 1880,
#  'kujou sara': 1880,
#  'tsumiki mikan': 1878,
#  "ak-12 (girls' frontline)": 1877,
#  'lucky beast (kemono friends)': 1876,
#  'robin (female) (fire emblem)': 1873,
#  'aegis (persona)': 1870,
#  'johnny joestar': 1868,
#  'ushiwakamaru (fate)': 1868,
#  '9s (nier:automata)': 1868,
#  'kinugasa (kancolle)': 1866,
#  'tachibana hibiki (symphogear)': 1861,
#  'noshiro (kancolle)': 1859,
#  'viktor nikiforov': 1859,
#  'suzutsuki (kancolle)': 1859,
#  'n (pokemon)': 1858,
#  'elizabeth bathory (fate/extra ccc)': 1858,
#  'mima (touhou)': 1851,
#  'ashiya douman (fate)': 1850,
#  'reze (chainsaw man)': 1850,
#  'leaf (pokemon)': 1849,
#  'nagatsuki (kancolle)': 1849,
#  'maru-yu (kancolle)': 1848,
#  'skadi the corrupting heart (arknights)': 1847,
#  'teruzuki (kancolle)': 1845,
#  'chiyoda momo': 1844,
#  'bardiche (nanoha)': 1843,
#  'javelin (azur lane)': 1840,
#  'vita (nanoha)': 1838,
#  'sinon': 1838,
#  'camilla (fire emblem)': 1838,
#  "jeanne d'arc alter santa lily (fate)": 1832,
#  'vivio': 1829,
#  'shiomi kotone': 1829,
#  'monokuma': 1824,
#  'shiomi syuko': 1824,
#  'lisa (genshin impact)': 1823,
#  'gengar': 1819,
#  'oda nobunaga (koha-ace)': 1817,
#  'nekomata okayu (1st costume)': 1817,
#  'yae sakura': 1814,
#  'nishizumi shiho': 1813,
#  'index (toaru majutsu no index)': 1803,
#  'lusamine (pokemon)': 1803,
#  'yuzuriha inori': 1801,
#  'levi (shingeki no kyojin)': 1799,
#  'oumae kumiko': 1796,
#  'elira pendora': 1795,
#  'andou (girls und panzer)': 1793,
#  'slime (genshin impact)': 1793,
#  'katsuragi (kancolle)': 1791,
#  'curren chan (umamusume)': 1790,
#  'nanashi mumei (1st costume)': 1788,
#  'nero claudius (bride) (fate)': 1786,
#  'shirase sakuya': 1785,
#  'pepperoni (girls und panzer)': 1782,
#  'st. louis (azur lane)': 1779,
#  'dusk (arknights)': 1777,
#  'saria (arknights)': 1774,
#  'kenzaki makoto': 1773,
#  'asashio kai ni (kancolle)': 1772,
#  'kuroshio (kancolle)': 1768,
#  'admire vega (umamusume)': 1767,
#  'last order (toaru majutsu no index)': 1765,
#  'azusa (blue archive)': 1764,
#  'chouzetsusaikawa tenshi-chan': 1763,
#  'yayoi (kancolle)': 1753,
#  'tama (kancolle)': 1752,
#  'houshou marine (summer)': 1746,
#  'suzukaze (kancolle)': 1745,
#  'shirayuki (kancolle)': 1743,
#  'hiroi kikuri': 1743,
#  'arch bishop (ragnarok online)': 1742,
#  'ranma-chan': 1741,
#  'horikawa raiko': 1740,
#  'artoria pendragon (lancer alter) (fate)': 1737,
#  'asashimo (kancolle)': 1736,
#  'takara miyuki': 1735,
#  ...}

# %%
character_tags_count_map = load_from_json("./tmp/character_tags_count_map.json")

# %%
character_tags_counts = [count for name, count in character_tags_count_map.items()]

# %%
# plot
plt.hist(character_tags_counts, bins=100, range=(1, 100))
# plt.yscale("log")
plt.xlabel("Count")
plt.ylabel("Frequency")
plt.title("Distribution of character tags counts")
plt.show()

# %%
popular_character_tags = [
    name for name, count in character_tags_count_map.items() if count > 10
]
save_to_json(popular_character_tags, "./tmp/popular_character_tags.json")
len(popular_character_tags)
# Out:
# 61578

# %% [markdown]
# ### show distribution of tags score

# %%
# get scores by rating
post_scores_rating_general = ds.filter(lambda x: x["rating"] == "g", batched=False)[
    "score"
]
post_scores_rating_sensitive = ds.filter(lambda x: x["rating"] == "s", batched=False)[
    "score"
]
post_scores_rating_questionable = ds.filter(
    lambda x: x["rating"] == "q", batched=False
)["score"]
post_scores_rating_explicit = ds.filter(lambda x: x["rating"] == "e", batched=False)[
    "score"
]
# Out:
# Filter:   0%|          | 0/7124975 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/7124975 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/7124975 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/7124975 [00:00<?, ? examples/s]

# %%
print(len(post_scores_rating_explicit))
print(len(post_scores_rating_questionable))
print(len(post_scores_rating_sensitive))
print(len(post_scores_rating_general))
# Out:
# 687358
# 882858
# 3951666
# 1603093

# %%
# plot all scores
plt.hist(post_scores_rating_explicit, bins=100, range=(0, 1000), alpha=0.5, label="e")
plt.hist(
    post_scores_rating_questionable, bins=100, range=(0, 1000), alpha=0.5, label="q"
)
plt.hist(post_scores_rating_sensitive, bins=100, range=(0, 1000), alpha=0.5, label="s")
plt.hist(post_scores_rating_general, bins=100, range=(0, 1000), alpha=0.5, label="g")
plt.legend()
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.yscale("log")
plt.title("Distribution of scores by rating")
plt.show()

# %%
# boxplot
plt.boxplot(
    [
        post_scores_rating_explicit,
        post_scores_rating_questionable,
        post_scores_rating_sensitive,
        post_scores_rating_general,
    ],
    labels=[
        "e",
        "q",
        "s",
        "g",
    ],
)
plt.yscale("log")
plt.xlabel("Rating")
plt.ylabel("Score")
plt.title("Boxplot of scores by rating")
plt.grid()
plt.show()

# %%
# sort by score
post_scores_rating_explicit.sort()
post_scores_rating_questionable.sort()
post_scores_rating_sensitive.sort()
post_scores_rating_general.sort()

# %%
# group by ratio and get the boundary score of each group
# ~ 10%, ~ 25%, ~75%, ~90%


def get_boundary_scores(scores):
    return [scores[int(len(scores) * ratio)] for ratio in [0.1, 0.25, 0.75, 0.9]]


boundary_scores_explicit = get_boundary_scores(post_scores_rating_explicit)
boundary_scores_questionable = get_boundary_scores(post_scores_rating_questionable)
boundary_scores_sensitive = get_boundary_scores(post_scores_rating_sensitive)
boundary_scores_general = get_boundary_scores(post_scores_rating_general)

quality_score_map = {
    "general": boundary_scores_general,
    "sensitive": boundary_scores_sensitive,
    "questionable": boundary_scores_questionable,
    "explicit": boundary_scores_explicit,
}
save_to_json(quality_score_map, "./tmp/quality_score_map.json")
quality_score_map
# Out:
# {'general': [1, 3, 14, 24],
#  'sensitive': [1, 4, 22, 44],
#  'questionable': [4, 10, 52, 99],
#  'explicit': [5, 14, 81, 151]}

# %%
def show_each_group_counts(scores, boundary_scores):
    counts = [0] * (len(boundary_scores) + 1)
    for score in scores:
        for i, boundary_score in enumerate(boundary_scores):
            if score <= boundary_score:
                counts[i] += 1
                break
        else:
            counts[-1] += 1
    return counts

# %%
print(show_each_group_counts(post_scores_rating_general, boundary_scores_general))
# Out:
# [188322, 239116, 784758, 230657, 160240]

# %%
print(show_each_group_counts(post_scores_rating_sensitive, boundary_scores_sensitive))
# Out:
# [429991, 683759, 1880060, 565512, 392344]

# %%
print(
    show_each_group_counts(
        post_scores_rating_questionable, boundary_scores_questionable
    )
)
# Out:
# [102755, 130558, 430707, 131044, 87794]

# %%
print(show_each_group_counts(post_scores_rating_explicit, boundary_scores_explicit))
# Out:
# [76615, 100853, 339210, 102541, 68139]

# %% [markdown]
# ## Gather tokens

# %% [markdown]
# ### Prepare special tokens

# %%
BOS_TOKEN = "<|bos|>"
EOS_TOKEN = "<|eos|>"
PAD_TOKEN = "<|pad|>"
UNK_TOKEN = "<|unk|>"
SEP_TOKEN = "<|sep|>"
MASK_TOKEN = "<|mask|>"

# group
RATING_START = "<rating>"
RATING_END = "</rating>"
GENERAL_START = "<general>"
GENERAL_END = "</general>"
CHARACTER_START = "<character>"
CHARACTER_END = "</character>"
COPYRIGHT_START = "<copyright>"
COPYRIGHT_END = "</copyright>"

# rating
RATING_SFW = "rating:sfw"
RATING_NSFW = "rating:nsfw"
RATING_GENERAL = "rating:general"
RATING_SENSITIVE = "rating:sensitive"
RATING_QUESTIONABLE = "rating:questionable"
RATING_EXPLICIT = "rating:explicit"

# quality
QUALITY_BEST = "<|best_quality|>"
QUALITY_HIGH = "<|high_quality|>"
QUALITY_NORMAL = "<|normal_quality|>"
QUALITY_LOW = "<|low_quality|>"
QUALITY_WORST = "<|worst_quality|>"

# total tags legnth
LENGTH_VERY_SHORT = "<|very_short|>"
LENGTH_SHORT = "<|short|>"
LENGTH_MEDIUM = "<|medium|>"
LENGTH_LONG = "<|long|>"
LENGTH_VERY_LONG = "<|very_long|>"

# for SFT
INPUT_START = "<|input_start|>"
INPUT_END = "<|input_end|>"

# flags
FLAG_KEEP_IDENTITY = "<|keep_identity|>"

# %%
RESERVED_TOKENS = [f"<|reserved_{i}|>" for i in range(32)]

# %%
SPECIAL_TOKENS = [
    BOS_TOKEN,
    EOS_TOKEN,
    PAD_TOKEN,
    UNK_TOKEN,
    SEP_TOKEN,
    MASK_TOKEN,
    #
    RATING_START,
    RATING_END,
    GENERAL_START,
    GENERAL_END,
    CHARACTER_START,
    CHARACTER_END,
    #
    RATING_SFW,
    RATING_NSFW,
    RATING_GENERAL,
    RATING_SENSITIVE,
    RATING_QUESTIONABLE,
    RATING_EXPLICIT,
    #
    QUALITY_BEST,
    QUALITY_HIGH,
    QUALITY_NORMAL,
    QUALITY_LOW,
    QUALITY_WORST,
    #
    LENGTH_VERY_SHORT,
    LENGTH_SHORT,
    LENGTH_MEDIUM,
    LENGTH_MEDIUM,
    LENGTH_LONG,
    LENGTH_VERY_LONG,
    #
    INPUT_START,
    INPUT_END,
    #
    FLAG_KEEP_IDENTITY,
    #
    *RESERVED_TOKENS,
]
len(SPECIAL_TOKENS)
# Out:
# 64

# %% [markdown]
# ### Prepare general/character/copyright tags

# %%
GENERAL_TAG_TOKENS = popular_general_tags
CHARACTER_TAG_TOKENS = popular_character_tags
COPYRIGHT_TAG_TOKENS = popular_copyright_tags

# %% [markdown]
# ### All

# %%
ALL_TOKENS = [
    *SPECIAL_TOKENS,
    *GENERAL_TAG_TOKENS,
    *CHARACTER_TAG_TOKENS,
    *COPYRIGHT_TAG_TOKENS,
]

# %% [markdown]
# ## Create a tokenizer!

# %%
tokenizer = Tokenizer(
    # 頭から順番に番号をつける
    WordLevel(vocab={tag: i for i, tag in enumerate(ALL_TOKENS)}, unk_token=UNK_TOKEN)
)

# %%
tokenizer.normalizer = Lowercase()

# %%
tokenizer.pre_tokenizer = Split(
    pattern=Regex(r",(?:\s)*"), behavior="removed", invert=False
)

# %%
# register special tokens
tokenizer.add_special_tokens(
    [
        AddedToken(
            content=token,
        )
        for token in SPECIAL_TOKENS
    ]
)
# Out:
# 63

# %%
# padding
tokenizer.enable_padding(pad_token=PAD_TOKEN)

# %%
tokenizer.get_vocab_size()
# Out:
# 78585

# %% [markdown]
# #### Test tokenizer

# %%
tokenizer.encode(
    "1girl, 2girls, aaa, long hair, very long hair, honkai: star rail, arknights, hogeeeeeeeee",
).tokens
# Out:
# ['1girl',
#  '2girls',
#  '<|unk|>',
#  'long hair',
#  'very long hair',
#  'honkai: star rail',
#  'arknights',
#  '<|unk|>']

# %%
# save if you want
# tokenizer.save("./tmp/tokenizer.json")

# %% [markdown]
# #### Transformers tokenizer format

# %%
pretrained_tokenizer = PreTrainedTokenizerFast(tokenizer_object=tokenizer)

pretrained_tokenizer.bos_token = BOS_TOKEN
pretrained_tokenizer.eos_token = EOS_TOKEN
pretrained_tokenizer.pad_token = PAD_TOKEN
pretrained_tokenizer.unk_token = UNK_TOKEN

# %%
pretrained_tokenizer.encode_plus("1girl, cat ears, blue hair, swept bangs")
# Out:
# {'input_ids': [64, 214, 111, 405], 'token_type_ids': [0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1]}

# %%
pretrained_tokenizer.push_to_hub("p1atdev/dart-tokenizer-v2-encode")
